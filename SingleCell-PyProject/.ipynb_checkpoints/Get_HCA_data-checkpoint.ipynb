# %% [markdown]
# # Obtain Projects and specimens from Human Cell Atlas

# %%
import requests
import json
import time

from IPython.display import clear_output

# %% [markdown]
# ## Get the samples and save them
#
# The data base has 800 samples, we indicate `size=801` to get them all.

# %%
seed_url = "https://service.explore.data.humancellatlas.org/repository/samples?filters=%7B%7D&size=801"

# %% [markdown]
# It is necessary to indicate the user agent in the request so the server do not detect we are web scraping.

# %%
# User-Agent obtenido del recurso del curso.
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %% [markdown]
# We do the request and get all the data in json format

# %%
answer = requests.get(seed_url, headers=headers)

# %% [markdown]
# If we take a look into the json, we can see that the data is in the object "hits".

# %%
# print(json.dumps(answer.json(), indent=2, sort_keys=True))

# %%
hits = answer.json()['hits']
print(len(hits))
# Out:
# 800

# %% [markdown]
# We save the hits in this raw json format.

# %%
with open('../SingleCell-Files/raw_data/HCA_samples.json', 'w') as outfile:
    json.dump({'samples': hits}, outfile)

# %% [markdown]
# ## Get the projects and save them

# %%
seed_url = "https://service.explore.data.humancellatlas.org/repository/projects?filters=%7B%7D&size=30&sort=projectTitle&order=asc"

# %%
# User-Agent obtenido del recurso del curso.
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)

# %%
project_hits = answer.json()["hits"]

print(json.dumps(projects_hits, indent=2, sort_keys=True))
# Out:
# [
#   {
#     "cellLines": [],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "brain"
#         ],
#         "organPart": [
#           "cortex"
#         ],
#         "selectedCellType": [
#           "neuron"
#         ],
#         "totalCells": 1330000
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "unknown"
#         ],
#         "disease": [
#           "normal"
#         ],
#         "donorCount": 2,
#         "genusSpecies": [
#           "Mus musculus"
#         ],
#         "id": [
#           "E18_20160930",
#           "E18_20161004"
#         ],
#         "organismAge": [
#           "18"
#         ],
#         "organismAgeRange": [
#           {
#             "gte": 1555200.0,
#             "lte": 1555200.0
#           }
#         ],
#         "organismAgeUnit": [
#           "day"
#         ]
#       }
#     ],
#     "entryId": "74b6d569-3b11-42ef-b6b1-a0454522b4a0",
#     "fileTypeSummaries": [
#       {
#         "count": 16377,
#         "fileType": "fastq",
#         "totalSize": 3206177550920
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           null
#         ],
#         "geoSeriesAccessions": [
#           "GSE93421"
#         ],
#         "insdcProjectAccessions": [
#           "SRP096558"
#         ],
#         "insdcStudyAccessions": [
#           "PRJNA360949"
#         ],
#         "laboratory": [
#           "Human Cell Atlas Data Coordination Platform"
#         ],
#         "projectShortname": "1M Neurons",
#         "projectTitle": "1.3 Million Brain Cells from E18 Mice",
#         "supplementaryLinks": [
#           "https://support.10xgenomics.com/single-cell-gene-expression/datasets/1.3.0/1M_neurons"
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina HiSeq 4000",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "10X v2 sequencing",
#           null
#         ],
#         "pairedEnd": [
#           false,
#           null
#         ],
#         "workflow": [
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "disease": [
#           "normal"
#         ],
#         "effectiveOrgan": [
#           "brain"
#         ],
#         "id": [
#           "E18_20160930_Brain",
#           "E18_20161004_Brain"
#         ],
#         "organ": [
#           "brain"
#         ],
#         "organPart": [
#           "cortex"
#         ],
#         "preservationMethod": [
#           "fresh"
#         ],
#         "sampleEntityType": [
#           "specimens"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           "normal"
#         ],
#         "id": [
#           "E18_20160930_Brain",
#           "E18_20161004_Brain"
#         ],
#         "organ": [
#           "brain"
#         ],
#         "organPart": [
#           "cortex"
#         ],
#         "preservationMethod": [
#           "fresh"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "pancreas"
#         ],
#         "organPart": [
#           null
#         ],
#         "selectedCellType": [
#           "pancreatic PP cell"
#         ],
#         "totalCells": 12404
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "female",
#           "male",
#           "unknown"
#         ],
#         "disease": [
#           "normal",
#           "type 2 diabetes mellitus"
#         ],
#         "donorCount": 14,
#         "genusSpecies": [
#           "Homo sapiens",
#           "Mus musculus"
#         ],
#         "id": [
#           "H1",
#           "H2",
#           "H3",
#           "H4",
#           "M_C57BL/6_1",
#           "M_C57BL/6_2",
#           "M_C57BL/6_3",
#           "M_C57BL/6_4",
#           "M_C57BL/6_5",
#           "M_ICR_1",
#           "M_ICR_2",
#           "M_ICR_3",
#           "M_ICR_4",
#           "M_ICR_5"
#         ],
#         "organismAge": [
#           "17",
#           "38",
#           "51",
#           "59",
#           null
#         ],
#         "organismAgeRange": [
#           {
#             "gte": 536112000.0,
#             "lte": 536112000.0
#           },
#           {
#             "gte": 1198368000.0,
#             "lte": 1198368000.0
#           },
#           {
#             "gte": 1608336000.0,
#             "lte": 1608336000.0
#           },
#           {
#             "gte": 1860624000.0,
#             "lte": 1860624000.0
#           }
#         ],
#         "organismAgeUnit": [
#           "year",
#           null
#         ]
#       }
#     ],
#     "entryId": "f86f1ab4-1fbb-4510-ae35-3ffd752d4dfc",
#     "fileTypeSummaries": [
#       {
#         "count": 38,
#         "fileType": "fastq.gz",
#         "totalSize": 418064570672
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           "E-GEOD-84133"
#         ],
#         "geoSeriesAccessions": [
#           "GSE84133"
#         ],
#         "insdcProjectAccessions": [
#           "SRP078321"
#         ],
#         "insdcStudyAccessions": [
#           "PRJNA328774"
#         ],
#         "laboratory": [
#           "Center for the Science of Therapeutics",
#           "Department of Immunology, Faculty of Medicine",
#           "Department of Stem Cell and Regenerative Biology",
#           "Department of Systems Biology",
#           "Faculty of Biology",
#           "Human Cell Atlas Data Coordination Platform"
#         ],
#         "projectShortname": "HumanMousePancreas",
#         "projectTitle": "A Single-Cell Transcriptomic Map of the Human and Mouse Pancreas Reveals Inter- and Intra-cell Population Structure",
#         "supplementaryLinks": [
#           null
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina HiSeq 2500",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "inDrop",
#           null
#         ],
#         "pairedEnd": [
#           true,
#           null
#         ],
#         "workflow": [
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "disease": [
#           null
#         ],
#         "effectiveOrgan": [
#           "pancreas"
#         ],
#         "id": [
#           "H1_pancreas",
#           "H2_pancreas",
#           "H3_pancreas",
#           "H4_pancreas",
#           "M_C57BL/6_pancreas",
#           "M_ICR_pancreas"
#         ],
#         "organ": [
#           "pancreas"
#         ],
#         "organPart": [
#           null
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "sampleEntityType": [
#           "specimens"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           null
#         ],
#         "id": [
#           "H1_pancreas",
#           "H2_pancreas",
#           "H3_pancreas",
#           "H4_pancreas",
#           "M_C57BL/6_pancreas",
#           "M_ICR_pancreas"
#         ],
#         "organ": [
#           "pancreas"
#         ],
#         "organPart": [
#           null
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "embryo"
#         ],
#         "organPart": [
#           null
#         ],
#         "selectedCellType": [
#           null
#         ],
#         "totalCells": 339089
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "female"
#         ],
#         "disease": [
#           null
#         ],
#         "donorCount": 63,
#         "genusSpecies": [
#           "Mus musculus"
#         ],
#         "id": [
#           "Female_mouse_1",
#           "Female_mouse_10",
#           "Female_mouse_11",
#           "Female_mouse_12",
#           "Female_mouse_13",
#           "Female_mouse_14",
#           "Female_mouse_15",
#           "Female_mouse_16",
#           "Female_mouse_17",
#           "Female_mouse_18",
#           "Female_mouse_19",
#           "Female_mouse_2",
#           "Female_mouse_20",
#           "Female_mouse_21",
#           "Female_mouse_22",
#           "Female_mouse_23",
#           "Female_mouse_24",
#           "Female_mouse_25",
#           "Female_mouse_26",
#           "Female_mouse_27",
#           "Female_mouse_28",
#           "Female_mouse_29",
#           "Female_mouse_3",
#           "Female_mouse_30",
#           "Female_mouse_31",
#           "Female_mouse_32",
#           "Female_mouse_33",
#           "Female_mouse_34",
#           "Female_mouse_35",
#           "Female_mouse_36",
#           "Female_mouse_37",
#           "Female_mouse_38",
#           "Female_mouse_39",
#           "Female_mouse_4",
#           "Female_mouse_40",
#           "Female_mouse_41",
#           "Female_mouse_42",
#           "Female_mouse_43",
#           "Female_mouse_44",
#           "Female_mouse_45",
#           "Female_mouse_46",
#           "Female_mouse_47",
#           "Female_mouse_48",
#           "Female_mouse_49",
#           "Female_mouse_5",
#           "Female_mouse_50",
#           "Female_mouse_51",
#           "Female_mouse_52",
#           "Female_mouse_53",
#           "Female_mouse_54",
#           "Female_mouse_55",
#           "Female_mouse_56",
#           "Female_mouse_57",
#           "Female_mouse_58",
#           "Female_mouse_59",
#           "Female_mouse_6",
#           "Female_mouse_60",
#           "Female_mouse_61",
#           "Female_mouse_62",
#           "Female_mouse_63",
#           "Female_mouse_7",
#           "Female_mouse_8",
#           "Female_mouse_9"
#         ],
#         "organismAge": [
#           "7",
#           "7-8",
#           "8",
#           "9"
#         ],
#         "organismAgeRange": [
#           {
#             "gte": 4233600.0,
#             "lte": 4233600.0
#           },
#           {
#             "gte": 4233600.0,
#             "lte": 4838400.0
#           },
#           {
#             "gte": 4838400.0,
#             "lte": 4838400.0
#           },
#           {
#             "gte": 5443200.0,
#             "lte": 5443200.0
#           }
#         ],
#         "organismAgeUnit": [
#           "week"
#         ]
#       }
#     ],
#     "entryId": "1defdada-a365-44ad-9b29-443b06bd11d6",
#     "fileTypeSummaries": [
#       {
#         "count": 10240,
#         "fileType": "fastq.gz",
#         "totalSize": 994936026664
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           "E-MTAB-6967"
#         ],
#         "geoSeriesAccessions": [
#           "GSE87038"
#         ],
#         "insdcProjectAccessions": [
#           "ERP110801"
#         ],
#         "insdcStudyAccessions": [
#           "PRJEB28586"
#         ],
#         "laboratory": [
#           null
#         ],
#         "projectShortname": "MouseGastrulationAtlas",
#         "projectTitle": "A single-cell molecular map of mouse gastrulation and early organogenesis",
#         "supplementaryLinks": [
#           "https://github.com/MarioniLab/EmbryoTimecourse2018",
#           "https://marionilab.cruk.cam.ac.uk/MouseGastrulation2018/"
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina HiSeq 2500",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "10X 3' v1 sequencing",
#           null
#         ],
#         "pairedEnd": [
#           false,
#           null
#         ],
#         "workflow": [
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "disease": [
#           null
#         ],
#         "effectiveOrgan": [
#           "embryo"
#         ],
#         "id": [
#           "embryo_pool_1",
#           "embryo_pool_10",
#           "embryo_pool_11",
#           "embryo_pool_12",
#           "embryo_pool_13",
#           "embryo_pool_14",
#           "embryo_pool_15",
#           "embryo_pool_16",
#           "embryo_pool_17",
#           "embryo_pool_18",
#           "embryo_pool_19",
#           "embryo_pool_2",
#           "embryo_pool_20",
#           "embryo_pool_21",
#           "embryo_pool_22",
#           "embryo_pool_23",
#           "embryo_pool_24",
#           "embryo_pool_25",
#           "embryo_pool_26",
#           "embryo_pool_3",
#           "embryo_pool_4",
#           "embryo_pool_5",
#           "embryo_pool_6",
#           "embryo_pool_7",
#           "embryo_pool_8",
#           "embryo_pool_9"
#         ],
#         "organ": [
#           "embryo"
#         ],
#         "organPart": [
#           null
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "sampleEntityType": [
#           "specimens"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           null
#         ],
#         "id": [
#           "embryo_pool_1",
#           "embryo_pool_10",
#           "embryo_pool_11",
#           "embryo_pool_12",
#           "embryo_pool_13",
#           "embryo_pool_14",
#           "embryo_pool_15",
#           "embryo_pool_16",
#           "embryo_pool_17",
#           "embryo_pool_18",
#           "embryo_pool_19",
#           "embryo_pool_2",
#           "embryo_pool_20",
#           "embryo_pool_21",
#           "embryo_pool_22",
#           "embryo_pool_23",
#           "embryo_pool_24",
#           "embryo_pool_25",
#           "embryo_pool_26",
#           "embryo_pool_3",
#           "embryo_pool_4",
#           "embryo_pool_5",
#           "embryo_pool_6",
#           "embryo_pool_7",
#           "embryo_pool_8",
#           "embryo_pool_9"
#         ],
#         "organ": [
#           "embryo"
#         ],
#         "organPart": [
#           null
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "lung"
#         ],
#         "organPart": [
#           "Left lateral basal bronchopulmonary segment"
#         ],
#         "selectedCellType": [
#           "T cell"
#         ],
#         "totalCells": 0
#       },
#       {
#         "organ": [
#           "blood"
#         ],
#         "organPart": [
#           "venous blood"
#         ],
#         "selectedCellType": [
#           "T cell"
#         ],
#         "totalCells": 0
#       },
#       {
#         "organ": [
#           "mediastinal lymph node"
#         ],
#         "organPart": [
#           "mediastinal lymph node"
#         ],
#         "selectedCellType": [
#           "T cell"
#         ],
#         "totalCells": 0
#       },
#       {
#         "organ": [
#           "hematopoietic system"
#         ],
#         "organPart": [
#           "bone marrow"
#         ],
#         "selectedCellType": [
#           "T cell"
#         ],
#         "totalCells": 0
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "male"
#         ],
#         "disease": [
#           "hypertension",
#           "normal"
#         ],
#         "donorCount": 4,
#         "genusSpecies": [
#           "Homo sapiens"
#         ],
#         "id": [
#           "Blood_donor_A",
#           "Blood_donor_B",
#           "Tissue_donor_1",
#           "Tissue_donor_2"
#         ],
#         "organismAge": [
#           "50-55",
#           "52",
#           "65"
#         ],
#         "organismAgeRange": [
#           {
#             "gte": 1639872000.0,
#             "lte": 1639872000.0
#           },
#           {
#             "gte": 1576800000.0,
#             "lte": 1734480000.0
#           },
#           {
#             "gte": 2049840000.0,
#             "lte": 2049840000.0
#           }
#         ],
#         "organismAgeUnit": [
#           "year"
#         ]
#       }
#     ],
#     "entryId": "4a95101c-9ffc-4f30-a809-f04518a23803",
#     "fileTypeSummaries": [
#       {
#         "count": 32,
#         "fileType": "fastq.gz",
#         "totalSize": 496164231119
#       },
#       {
#         "count": 80,
#         "fileType": "unknown",
#         "totalSize": 1497756132
#       },
#       {
#         "count": 16,
#         "fileType": "bam",
#         "totalSize": 461515369236
#       },
#       {
#         "count": 16,
#         "fileType": "matrix",
#         "totalSize": 2368
#       },
#       {
#         "count": 16,
#         "fileType": "csv",
#         "totalSize": 414889663
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           null
#         ],
#         "geoSeriesAccessions": [
#           null
#         ],
#         "insdcProjectAccessions": [
#           null
#         ],
#         "insdcStudyAccessions": [
#           null
#         ],
#         "laboratory": [
#           "Farber Lab; Columbia Center for Translational Immunology",
#           "Human Cell Atlas Data Coordination Platform",
#           "Sims Lab; Department of Systems Biology"
#         ],
#         "projectShortname": "HumanTissueTcellActivation",
#         "projectTitle": "A single-cell reference map of transcriptional states for human blood and tissue T cell activation",
#         "supplementaryLinks": [
#           null
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina HiSeq 4000",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "10X v2 sequencing",
#           null
#         ],
#         "pairedEnd": [
#           false,
#           null
#         ],
#         "workflow": [
#           "optimus_v1.3.5",
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "disease": [
#           null
#         ],
#         "effectiveOrgan": [
#           "blood",
#           "hematopoietic system",
#           "lung",
#           "mediastinal lymph node"
#         ],
#         "id": [
#           "PP001",
#           "PP002",
#           "PP003",
#           "PP004",
#           "PP005",
#           "PP006",
#           "PP009",
#           "PP010",
#           "PP011",
#           "PP012",
#           "PP013",
#           "PP014",
#           "PP017",
#           "PP018",
#           "PP019",
#           "PP020"
#         ],
#         "organ": [
#           "blood",
#           "hematopoietic system",
#           "lung",
#           "mediastinal lymph node"
#         ],
#         "organPart": [
#           "Left lateral basal bronchopulmonary segment",
#           "bone marrow",
#           "mediastinal lymph node",
#           "venous blood"
#         ],
#         "preservationMethod": [
#           "fresh"
#         ],
#         "sampleEntityType": [
#           "specimens"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           null
#         ],
#         "id": [
#           "PP001",
#           "PP002",
#           "PP003",
#           "PP004",
#           "PP005",
#           "PP006",
#           "PP009",
#           "PP010",
#           "PP011",
#           "PP012",
#           "PP013",
#           "PP014",
#           "PP017",
#           "PP018",
#           "PP019",
#           "PP020"
#         ],
#         "organ": [
#           "blood",
#           "hematopoietic system",
#           "lung",
#           "mediastinal lymph node"
#         ],
#         "organPart": [
#           "Left lateral basal bronchopulmonary segment",
#           "bone marrow",
#           "mediastinal lymph node",
#           "venous blood"
#         ],
#         "preservationMethod": [
#           "fresh"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "eye"
#         ],
#         "organPart": [
#           "retinal neural layer"
#         ],
#         "selectedCellType": [
#           null
#         ],
#         "totalCells": 44000
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "female",
#           "male"
#         ],
#         "disease": [
#           "cataract (disease)",
#           "normal"
#         ],
#         "donorCount": 3,
#         "genusSpecies": [
#           "Homo sapiens"
#         ],
#         "id": [
#           "17-010",
#           "17-011",
#           "SC"
#         ],
#         "organismAge": [
#           "42",
#           "53",
#           "80"
#         ],
#         "organismAgeRange": [
#           {
#             "gte": 1324512000.0,
#             "lte": 1324512000.0
#           },
#           {
#             "gte": 1671408000.0,
#             "lte": 1671408000.0
#           },
#           {
#             "gte": 2522880000.0,
#             "lte": 2522880000.0
#           }
#         ],
#         "organismAgeUnit": [
#           "year"
#         ]
#       }
#     ],
#     "entryId": "8185730f-4113-40d3-9cc3-929271784c2b",
#     "fileTypeSummaries": [
#       {
#         "count": 15,
#         "fileType": "fastq.gz",
#         "totalSize": 101869450565
#       },
#       {
#         "count": 25,
#         "fileType": "unknown",
#         "totalSize": 344662182
#       },
#       {
#         "count": 5,
#         "fileType": "bam",
#         "totalSize": 94362546462
#       },
#       {
#         "count": 5,
#         "fileType": "matrix",
#         "totalSize": 740
#       },
#       {
#         "count": 5,
#         "fileType": "csv",
#         "totalSize": 81162079
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           "E-MTAB-7316"
#         ],
#         "geoSeriesAccessions": [
#           null
#         ],
#         "insdcProjectAccessions": [
#           null
#         ],
#         "insdcStudyAccessions": [
#           null
#         ],
#         "laboratory": [
#           "Cellular Reprogramming Unit",
#           "Clinical Genetics Unit",
#           "Department of Chemistry and Biotechnology",
#           "Garvan\u2010Weizmann Centre for Cellular Genomics",
#           "Human Cell Atlas Data Coordination Platform",
#           "Institute for Molecular Bioscience",
#           "John Curtin School of Medical Research",
#           "Lions Eye Donation Services",
#           "National Institute for Aging",
#           "Save Sight Institute",
#           "Stem Cells and Regenerative Medicine Section, NIHR Great Ormond Street Hospital Biomedical Research Centre"
#         ],
#         "projectShortname": "WongAdultRetina",
#         "projectTitle": "A single-cell transcriptome atlas of the adult human retina",
#         "supplementaryLinks": [
#           "https://github.com/IMB-Computational-Genomics-Lab/scGPS",
#           "https://github.com/powellgenomicslab/ascend",
#           "https://github.com/satijalab/seurat"
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina HiSeq 2500",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "10X v2 sequencing",
#           null
#         ],
#         "pairedEnd": [
#           false,
#           null
#         ],
#         "workflow": [
#           "optimus_v1.3.5",
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "disease": [
#           "normal"
#         ],
#         "effectiveOrgan": [
#           "eye"
#         ],
#         "id": [
#           "17-010-R",
#           "17-011-R",
#           "SC-L"
#         ],
#         "organ": [
#           "eye"
#         ],
#         "organPart": [
#           "retinal neural layer"
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "sampleEntityType": [
#           "specimens"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           "normal"
#         ],
#         "id": [
#           "17-010-R",
#           "17-011-R",
#           "SC-L"
#         ],
#         "organ": [
#           "eye"
#         ],
#         "organPart": [
#           "retinal neural layer"
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [
#       {
#         "cellLineType": [
#           "induced pluripotent"
#         ],
#         "id": [
#           "HPSI0214i-kucg_2",
#           "HPSI0214i-wibj_2",
#           "HPSI0314i-hoik_1",
#           "HPSI0314i-sojd_3"
#         ],
#         "modelOrgan": [
#           "stem cell"
#         ]
#       }
#     ],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "brain"
#         ],
#         "organPart": [
#           null
#         ],
#         "selectedCellType": [
#           "neural cell"
#         ],
#         "totalCells": 19916
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "female",
#           "male"
#         ],
#         "disease": [
#           "normal"
#         ],
#         "donorCount": 4,
#         "genusSpecies": [
#           "Homo sapiens"
#         ],
#         "id": [
#           "HPSI0214i-kucg",
#           "HPSI0214i-wibj",
#           "HPSI0314i-hoik",
#           "HPSI0314i-sojd"
#         ],
#         "organismAge": [
#           "40-44",
#           "45-49",
#           "55-59",
#           "65-69"
#         ],
#         "organismAgeRange": [
#           {
#             "gte": 1261440000.0,
#             "lte": 1387584000.0
#           },
#           {
#             "gte": 1419120000.0,
#             "lte": 1545264000.0
#           },
#           {
#             "gte": 1734480000.0,
#             "lte": 1860624000.0
#           },
#           {
#             "gte": 2049840000.0,
#             "lte": 2175984000.0
#           }
#         ],
#         "organismAgeUnit": [
#           "year"
#         ]
#       }
#     ],
#     "entryId": "005d611a-14d5-4fbf-846e-571a1f874f70",
#     "fileTypeSummaries": [
#       {
#         "count": 18,
#         "fileType": "fastq.gz",
#         "totalSize": 53857782294
#       },
#       {
#         "count": 3,
#         "fileType": "pdf",
#         "totalSize": 15762678
#       },
#       {
#         "count": 30,
#         "fileType": "unknown",
#         "totalSize": 641963142
#       },
#       {
#         "count": 6,
#         "fileType": "bam",
#         "totalSize": 56932529172
#       },
#       {
#         "count": 6,
#         "fileType": "matrix",
#         "totalSize": 888
#       },
#       {
#         "count": 6,
#         "fileType": "csv",
#         "totalSize": 154340957
#       }
#     ],
#     "organoids": [
#       {
#         "id": [
#           "Org_HPSI0214i-kucg_2_1",
#           "Org_HPSI0214i-kucg_2_2",
#           "Org_HPSI0214i-kucg_2_3",
#           "Org_HPSI0214i-wibj_2_1",
#           "Org_HPSI0214i-wibj_2_2",
#           "Org_HPSI0214i-wibj_2_3",
#           "Org_HPSI0314i-hoik_1_1",
#           "Org_HPSI0314i-hoik_1_2",
#           "Org_HPSI0314i-hoik_1_3",
#           "Org_HPSI0314i-sojd_3_1",
#           "Org_HPSI0314i-sojd_3_2",
#           "Org_HPSI0314i-sojd_3_3"
#         ],
#         "modelOrgan": [
#           "brain"
#         ],
#         "modelOrganPart": [
#           null
#         ]
#       }
#     ],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           null
#         ],
#         "geoSeriesAccessions": [
#           null
#         ],
#         "insdcProjectAccessions": [
#           "ERP114427"
#         ],
#         "insdcStudyAccessions": [
#           "PRJEB31821"
#         ],
#         "laboratory": [
#           "Human Cell Atlas Data Coordination Platform"
#         ],
#         "projectShortname": "HPSI human cerebral organoids",
#         "projectTitle": "Assessing the relevance of organoids to model inter-individual variation",
#         "supplementaryLinks": [
#           null
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina HiSeq 2500",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "10X v2 sequencing",
#           null
#         ],
#         "pairedEnd": [
#           true,
#           null
#         ],
#         "workflow": [
#           "optimus_v1.3.1",
#           "optimus_v1.3.2",
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "effectiveOrgan": [
#           "brain"
#         ],
#         "id": [
#           "Org_HPSI0214i-kucg_2_1",
#           "Org_HPSI0214i-kucg_2_2",
#           "Org_HPSI0214i-kucg_2_3",
#           "Org_HPSI0214i-wibj_2_1",
#           "Org_HPSI0214i-wibj_2_2",
#           "Org_HPSI0214i-wibj_2_3",
#           "Org_HPSI0314i-hoik_1_1",
#           "Org_HPSI0314i-hoik_1_2",
#           "Org_HPSI0314i-hoik_1_3",
#           "Org_HPSI0314i-sojd_3_1",
#           "Org_HPSI0314i-sojd_3_2",
#           "Org_HPSI0314i-sojd_3_3"
#         ],
#         "modelOrgan": [
#           "brain"
#         ],
#         "modelOrganPart": [
#           null
#         ],
#         "sampleEntityType": [
#           "organoids"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           "normal"
#         ],
#         "id": [
#           "HPSI0214i-kucg_skin",
#           "HPSI0214i-wibj_skin",
#           "HPSI0314i-hoik_skin",
#           "HPSI0314i-sojd_skin"
#         ],
#         "organ": [
#           "skin of body"
#         ],
#         "organPart": [
#           "skin epidermis"
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "hematopoietic system"
#         ],
#         "organPart": [
#           "bone marrow"
#         ],
#         "selectedCellType": [
#           "Plasma cell"
#         ],
#         "totalCells": 9500
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "female",
#           "male"
#         ],
#         "disease": [
#           "osteoarthritis, hip"
#         ],
#         "donorCount": 12,
#         "genusSpecies": [
#           "Homo sapiens"
#         ],
#         "id": [
#           "Hip10",
#           "Hip11",
#           "Hip12",
#           "Hip13",
#           "Hip15",
#           "Hip16",
#           "Hip17",
#           "Hip5",
#           "Hip6",
#           "Hip7",
#           "Hip8",
#           "Hip9"
#         ],
#         "organismAge": [
#           "49",
#           "50",
#           "53",
#           "63",
#           "68",
#           "69",
#           "73",
#           "76",
#           "78",
#           "80",
#           "85"
#         ],
#         "organismAgeRange": [
#           {
#             "gte": 1545264000.0,
#             "lte": 1545264000.0
#           },
#           {
#             "gte": 1576800000.0,
#             "lte": 1576800000.0
#           },
#           {
#             "gte": 1671408000.0,
#             "lte": 1671408000.0
#           },
#           {
#             "gte": 1986768000.0,
#             "lte": 1986768000.0
#           },
#           {
#             "gte": 2144448000.0,
#             "lte": 2144448000.0
#           },
#           {
#             "gte": 2175984000.0,
#             "lte": 2175984000.0
#           },
#           {
#             "gte": 2302128000.0,
#             "lte": 2302128000.0
#           },
#           {
#             "gte": 2396736000.0,
#             "lte": 2396736000.0
#           },
#           {
#             "gte": 2459808000.0,
#             "lte": 2459808000.0
#           },
#           {
#             "gte": 2522880000.0,
#             "lte": 2522880000.0
#           },
#           {
#             "gte": 2680560000.0,
#             "lte": 2680560000.0
#           }
#         ],
#         "organismAgeUnit": [
#           "year"
#         ]
#       }
#     ],
#     "entryId": "a29952d9-925e-40f4-8a1c-274f118f1f51",
#     "fileTypeSummaries": [
#       {
#         "count": 50,
#         "fileType": "fastq.gz",
#         "totalSize": 32304816501
#       },
#       {
#         "count": 2,
#         "fileType": "pdf",
#         "totalSize": 204869
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           null
#         ],
#         "geoSeriesAccessions": [
#           null
#         ],
#         "insdcProjectAccessions": [
#           null
#         ],
#         "insdcStudyAccessions": [
#           null
#         ],
#         "laboratory": [
#           "Human Cell Atlas Data Coordination Platform",
#           "Prof. Ido Amit"
#         ],
#         "projectShortname": "BM_PC",
#         "projectTitle": "Bone marrow plasma cells from hip replacement surgeries",
#         "supplementaryLinks": [
#           null
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina NextSeq 500",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "MARS-seq",
#           null
#         ],
#         "pairedEnd": [
#           true,
#           null
#         ],
#         "workflow": [
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "disease": [
#           null
#         ],
#         "effectiveOrgan": [
#           "hematopoietic system"
#         ],
#         "id": [
#           "Hip10_specimen",
#           "Hip11_specimen",
#           "Hip12_specimen",
#           "Hip13_specimen",
#           "Hip15_specimen",
#           "Hip16_specimen",
#           "Hip17_specimen",
#           "Hip5_specimen",
#           "Hip6_specimen",
#           "Hip7_specimen",
#           "Hip8_specimen",
#           "Hip9_specimen"
#         ],
#         "organ": [
#           "hematopoietic system"
#         ],
#         "organPart": [
#           "bone marrow"
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "sampleEntityType": [
#           "specimens"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           null
#         ],
#         "id": [
#           "Hip10_specimen",
#           "Hip11_specimen",
#           "Hip12_specimen",
#           "Hip13_specimen",
#           "Hip15_specimen",
#           "Hip16_specimen",
#           "Hip17_specimen",
#           "Hip5_specimen",
#           "Hip6_specimen",
#           "Hip7_specimen",
#           "Hip8_specimen",
#           "Hip9_specimen"
#         ],
#         "organ": [
#           "hematopoietic system"
#         ],
#         "organPart": [
#           "bone marrow"
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "blood"
#         ],
#         "organPart": [
#           null
#         ],
#         "selectedCellType": [
#           "peripheral blood mononuclear cell"
#         ],
#         "totalCells": 20000
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "unknown"
#         ],
#         "disease": [
#           "normal"
#         ],
#         "donorCount": 8,
#         "genusSpecies": [
#           "Homo sapiens"
#         ],
#         "id": [
#           "Donor_PBMC1",
#           "Donor_PBMC2",
#           "Donor_PBMC3",
#           "Donor_PBMC4",
#           "Donor_PBMC5",
#           "Donor_PBMC6",
#           "Donor_PBMC7",
#           "Donor_PBMC8"
#         ],
#         "organismAge": [
#           null
#         ],
#         "organismAgeRange": null,
#         "organismAgeUnit": [
#           null
#         ]
#       }
#     ],
#     "entryId": "f81efc03-9f56-4354-aabb-6ce819c3d414",
#     "fileTypeSummaries": [
#       {
#         "count": 6,
#         "fileType": "fastq.gz",
#         "totalSize": 83729759795
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           null
#         ],
#         "geoSeriesAccessions": [
#           null
#         ],
#         "insdcProjectAccessions": [
#           null
#         ],
#         "insdcStudyAccessions": [
#           null
#         ],
#         "laboratory": [
#           "Human Cell Atlas Data Coordination Platform",
#           "Satija Lab",
#           "Technology Development and Innovation"
#         ],
#         "projectShortname": "Multiplexed scRNA-seq with barcoded antibodies",
#         "projectTitle": "Cell hashing with barcoded antibodies enables multiplexing and doublet detection for single cell genomics",
#         "supplementaryLinks": [
#           null
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina Hiseq 2500",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "CITE-seq",
#           null
#         ],
#         "pairedEnd": [
#           false,
#           null
#         ],
#         "workflow": [
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "disease": [
#           null
#         ],
#         "effectiveOrgan": [
#           "blood"
#         ],
#         "id": [
#           "Specimen_PBMC1",
#           "Specimen_PBMC2",
#           "Specimen_PBMC3",
#           "Specimen_PBMC4",
#           "Specimen_PBMC5",
#           "Specimen_PBMC6",
#           "Specimen_PBMC7",
#           "Specimen_PBMC8"
#         ],
#         "organ": [
#           "blood"
#         ],
#         "organPart": [
#           null
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "sampleEntityType": [
#           "specimens"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           null
#         ],
#         "id": [
#           "Specimen_PBMC1",
#           "Specimen_PBMC2",
#           "Specimen_PBMC3",
#           "Specimen_PBMC4",
#           "Specimen_PBMC5",
#           "Specimen_PBMC6",
#           "Specimen_PBMC7",
#           "Specimen_PBMC8"
#         ],
#         "organ": [
#           "blood"
#         ],
#         "organPart": [
#           null
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "immune system"
#         ],
#         "organPart": [
#           "bone marrow"
#         ],
#         "selectedCellType": [
#           "bone marrow hematopoietic cell"
#         ],
#         "totalCells": 274182
#       },
#       {
#         "organ": [
#           "blood"
#         ],
#         "organPart": [
#           "umbilical cord blood"
#         ],
#         "selectedCellType": [
#           "cord blood hematopoietic stem cell"
#         ],
#         "totalCells": 253910
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "female",
#           "male"
#         ],
#         "disease": [
#           null
#         ],
#         "donorCount": 16,
#         "genusSpecies": [
#           "Homo sapiens"
#         ],
#         "id": [
#           "BM1",
#           "BM2",
#           "BM3",
#           "BM4",
#           "BM5",
#           "BM6",
#           "BM7",
#           "BM8",
#           "CB1",
#           "CB2",
#           "CB3",
#           "CB4",
#           "CB5",
#           "CB6",
#           "CB7",
#           "CB8"
#         ],
#         "organismAge": [
#           "0",
#           "26",
#           "29",
#           "32",
#           "36",
#           "39",
#           "50",
#           "52"
#         ],
#         "organismAgeRange": [
#           {
#             "gte": 0.0,
#             "lte": 0.0
#           },
#           {
#             "gte": 819936000.0,
#             "lte": 819936000.0
#           },
#           {
#             "gte": 914544000.0,
#             "lte": 914544000.0
#           },
#           {
#             "gte": 1009152000.0,
#             "lte": 1009152000.0
#           },
#           {
#             "gte": 1135296000.0,
#             "lte": 1135296000.0
#           },
#           {
#             "gte": 1229904000.0,
#             "lte": 1229904000.0
#           },
#           {
#             "gte": 1576800000.0,
#             "lte": 1576800000.0
#           },
#           {
#             "gte": 1639872000.0,
#             "lte": 1639872000.0
#           }
#         ],
#         "organismAgeUnit": [
#           "year"
#         ]
#       }
#     ],
#     "entryId": "cc95ff89-2e68-4a08-a234-480eca21ce79",
#     "fileTypeSummaries": [
#       {
#         "count": 762,
#         "fileType": "fastq.gz",
#         "totalSize": 1306165450414
#       },
#       {
#         "count": 635,
#         "fileType": "unknown",
#         "totalSize": 7219422047
#       },
#       {
#         "count": 127,
#         "fileType": "bam",
#         "totalSize": 1237598776632
#       },
#       {
#         "count": 127,
#         "fileType": "matrix",
#         "totalSize": 18796
#       },
#       {
#         "count": 127,
#         "fileType": "csv",
#         "totalSize": 1949971768
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           null
#         ],
#         "geoSeriesAccessions": [
#           null
#         ],
#         "insdcProjectAccessions": [
#           null
#         ],
#         "insdcStudyAccessions": [
#           null
#         ],
#         "laboratory": [
#           "Human Cell Atlas Data Coordination Platform",
#           "Regev Lab"
#         ],
#         "projectShortname": "1M Immune Cells",
#         "projectTitle": "Census of Immune Cells",
#         "supplementaryLinks": [
#           null
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina HiSeq X",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "10X v2 sequencing",
#           null
#         ],
#         "pairedEnd": [
#           false,
#           null
#         ],
#         "workflow": [
#           "optimus_v1.3.2",
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "disease": [
#           null
#         ],
#         "effectiveOrgan": [
#           "blood",
#           "immune system"
#         ],
#         "id": [
#           "1_BM2",
#           "1_BM3",
#           "1_BM5",
#           "1_BM6",
#           "1_BM7",
#           "1_CB1",
#           "1_CB2",
#           "1_CB3",
#           "1_CB4",
#           "1_CB5",
#           "1_CB6",
#           "2_BM1",
#           "2_BM2",
#           "2_BM4",
#           "2_BM5",
#           "2_BM7",
#           "2_CB1",
#           "2_CB2",
#           "2_CB3",
#           "2_CB4",
#           "2_CB5",
#           "2_CB6",
#           "2_CB7",
#           "2_CB8",
#           "3_BM1",
#           "3_BM2",
#           "3_BM3",
#           "3_BM5",
#           "3_BM8",
#           "3_CB2",
#           "3_CB4",
#           "3_CB5",
#           "3_CB6",
#           "3_CB7",
#           "3_CB8",
#           "4_BM1",
#           "4_BM2",
#           "4_BM3",
#           "4_BM4",
#           "4_BM5",
#           "4_BM6",
#           "4_CB1",
#           "4_CB2",
#           "4_CB3",
#           "4_CB4",
#           "4_CB5",
#           "4_CB6",
#           "4_CB7",
#           "4_CB8",
#           "5_BM1",
#           "5_BM2",
#           "5_BM3",
#           "5_BM4",
#           "5_BM5",
#           "5_BM6",
#           "5_BM7",
#           "5_BM8",
#           "5_CB2",
#           "5_CB3",
#           "5_CB6",
#           "5_CB8",
#           "6_BM1",
#           "6_BM2",
#           "6_BM5",
#           "6_BM6",
#           "6_BM7",
#           "6_BM8",
#           "6_CB1",
#           "6_CB2",
#           "6_CB3",
#           "6_CB4",
#           "6_CB8",
#           "7_BM1",
#           "7_BM2",
#           "7_BM3",
#           "7_BM4",
#           "7_BM6",
#           "7_BM7",
#           "7_CB1",
#           "7_CB2",
#           "7_CB3",
#           "7_CB4",
#           "7_CB5",
#           "7_CB7",
#           "7_CB8",
#           "8_BM1",
#           "8_BM2",
#           "8_BM3",
#           "8_BM4",
#           "8_BM5",
#           "8_BM6",
#           "8_BM7",
#           "8_BM8",
#           "8_CB1",
#           "8_CB2",
#           "8_CB3",
#           "8_CB4",
#           "8_CB5",
#           "8_CB6",
#           "8_CB7"
#         ],
#         "organ": [
#           "blood",
#           "immune system"
#         ],
#         "organPart": [
#           "bone marrow",
#           "umbilical cord blood"
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "sampleEntityType": [
#           "specimens"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           null
#         ],
#         "id": [
#           "1_BM2",
#           "1_BM3",
#           "1_BM5",
#           "1_BM6",
#           "1_BM7",
#           "1_CB1",
#           "1_CB2",
#           "1_CB3",
#           "1_CB4",
#           "1_CB5",
#           "1_CB6",
#           "2_BM1",
#           "2_BM2",
#           "2_BM4",
#           "2_BM5",
#           "2_BM7",
#           "2_CB1",
#           "2_CB2",
#           "2_CB3",
#           "2_CB4",
#           "2_CB5",
#           "2_CB6",
#           "2_CB7",
#           "2_CB8",
#           "3_BM1",
#           "3_BM2",
#           "3_BM3",
#           "3_BM5",
#           "3_BM8",
#           "3_CB2",
#           "3_CB4",
#           "3_CB5",
#           "3_CB6",
#           "3_CB7",
#           "3_CB8",
#           "4_BM1",
#           "4_BM2",
#           "4_BM3",
#           "4_BM4",
#           "4_BM5",
#           "4_BM6",
#           "4_CB1",
#           "4_CB2",
#           "4_CB3",
#           "4_CB4",
#           "4_CB5",
#           "4_CB6",
#           "4_CB7",
#           "4_CB8",
#           "5_BM1",
#           "5_BM2",
#           "5_BM3",
#           "5_BM4",
#           "5_BM5",
#           "5_BM6",
#           "5_BM7",
#           "5_BM8",
#           "5_CB2",
#           "5_CB3",
#           "5_CB6",
#           "5_CB8",
#           "6_BM1",
#           "6_BM2",
#           "6_BM5",
#           "6_BM6",
#           "6_BM7",
#           "6_BM8",
#           "6_CB1",
#           "6_CB2",
#           "6_CB3",
#           "6_CB4",
#           "6_CB8",
#           "7_BM1",
#           "7_BM2",
#           "7_BM3",
#           "7_BM4",
#           "7_BM6",
#           "7_BM7",
#           "7_CB1",
#           "7_CB2",
#           "7_CB3",
#           "7_CB4",
#           "7_CB5",
#           "7_CB7",
#           "7_CB8",
#           "8_BM1",
#           "8_BM2",
#           "8_BM3",
#           "8_BM4",
#           "8_BM5",
#           "8_BM6",
#           "8_BM7",
#           "8_BM8",
#           "8_CB1",
#           "8_CB2",
#           "8_CB3",
#           "8_CB4",
#           "8_CB5",
#           "8_CB6",
#           "8_CB7"
#         ],
#         "organ": [
#           "blood",
#           "immune system"
#         ],
#         "organPart": [
#           "bone marrow",
#           "umbilical cord blood"
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [
#       {
#         "cellLineType": [
#           "induced pluripotent",
#           "primary",
#           "stem cell-derived"
#         ],
#         "id": [
#           "cell_line_Day0_hiPSC-CM_BioRep1",
#           "cell_line_Day0_hiPSC-CM_BioRep2",
#           "cell_line_Day15_hiPSC-CM_BioRep2",
#           "cell_line_Day1_hiPSC-CM_BioRep1",
#           "cell_line_Day1_hiPSC-CM_BioRep2",
#           "cell_line_Day3_hiPSC-CM_BioRep1",
#           "cell_line_Day3_hiPSC-CM_BioRep2",
#           "cell_line_Day7_hiPSC-CM_BioRep1",
#           "cell_line_Day7_hiPSC-CM_BioRep2",
#           "cell_line_GM18505",
#           "cell_line_GM18517"
#         ],
#         "modelOrgan": [
#           "blood",
#           "heart",
#           "stem cell"
#         ]
#       }
#     ],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "heart"
#         ],
#         "organPart": [
#           null
#         ],
#         "selectedCellType": [
#           null
#         ],
#         "totalCells": 0
#       },
#       {
#         "organ": [
#           "stem cell"
#         ],
#         "organPart": [
#           null
#         ],
#         "selectedCellType": [
#           null
#         ],
#         "totalCells": 0
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "female"
#         ],
#         "disease": [
#           "normal"
#         ],
#         "donorCount": 2,
#         "genusSpecies": [
#           "Homo sapiens"
#         ],
#         "id": [
#           "GM18505",
#           "GM18517"
#         ],
#         "organismAge": [
#           null
#         ],
#         "organismAgeRange": null,
#         "organismAgeUnit": [
#           null
#         ]
#       }
#     ],
#     "entryId": "a9c022b4-c771-4468-b769-cabcf9738de3",
#     "fileTypeSummaries": [
#       {
#         "count": 44,
#         "fileType": "fastq.gz",
#         "totalSize": 158079432433
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           null
#         ],
#         "geoSeriesAccessions": [
#           null
#         ],
#         "insdcProjectAccessions": [
#           null
#         ],
#         "insdcStudyAccessions": [
#           null
#         ],
#         "laboratory": [
#           "Basu",
#           "Human Cell Atlas Data Coordination Platform",
#           "Pott"
#         ],
#         "projectShortname": "Drop-seq, DroNc-seq, Fluidigm C1 Comparison",
#         "projectTitle": "Comparison, calibration, and benchmarking of high-throughput single cell RNA-Seq techniques for unbiased cell-type classification",
#         "supplementaryLinks": [
#           null
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina NextSeq 500",
#           null
#         ],
# ...
#           "3_56_F_Mammary_Gland_Mammary_Gland",
#           "3_57_F_Mammary_Gland_Mammary_Gland",
#           "3_8_M_Brain_Myeloid_Cerebellum",
#           "3_8_M_Brain_Non-Myeloid_Hippocampus",
#           "3_8_M_Brain_Non-Myeloid_Striatum",
#           "3_8_M_Fat_GAT",
#           "3_8_M_Heart_RA",
#           "3_8_M_Large_Intestine_Distal",
#           "3_8_M_Large_Intestine_Proximal",
#           "3_8_M_Limb_Muscle_ForelimbandHindlimb",
#           "3_8_M_Pancreas_Exocrine",
#           "3_8_M_Skin_Telogen",
#           "3_9_M_Brain_Myeloid_Cortex",
#           "3_9_M_Brain_Myeloid_Hippocampus",
#           "3_9_M_Brain_Myeloid_Striatum",
#           "3_9_M_Brain_Non-Myeloid_Cerebellum",
#           "3_9_M_Brain_Non-Myeloid_Cortex",
#           "3_9_M_Brain_Non-Myeloid_Hippocampus",
#           "3_9_M_Fat_BAT",
#           "3_9_M_Fat_GAT",
#           "3_9_M_Heart_LA",
#           "3_9_M_Heart_LV",
#           "3_9_M_Large_Intestine_Distal",
#           "3_9_M_Liver_Hepatocytes",
#           "3_9_M_Marrow_B-cells",
#           "3_9_M_Marrow_Granulocytes",
#           "3_9_M_Tongue"
#         ],
#         "organ": [
#           "adipose tissue",
#           "bladder organ",
#           "bone tissue",
#           "brain",
#           "diaphragm",
#           "heart",
#           "kidney",
#           "large intestine",
#           "liver",
#           "lung",
#           "mammary gland",
#           "muscle organ",
#           "pancreas",
#           "skin of body",
#           "spleen",
#           "thymus",
#           "tongue",
#           "trachea"
#         ],
#         "organPart": [
#           null
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "kidney"
#         ],
#         "organPart": [
#           "cortex"
#         ],
#         "selectedCellType": [
#           "endothelial cell",
#           "epithelial cell",
#           "fibroblast",
#           "monocyte",
#           "myofibroblast cell"
#         ],
#         "totalCells": 30000
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "female",
#           "male"
#         ],
#         "disease": [
#           "Enterococcus faecalis infection",
#           "Lyme disease",
#           "acoustic neuroma",
#           "acute kidney tubular necrosis",
#           "adrenal cortex adenoma",
#           "anxiety disorder",
#           "arthritis",
#           "benign prostatic hyperplasia (disease)",
#           "depressive disorder",
#           "diverticulitis",
#           "essential hypertension",
#           "gastroesophageal reflux disease",
#           "hereditary hemochromatosis",
#           "hiatus hernia (disease)",
#           "hyperlipidemia (disease)",
#           "irritable bowel syndrome",
#           "kidney cancer",
#           "non-alcoholic fatty liver disease",
#           "obstructive sleep apnea syndrome",
#           "pericardial effusion (disease)",
#           "prostate cancer",
#           "pure autonomic failure",
#           "syndromic dyslipidemia",
#           "type 2 diabetes mellitus",
#           "ventricular tachycardia"
#         ],
#         "donorCount": 6,
#         "genusSpecies": [
#           "Homo sapiens"
#         ],
#         "id": [
#           "donor_control_1",
#           "donor_control_2",
#           "donor_control_3",
#           "donor_diabetes_1",
#           "donor_diabetes_2",
#           "donor_diabetes_3"
#         ],
#         "organismAge": [
#           "52",
#           "54",
#           "57",
#           "61",
#           "62",
#           "74"
#         ],
#         "organismAgeRange": null,
#         "organismAgeUnit": [
#           null
#         ]
#       }
#     ],
#     "entryId": "577c946d-6de5-4b55-a854-cd3fde40bff2",
#     "fileTypeSummaries": [
#       {
#         "count": 28,
#         "fileType": "fastq.gz",
#         "totalSize": 173929092601
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           null
#         ],
#         "geoSeriesAccessions": [
#           "GSE131882"
#         ],
#         "insdcProjectAccessions": [
#           null
#         ],
#         "insdcStudyAccessions": [
#           null
#         ],
#         "laboratory": [
#           "Department of Medicine, Division of Nephrology",
#           "Department of Medicine, Division of Renal Medicine",
#           "Department of Pathology and Immunology",
#           "Department of Pathology, Brigham and Women\u2019s Hospital",
#           "Human Cell Atlas Data Coordination Platform"
#         ],
#         "projectShortname": "Diabetic Nephropathy snRNA-seq",
#         "projectTitle": "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy",
#         "supplementaryLinks": [
#           null
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina HiSeq 2500",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "10X 5' v2 sequencing",
#           null
#         ],
#         "pairedEnd": [
#           true,
#           null
#         ],
#         "workflow": [
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "disease": [
#           "normal",
#           "type 2 diabetes mellitus"
#         ],
#         "effectiveOrgan": [
#           "kidney"
#         ],
#         "id": [
#           "specimen_control_1",
#           "specimen_control_2",
#           "specimen_control_3",
#           "specimen_diabetes_1",
#           "specimen_diabetes_2",
#           "specimen_diabetes_3"
#         ],
#         "organ": [
#           "kidney"
#         ],
#         "organPart": [
#           "cortex"
#         ],
#         "preservationMethod": [
#           "cryopreservation in liquid nitrogen (dead tissue)"
#         ],
#         "sampleEntityType": [
#           "specimens"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           "normal",
#           "type 2 diabetes mellitus"
#         ],
#         "id": [
#           "specimen_control_1",
#           "specimen_control_2",
#           "specimen_control_3",
#           "specimen_diabetes_1",
#           "specimen_diabetes_2",
#           "specimen_diabetes_3"
#         ],
#         "organ": [
#           "kidney"
#         ],
#         "organPart": [
#           "cortex"
#         ],
#         "preservationMethod": [
#           "cryopreservation in liquid nitrogen (dead tissue)"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "embryo"
#         ],
#         "organPart": [
#           null
#         ],
#         "selectedCellType": [
#           null
#         ],
#         "totalCells": 27083
#       },
#       {
#         "organ": [
#           "endoderm"
#         ],
#         "organPart": [
#           "definitive endoderm",
#           "parietal endoderm",
#           "visceral endoderm",
#           "yolk sac endoderm",
#           null
#         ],
#         "selectedCellType": [
#           "endodermal cell",
#           null
#         ],
#         "totalCells": 54166
#       },
#       {
#         "organ": [
#           "presumptive gut"
#         ],
#         "organPart": [
#           null
#         ],
#         "selectedCellType": [
#           null
#         ],
#         "totalCells": 30952
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "female"
#         ],
#         "disease": [
#           "normal"
#         ],
#         "donorCount": 6,
#         "genusSpecies": [
#           "Mus musculus"
#         ],
#         "id": [
#           "donor_1",
#           "donor_2",
#           "donor_3",
#           "donor_4",
#           "donor_5",
#           "donor_6"
#         ],
#         "organismAge": [
#           "4-6"
#         ],
#         "organismAgeRange": [
#           {
#             "gte": 2419200.0,
#             "lte": 3628800.0
#           }
#         ],
#         "organismAgeUnit": [
#           "week"
#         ]
#       }
#     ],
#     "entryId": "4e6f083b-5b9a-4393-9890-2a83da8188f1",
#     "fileTypeSummaries": [
#       {
#         "count": 568,
#         "fileType": "fastq.gz",
#         "totalSize": 1355969710149
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           null
#         ],
#         "geoSeriesAccessions": [
#           "GSE123046",
#           "GSE123124"
#         ],
#         "insdcProjectAccessions": [
#           "SRP171031",
#           "SRP171152"
#         ],
#         "insdcStudyAccessions": [
#           "PRJNA507618"
#         ],
#         "laboratory": [
#           "Computational and Systems Biology Program",
#           "Developmental Biology Program",
#           "Human Cell Atlas Data Coordination Platform",
#           "Medical Genetics"
#         ],
#         "projectShortname": "Mouse Endoderm Project",
#         "projectTitle": "The emergent landscape of the mouse gut endoderm at single-cell resolution",
#         "supplementaryLinks": [
#           "https://github.com/dpeerlab/Harmony"
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina NovaSeq 6000",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "10X v2 sequencing",
#           null
#         ],
#         "pairedEnd": [
#           true,
#           null
#         ],
#         "workflow": [
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "disease": [
#           "normal"
#         ],
#         "effectiveOrgan": [
#           "embryo",
#           "endoderm",
#           "presumptive gut"
#         ],
#         "id": [
#           "e3.5_whole_embryos_rep1",
#           "e3.5_whole_embryos_rep2",
#           "e4.5_whole_embryos_rep1",
#           "e4.5_whole_embryos_rep2",
#           "e5.5_whole_embryos_rep1",
#           "e5.5_whole_embryos_rep2",
#           "e6.5_endoderm_rep1",
#           "e6.5_endoderm_rep2",
#           "e7.5_parietal_endoderm_rep1",
#           "e7.5_parietal_endoderm_rep2",
#           "e7.5_visceral_and_definitive_endoderm_rep1",
#           "e7.5_visceral_and_definitive_endoderm_rep2",
#           "e7.5_visceral_and_definitive_endoderm_rep3",
#           "e8.75_guttube_rep1",
#           "e8.75_guttube_rep2",
#           "e8.75_guttube_rep3",
#           "e8.75_guttube_rep4",
#           "e8.75_parietal_endoderm_rep1",
#           "e8.75_parietal_endoderm_rep2",
#           "e8.75_yolksac_endoderm_rep1",
#           "e8.75_yolksac_endoderm_rep2"
#         ],
#         "organ": [
#           "embryo",
#           "endoderm",
#           "presumptive gut"
#         ],
#         "organPart": [
#           "definitive endoderm",
#           "parietal endoderm",
#           "visceral endoderm",
#           "yolk sac endoderm",
#           null
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "sampleEntityType": [
#           "specimens"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           "normal"
#         ],
#         "id": [
#           "e3.5_whole_embryos_rep1",
#           "e3.5_whole_embryos_rep2",
#           "e4.5_whole_embryos_rep1",
#           "e4.5_whole_embryos_rep2",
#           "e5.5_whole_embryos_rep1",
#           "e5.5_whole_embryos_rep2",
#           "e6.5_endoderm_rep1",
#           "e6.5_endoderm_rep2",
#           "e7.5_parietal_endoderm_rep1",
#           "e7.5_parietal_endoderm_rep2",
#           "e7.5_visceral_and_definitive_endoderm_rep1",
#           "e7.5_visceral_and_definitive_endoderm_rep2",
#           "e7.5_visceral_and_definitive_endoderm_rep3",
#           "e8.75_guttube_rep1",
#           "e8.75_guttube_rep2",
#           "e8.75_guttube_rep3",
#           "e8.75_guttube_rep4",
#           "e8.75_parietal_endoderm_rep1",
#           "e8.75_parietal_endoderm_rep2",
#           "e8.75_yolksac_endoderm_rep1",
#           "e8.75_yolksac_endoderm_rep2"
#         ],
#         "organ": [
#           "embryo",
#           "endoderm",
#           "presumptive gut"
#         ],
#         "organPart": [
#           "definitive endoderm",
#           "parietal endoderm",
#           "visceral endoderm",
#           "yolk sac endoderm",
#           null
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   },
#   {
#     "cellLines": [],
#     "cellSuspensions": [
#       {
#         "organ": [
#           "eye"
#         ],
#         "organPart": [
#           "fovea centralis",
#           "retina"
#         ],
#         "selectedCellType": [
#           "neuron",
#           null
#         ],
#         "totalCells": 230800
#       }
#     ],
#     "donorOrganisms": [
#       {
#         "biologicalSex": [
#           "female",
#           "male"
#         ],
#         "disease": [
#           "normal"
#         ],
#         "donorCount": 4,
#         "genusSpecies": [
#           "Homo sapiens"
#         ],
#         "id": [
#           "19D013",
#           "19D014",
#           "19D015",
#           "D001-12"
#         ],
#         "organismAge": [
#           "73",
#           "78",
#           "84"
#         ],
#         "organismAgeRange": [
#           {
#             "gte": 2302128000.0,
#             "lte": 2302128000.0
#           },
#           {
#             "gte": 2459808000.0,
#             "lte": 2459808000.0
#           },
#           {
#             "gte": 2649024000.0,
#             "lte": 2649024000.0
#           }
#         ],
#         "organismAgeUnit": [
#           "year"
#         ]
#       }
#     ],
#     "entryId": "9c20a245-f2c0-43ae-82c9-2232ec6b594f",
#     "fileTypeSummaries": [
#       {
#         "count": 39,
#         "fileType": "fastq.gz",
#         "totalSize": 1289852895325
#       },
#       {
#         "count": 4,
#         "fileType": "pdf",
#         "totalSize": 10065207
#       }
#     ],
#     "organoids": [],
#     "projects": [
#       {
#         "arrayExpressAccessions": [
#           null
#         ],
#         "geoSeriesAccessions": [
#           null
#         ],
#         "insdcProjectAccessions": [
#           null
#         ],
#         "insdcStudyAccessions": [
#           null
#         ],
#         "laboratory": [
#           "Department of Ophthalmology and Visual Sciences",
#           "Human Genome Sequencing Center, Department of Molecular and Human Genetics,"
#         ],
#         "projectShortname": "snRNA-seq_for_human_retina",
#         "projectTitle": "Transcriptomic classification of human retinal cell types with single-nuclei RNA-seq.",
#         "supplementaryLinks": [
#           null
#         ]
#       }
#     ],
#     "protocols": [
#       {
#         "assayType": [
#           null
#         ],
#         "instrumentManufacturerModel": [
#           "Illumina NovaSeq 6000",
#           null
#         ],
#         "libraryConstructionApproach": [
#           "10x 3' v3 sequencing",
#           null
#         ],
#         "pairedEnd": [
#           false,
#           null
#         ],
#         "workflow": [
#           null
#         ]
#       }
#     ],
#     "samples": [
#       {
#         "disease": [
#           null
#         ],
#         "effectiveOrgan": [
#           "eye"
#         ],
#         "id": [
#           "19D013_fovea",
#           "19D013_per",
#           "19D014_fovea",
#           "19D014_per",
#           "19D015_fovea",
#           "19D015_per",
#           "D001-12_per"
#         ],
#         "organ": [
#           "eye"
#         ],
#         "organPart": [
#           "fovea centralis",
#           "retina"
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "sampleEntityType": [
#           "specimens"
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ],
#     "specimens": [
#       {
#         "disease": [
#           null
#         ],
#         "id": [
#           "19D013_fovea",
#           "19D013_per",
#           "19D014_fovea",
#           "19D014_per",
#           "19D015_fovea",
#           "19D015_per",
#           "D001-12_per"
#         ],
#         "organ": [
#           "eye"
#         ],
#         "organPart": [
#           "fovea centralis",
#           "retina"
#         ],
#         "preservationMethod": [
#           null
#         ],
#         "source": [
#           "specimen_from_organism"
#         ]
#       }
#     ]
#   }
# ]

# %%
projects = []
accessing_error = []

n_projects = len(project_hits)

for n, hit in enumerate(project_hits):
    entry_id = hit["entryId"]
    seed_url = "https://service.explore.data.humancellatlas.org/repository/projects/" + entry_id

    # Print loop information
    print("Getting project with id \"" + entry_id + "\"...")
    print("Number of errors: " + str(len(accessing_error)))
    print(f"{n+1}/{n_projects}")
    
    time.sleep(2)
    
    answer_project = requests.get(seed_url, headers=headers)
    
    # If couldn't get the information save the error
    if answer.status_code != requests.codes.ok:
        accessing_error.append(answer)
        clear_output(wait=True)
        continue
    
    projects.append(answer_project.json())
    
    clear_output(wait=True)
# Out:
# Getting project with id "9c20a245-f2c0-43ae-82c9-2232ec6b594f"...
# Number of errors: 0
# 28/28

# %%
with open('../SingleCell-Files/raw_data/HCA_projects.json', 'w') as outfile:
    json.dump({"projects": projects}, outfile)

# %% [markdown]
# # Parse HCA

# %%
import json

with open('../SingleCell-Files/hits_raw.json') as f:
    hits = json.load(f)

# %%
def hca2ont(text):
    if text is None:
        return None
    
    if type(text) is list:
        return list(map(hca2ont, text))
    
    aux = list(text.title())
    
    for i in range(len(text)):
        if text[i].isupper():
            aux[i] = text[i]
    
    return ''.join(aux).replace(' ', '')

# %% [markdown]
# # Full json individual

# %%
print(json.dumps(hits[559], indent=2, sort_keys=True))
# Out:
# {
#   "cellLines": [
#     {
#       "cellLineType": [
#         "primary"
#       ],
#       "id": [
#         "Cell_line_1"
#       ],
#       "modelOrgan": [
#         "immune system"
#       ]
#     }
#   ],
#   "cellSuspensions": [
#     {
#       "organ": [
#         "embryo",
#         "immune system"
#       ],
#       "organPart": [
#         "skin epidermis",
#         null
#       ],
#       "selectedCellType": [
#         "dendritic cell"
#       ],
#       "totalCells": 0
#     }
#   ],
#   "donorOrganisms": [
#     {
#       "biologicalSex": [
#         "unknown"
#       ],
#       "disease": [
#         "normal"
#       ],
#       "donorCount": 1,
#       "genusSpecies": [
#         "Homo sapiens"
#       ],
#       "id": [
#         "Donor1"
#       ],
#       "organismAge": [
#         null
#       ],
#       "organismAgeRange": null,
#       "organismAgeUnit": [
#         null
#       ]
#     }
#   ],
#   "entryId": "6a28bd71-9910-47e3-b01c-f9e6fd720341",
#   "fileTypeSummaries": [
#     {
#       "count": 12,
#       "fileType": "fastq.gz",
#       "totalSize": 12689741805
#     },
#     {
#       "count": 5,
#       "fileType": "unknown",
#       "totalSize": 61699776
#     },
#     {
#       "count": 1,
#       "fileType": "bam",
#       "totalSize": 11827751995
#     },
#     {
#       "count": 1,
#       "fileType": "matrix",
#       "totalSize": 148
#     },
#     {
#       "count": 1,
#       "fileType": "csv",
#       "totalSize": 18382607
#     }
#   ],
#   "organoids": [],
#   "projects": [
#     {
#       "laboratory": [
#         "Center for Neurobiology and Brain Restoration",
#         "Department of Laboratory Medicine",
#         "Human Cell Atlas Data coordination Platform"
#       ],
#       "projectShortname": [
#         "Reprogrammed_Dendritic_Cells"
#       ],
#       "projectTitle": [
#         "Single cell profiling of human induced dendritic cells generated by direct reprogramming of embryonic fibroblasts"
#       ]
#     }
#   ],
#   "protocols": [
#     {
#       "assayType": [
#         null
#       ],
#       "instrumentManufacturerModel": [
#         "Illumina NextSeq 500",
#         null
#       ],
#       "libraryConstructionApproach": [
#         "10X v2 sequencing",
#         null
#       ],
#       "pairedEnd": [
#         false,
#         null
#       ],
#       "workflow": [
#         "optimus_v1.3.5",
#         null
#       ]
#     }
#   ],
#   "samples": [
#     {
#       "cellLineType": "primary",
#       "effectiveOrgan": "immune system",
#       "id": "Cell_line_1",
#       "modelOrgan": "immune system",
#       "sampleEntityType": "cellLines"
#     }
#   ],
#   "specimens": [
#     {
#       "disease": [
#         "normal"
#       ],
#       "id": [
#         "Specimen1"
#       ],
#       "organ": [
#         "embryo"
#       ],
#       "organPart": [
#         "skin epidermis"
#       ],
#       "preservationMethod": [
#         null
#       ],
#       "source": [
#         "specimen_from_organism"
#       ]
#     }
#   ]
# }

# %%
individual = {}

# %% [markdown]
# # Cell Lines
#
# Nada que cambiar

# %%
for i in range(len(hits)):
    if hits[i]['cellLines']:
        print("#"*30)
        print("\nHIT NUMBER " + str(i))
        print(json.dumps(hits[i]['cellLines'], indent=2, sort_keys=True))
        
        if len(hits[i]['cellLines']) > 1:
            print("@"*60)
            print("More than 1")
            print("@"*60)
           
        
        # break
# Out:
# ##############################
#
# HIT NUMBER 559
# [
#   {
#     "cellLineType": [
#       "primary"
#     ],
#     "id": [
#       "Cell_line_1"
#     ],
#     "modelOrgan": [
#       "immune system"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 560
# [
#   {
#     "cellLineType": [
#       "primary"
#     ],
#     "id": [
#       "Cell_line_2"
#     ],
#     "modelOrgan": [
#       "immune system"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 590
# [
#   {
#     "cellLineType": [
#       "stem cell"
#     ],
#     "id": [
#       "HS_BM_1_cell_line"
#     ],
#     "modelOrgan": [
#       "hematopoietic system"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 591
# [
#   {
#     "cellLineType": [
#       "stem cell"
#     ],
#     "id": [
#       "HS_BM_2_cell_line"
#     ],
#     "modelOrgan": [
#       "hematopoietic system"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 592
# [
#   {
#     "cellLineType": [
#       "stem cell"
#     ],
#     "id": [
#       "HS_BM_3_cell_line"
#     ],
#     "modelOrgan": [
#       "hematopoietic system"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 626
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0214i-kucg_2"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 627
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0214i-kucg_2"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 628
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0214i-kucg_2"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 629
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0214i-wibj_2"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 630
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0214i-wibj_2"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 631
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0214i-wibj_2"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 632
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0314i-hoik_1"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 633
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0314i-hoik_1"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 634
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0314i-hoik_1"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 635
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0314i-sojd_3"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 636
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0314i-sojd_3"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 637
# [
#   {
#     "cellLineType": [
#       "induced pluripotent"
#     ],
#     "id": [
#       "HPSI0314i-sojd_3"
#     ],
#     "modelOrgan": [
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 662
# [
#   {
#     "cellLineType": [
#       "primary"
#     ],
#     "id": [
#       "Cell_line_1",
#       "Cell_line_2"
#     ],
#     "modelOrgan": [
#       "immune system"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 714
# [
#   {
#     "cellLineType": [
#       "induced pluripotent",
#       "primary"
#     ],
#     "id": [
#       "cell_line_Day0_hiPSC-CM_BioRep1",
#       "cell_line_GM18505"
#     ],
#     "modelOrgan": [
#       "blood",
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 715
# [
#   {
#     "cellLineType": [
#       "induced pluripotent",
#       "primary"
#     ],
#     "id": [
#       "cell_line_Day0_hiPSC-CM_BioRep2",
#       "cell_line_GM18517"
#     ],
#     "modelOrgan": [
#       "blood",
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 716
# [
#   {
#     "cellLineType": [
#       "primary",
#       "stem cell-derived"
#     ],
#     "id": [
#       "cell_line_Day15_hiPSC-CM_BioRep2",
#       "cell_line_GM18517"
#     ],
#     "modelOrgan": [
#       "blood",
#       "heart"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 717
# [
#   {
#     "cellLineType": [
#       "primary",
#       "stem cell-derived"
#     ],
#     "id": [
#       "cell_line_Day1_hiPSC-CM_BioRep1",
#       "cell_line_GM18505"
#     ],
#     "modelOrgan": [
#       "blood",
#       "heart"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 718
# [
#   {
#     "cellLineType": [
#       "primary",
#       "stem cell-derived"
#     ],
#     "id": [
#       "cell_line_Day1_hiPSC-CM_BioRep2",
#       "cell_line_GM18517"
#     ],
#     "modelOrgan": [
#       "blood",
#       "heart"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 719
# [
#   {
#     "cellLineType": [
#       "primary",
#       "stem cell-derived"
#     ],
#     "id": [
#       "cell_line_Day3_hiPSC-CM_BioRep1",
#       "cell_line_GM18505"
#     ],
#     "modelOrgan": [
#       "blood",
#       "heart"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 720
# [
#   {
#     "cellLineType": [
#       "primary",
#       "stem cell-derived"
#     ],
#     "id": [
#       "cell_line_Day3_hiPSC-CM_BioRep2",
#       "cell_line_GM18517"
#     ],
#     "modelOrgan": [
#       "blood",
#       "heart"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 721
# [
#   {
#     "cellLineType": [
#       "primary",
#       "stem cell-derived"
#     ],
#     "id": [
#       "cell_line_Day7_hiPSC-CM_BioRep1",
#       "cell_line_GM18505"
#     ],
#     "modelOrgan": [
#       "blood",
#       "heart"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 722
# [
#   {
#     "cellLineType": [
#       "primary",
#       "stem cell-derived"
#     ],
#     "id": [
#       "cell_line_Day7_hiPSC-CM_BioRep2",
#       "cell_line_GM18517"
#     ],
#     "modelOrgan": [
#       "blood",
#       "heart"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 723
# [
#   {
#     "cellLineType": [
#       "stem cell-derived"
#     ],
#     "id": [
#       "cell_line_WAe001-A",
#       "cell_line_at_day_100"
#     ],
#     "modelOrgan": [
#       "brain",
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 724
# [
#   {
#     "cellLineType": [
#       "stem cell-derived"
#     ],
#     "id": [
#       "cell_line_WAe001-A",
#       "cell_line_at_day_125"
#     ],
#     "modelOrgan": [
#       "brain",
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 725
# [
#   {
#     "cellLineType": [
#       "stem cell-derived"
#     ],
#     "id": [
#       "cell_line_WAe001-A",
#       "cell_line_at_day_26"
#     ],
#     "modelOrgan": [
#       "brain",
#       "stem cell"
#     ]
#   }
# ]
# ##############################
#
# HIT NUMBER 726
# [
#   {
#     "cellLineType": [
#       "stem cell-derived"
#     ],
#     "id": [
#       "cell_line_WAe001-A",
#       "cell_line_at_day_54"
#     ],
#     "modelOrgan": [
#       "brain",
#       "stem cell"
#     ]
#   }
# ]

# %%
cell_line_type = hits[559]['cellLines'][0]['cellLineType']
model_organ = hits[559]['cellLines'][0]['modelOrgan']
                         
individual['cell_line_type'] = hca2ont(cell_line_type)
individual['model_organ'] = hca2ont(model_organ)
                         
print(json.dumps(individual ,indent=2, sort_keys=True))

# %% [markdown]
# # Cell Suspensions
#
# - Organ: 1P Mayus y sin espacios.
# - Organ part: 1P Mayus y sin espacios.
# - Selected Cell Types: 1P Mayus y sin espacios.
# - Total Cells: OK

# %%
print(json.dumps(hits[2]['cellSuspensions'], indent=2, sort_keys=True))
# Out:
# [
#   {
#     "organ": [
#       "lymph node"
#     ],
#     "organPart": [
#       null
#     ],
#     "selectedCellType": [
#       "CD8-positive, alpha-beta T cell"
#     ],
#     "totalCells": 91
#   }
# ]

# %%
organ = hits[2]['cellSuspensions'][0]['organ']
organ_part = hits[2]['cellSuspensions'][0]['organPart']
selected_cell_type = hits[2]['cellSuspensions'][0]['selectedCellType']
total_cells = hits[2]['cellSuspensions'][0]['totalCells']
                         
individual['organ'] = hca2ont(organ)
individual['organ_part'] = hca2ont(organ_part)
individual['selected_cell_type'] = hca2ont(selected_cell_type)
individual['total_cells'] = total_cells
                         
print(json.dumps(individual ,indent=2, sort_keys=True))

# %% [markdown]
# # Donor Organism
#
# - Biological Sex: 1P Mayus
# - Disease: 1P Mayus sin espacios.
# - Donor Count: OK
# - Genus Species: 1P Mayus sin espacios.
# - Organism Age: OK

# %%
print(json.dumps(hits[0]['donorOrganisms'], indent=2, sort_keys=True))
# Out:
# [
#   {
#     "biologicalSex": [
#       "female"
#     ],
#     "disease": [
#       "melanoma (disease)"
#     ],
#     "donorCount": 1,
#     "genusSpecies": [
#       "Mus musculus"
#     ],
#     "id": [
#       "1104"
#     ],
#     "organismAge": [
#       "6-12"
#     ],
#     "organismAgeRange": [
#       {
#         "gte": 3628800.0,
#         "lte": 7257600.0
#       }
#     ],
#     "organismAgeUnit": [
#       "week"
#     ]
#   }
# ]

# %%
biological_sex = hits[0]['donorOrganisms'][0]['biologicalSex']
disease = hits[0]['donorOrganisms'][0]['disease']
donor_count = hits[0]['donorOrganisms'][0]['donorCount']
genus_species = hits[0]['donorOrganisms'][0]['genusSpecies']
organism_age = hits[0]['donorOrganisms'][0]['organismAge']
organism_age_range = hits[0]['donorOrganisms'][0]['organismAgeRange']
organism_age_unit = hits[0]['donorOrganisms'][0]['organismAgeUnit']

individual['biological_sex'] = hca2ont(biological_sex)
individual['disease'] = hca2ont(disease)
individual['donor_count'] = donor_count
individual['genus_species'] = hca2ont(genus_species)
individual['organism_age'] = organism_age
individual['organism_age_range'] = organism_age_range
individual['organism_age_unit'] = hca2ont(organism_age_unit)
                         
print(json.dumps(individual ,indent=2, sort_keys=True))

# %% [markdown]
# # Entry Id
#
# Nada de aqui se usa.

# %%
print(json.dumps(hits[0]['entryId'], indent=2, sort_keys=True))

# %% [markdown]
# # File Type Summaries
#
# - File Type: OK

# %%
print(json.dumps(hits[559]['fileTypeSummaries'], indent=2, sort_keys=True))

# %%
file_type = []
count = []
total_size = []

for i in range(len(hits[559]['fileTypeSummaries'])):
    file_type.append(hits[559]['fileTypeSummaries'][i]['fileType'])
    count.append(hits[559]['fileTypeSummaries'][i]['count'])
    total_size.append(hits[559]['fileTypeSummaries'][i]['totalSize'])
    
individual['file_type'] = file_type
individual['count'] = count
individual['total_size'] = total_size

print(json.dumps(individual ,indent=2, sort_keys=True))

# %% [markdown]
# # Organoids
#
# Nada de aqui

# %%
for i in range(len(hits)):
    if hits[i]['organoids']:
        print("#"*30)
        print("\nHIT NUMBER " + str(i))
        print(json.dumps(hits[i]['organoids'], indent=2, sort_keys=True))
        
        if len(hits[i]['organoids']) > 1:
            print("@"*60)
            print("More than 1")
            print("@"*60)

# %%
model_organ = hits[626]['organoids'][0]['modelOrgan']
model_organ_part = hits[626]['organoids'][0]['modelOrganPart']

individual['model_organ'] = hca2ont(model_organ)
individual['model_organ_part'] = hca2ont(model_organ_part)
                         
print(json.dumps(individual ,indent=2, sort_keys=True))

# %% [markdown]
# # Projects
#
# - Laboratory: 1P Mayus sin espacios ("Human Cell Atlas" en vez de "Human Cell Atlas Data Coordination Platform")

# %%
print(json.dumps(hits[0]['projects'], indent=2, sort_keys=True))
# Out:
# [
#   {
#     "laboratory": [
#       "Human Cell Atlas Data Coordination Platform",
#       "Institute of Cellular Medicine",
#       "MRC Cancer Unit",
#       "Sarah Teichmann"
#     ],
#     "projectShortname": [
#       "Mouse Melanoma"
#     ],
#     "projectTitle": [
#       "Melanoma infiltration of stromal and immune cells"
#     ]
#   }
# ]

# %%
laboratory = hits[0]['projects'][0]['laboratory']
project_shortname = hits[0]['projects'][0]['projectShortname']
project_title = hits[0]['projects'][0]['projectTitle']

individual['laboratory'] = hca2ont(laboratory)
individual['project_shortname'] = project_shortname
individual['project_title'] = project_title

print(json.dumps(individual ,indent=2, sort_keys=True))

# %% [markdown]
# # Protocols
#
# - Instrument Manufactured Model: Sin espcios.
# - Library Construct approach: 1P en mayus y sin '-'.
# - Paired End: OK

# %%
for i in range(len(hits)):
    if hits[i]['protocols'] and hits[i]['protocols'][0]['workflow'][0] is not None:
        print("#"*30)
        print("\nHIT NUMBER " + str(i))
        print(json.dumps(hits[i]['protocols'][0]['workflow'], indent=2, sort_keys=True))
        
        if len(hits[i]['protocols']) > 1:
            print("@"*60)
            print("More than 1")
            print("@"*60)

# print(json.dumps(hits[0]['protocols'], indent=2, sort_keys=True))

# %%
instrument_manufacturer_model = hits[0]['protocols'][0]['instrumentManufacturerModel']
library_construction_approach = hits[0]['protocols'][0]['libraryConstructionApproach']
paired_end = hits[0]['protocols'][0]['pairedEnd']

individual['instrument_manufacturer_model'] = hca2ont(instrument_manufacturer_model)
individual['library_construction_approach'] = hca2ont(library_construction_approach)
individual['paired_end'] = paired_end

print(json.dumps(individual ,indent=2, sort_keys=True))

# %% [markdown]
# # Samples
#
# Nada

# %%
print(json.dumps(hits[559]['samples'], indent=2, sort_keys=True))

for i in range(len(hits)):
    if hits[i]['samples'] and hits[i]['samples'][0]['preservationMethod'] is not None:
        print("#"*30)
        print("\nHIT NUMBER " + str(i))
        print(json.dumps(hits[i]['samples'][0]['preservationMethod'], indent=2, sort_keys=True))
        
        if len(hits[i]['protocols']) > 1:
            print("@"*60)
            print("More than 1")
            print("@"*60)
# Out:
# [
#   {
#     "cellLineType": "primary",
#     "effectiveOrgan": "immune system",
#     "id": "Cell_line_1",
#     "modelOrgan": "immune system",
#     "sampleEntityType": "cellLines"
#   }
# ]
# ##############################
#
# HIT NUMBER 78
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 79
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 96
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 97
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 98
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 99
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 100
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 101
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 102
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 103
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 104
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 105
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 106
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 107
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 108
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 109
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 110
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 111
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 112
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 113
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 114
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 115
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 116
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 117
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 118
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 119
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 120
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 121
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 122
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 123
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 124
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 125
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 126
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 127
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 128
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 129
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 130
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 131
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 132
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 133
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 134
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 135
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 136
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 137
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 138
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 139
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 140
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 141
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 142
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 143
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 144
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 145
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 146
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 147
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 148
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 149
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 150
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 151
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 152
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 153
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 154
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 155
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 156
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 157
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 158
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 159
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 160
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 161
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 162
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 163
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 164
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 165
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 166
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 167
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 168
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 169
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 170
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 171
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 172
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 173
# "cryopreservation, other"
# ##############################
#
# HIT NUMBER 491
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 492
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 493
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 494
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 495
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 496
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 497
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 498
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 499
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 500
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 501
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 502
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 503
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 504
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 505
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 506
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 507
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 508
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 509
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 510
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 511
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 512
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 513
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 514
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 515
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 516
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 517
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 518
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 519
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 520
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 521
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 522
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 523
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 524
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 525
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 526
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 527
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 528
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 529
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 530
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 531
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 532
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 533
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 534
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 535
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 536
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 537
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 538
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 539
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 540
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 541
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 542
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 543
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 544
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 545
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 546
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 547
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 548
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 549
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 550
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 551
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 552
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 553
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 554
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 555
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 556
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 557
# "hypothermic preservation media at 2-8C"
# ##############################
#
# HIT NUMBER 558
# "fresh"
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-e09eef3574d9> in <module>
#       2
#       3 for i in range(len(hits)):
# ----> 4     if hits[i]['samples'] and hits[i]['samples'][0]['preservationMethod'] is not None:
#       5         print("#"*30)
#       6         print("\nHIT NUMBER " + str(i))
#
# KeyError: 'preservationMethod'

# %% [markdown]
# # Specimens
#
# - id: OK

# %%
print(json.dumps(hits[659]['specimens'], indent=2, sort_keys=True))
# Out:
# [
#   {
#     "disease": [
#       null
#     ],
#     "id": [
#       "PP019"
#     ],
#     "organ": [
#       "blood"
#     ],
#     "organPart": [
#       "venous blood"
#     ],
#     "preservationMethod": [
#       "fresh"
#     ],
#     "source": [
#       "specimen_from_organism"
#     ]
#   }
# ]

# %%
individual_id = hits[0]['specimens'][0]['id'][0]
preservation_method = hits[659]['specimens'][0]['preservationMethod'][0]

individual['id'] = individual_id
individual['preservation_method'] = hca2ont(preservation_method)

print(json.dumps(individual ,indent=2, sort_keys=True))
