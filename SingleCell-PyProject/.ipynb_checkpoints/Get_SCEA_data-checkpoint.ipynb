# %% [markdown]
# # Obtain Projects and specimens from Single Cell Expression Atlas

# %% [markdown]
# ## Imports

# %%
import requests
import json
import re
import time

from pprint import pprint
from lxml import html
from IPython.display import clear_output

# %% [markdown]
# ## Get the projects and save them

# %%
def get_info_from_html(experiment_ID):
    seed_url = "https://www.ebi.ac.uk/gxa/sc/experiments/" + experiment_ID + "/experiment-design"
  
    # Get the project samples information
    answer = requests.get(seed_url, headers=headers)
    
    # If couldn't get the information save the error
    if answer.status_code != requests.codes.ok:
        accessing_error.append(answer)
        clear_output(wait=True)
        return None
    
    # Parse response so we get the sample information
    parser = html.fromstring(answer.text)
    script_text = parser.xpath(".//div[@id='content']//script[3]/text()") 
    match = re.search(r'content: (?P<value>{.*})', script_text[0])
    value = match.group('value')
    
    return value

# %%
seed_url = "https://www.ebi.ac.uk/gxa/sc/json/experiments"

# %%
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)

# %%
accessing_error = []
projects = []
n_experiments = len(answer.json()["experiments"])

avoid_collections = ["Human Cell Atlas"]

for n, experiment in enumerate(answer.json()['experiments']):
    experiment_ID = experiment['experimentAccession']
    seed_url = "https://www.ebi.ac.uk/gxa/sc/experiments/" + experiment_ID + "/results/tsne"
    
    # Print loop information
    print("Getting project \"" + experiment_ID + "\"")
    print("Number of errors: " + str(len(accessing_error)))
    print(f"{n+1}/{n_experiments}")
    
    # If the projects is in a repository we already have we skip it
    if [i for i in experiment["experimentProjects"] if i in avoid_collections]:
        clear_output(wait=True)
        continue
    
    # Wait between request so we dont overcharge server
    time.sleep(2.0)
    
    # Get the project samples information
    answer = requests.get(seed_url, headers=headers)
    
    # If couldn't get the information save the error
    if answer.status_code != requests.codes.ok:
        accessing_error.append(answer)
        clear_output(wait=True)
        continue
        
    # Parse response so we get the useful information
    parser = html.fromstring(answer.text)
    publication_link = parser.xpath(".//a[@class='pubmed-id']/@href")
    publication_title = parser.xpath(".//a[@class='pubmed-id']/text()")

    experiment['publication_link'] = publication_link
    experiment['publication_title'] = publication_title
    experiment['repository_link'] = seed_url
    experiment['supplementary_link'] = []
    
    # Get supplementary information
    seed_url = "https://www.ebi.ac.uk/gxa/sc/json/experiments/" + experiment_ID + "/resources/SUPPLEMENTARY_INFORMATION"
    ## Wait between request so we dont overcharge server
    time.sleep(2.0)
    
    answer = requests.get(seed_url, headers=headers)
    answer_json = answer.json()
    experiment['ENA_ID'] = None
    experiment['ArrayExpress_ID'] = None

    # For each repository information, save the id and the url of the project
    for group in answer.json():
        if group['type'] == 'icon-ena': # If ENA repository
            ena_id_re = re.search('([SE]RP\d+)', group['description'])
            
            if not ena_id_re:
                continue
            
            ena_id = ena_id_re.group(1)
            
            experiment['ENA_ID'] = ena_id
            experiment['supplementary_link'].append(group['url'])
            
        elif group['type'] == 'icon-ae': # If Array Expression repository
            ae_id_re = re.search('(E-MTAB-\d+)', group['description'])
            
            if not ae_id_re:
                continue
            
            ae_id = ae_id_re.group(1)
            
            experiment['ArrayExpress_ID'] = ae_id
            experiment['supplementary_link'].append(group['url'])
            
        else:
            continue
    
    # Get download information
    time.sleep(2.0)
   
    info = get_info_from_html(experiment_ID)
    
    print(info)
    
    experiment['downloads'] = info['tabs'][3]['props']['data']
    
    # Add the project to the list
    projects.append(experiment)
    
    clear_output(wait=True)
# Out:
# Getting project "E-CURD-10"
# Number of errors: 0
# 1/175
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-89870a835858> in <module>
#      83     info = get_info_from_html(experiment_ID)
#      84
# ---> 85     experiment['downloads'] = info['tabs'][3]['props']['data']
#      86
#      87     # Add the project to the list
#
# TypeError: string indices must be integers

# %%
print(len(projects))

# %%
with open('../SingleCell-Files/raw_data/SCAE_projects.json', 'w') as outfile:
    json.dump({"experiments": projects}, outfile)

# %% [markdown]
# # Get the specimens and save them

# %%
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
# https://www.ebi.ac.uk/gxa/sc/experiments/*NOMBRE EXPERIMENTO*/experiment-design
experiment_ID = projects[100]['experimentAccession']
seed_url = "https://www.ebi.ac.uk/gxa/sc/experiments/" + experiment_ID + "/experiment-design"

# %%
answer = requests.get(seed_url, headers=headers)

# %%
parser = html.fromstring(answer.text)

# %%
script_text = parser.xpath(".//div[@id='content']//script[3]/text()")

# %%
print(answer.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8">
#     <title>Experiment < Single Cell Expression Atlas &lt; EMBL-EBI</title>
#     <meta name="description" content="EMBL-EBI Single Cell Expression Atlas, an open public repository of single cell gene expression data">
#     <meta name="keywords" content="expression atlas, single cell expression, gene expression, baseline expression, functional genomics, public repository, repository, bioinformatics, europe, institute">
#     <meta name="author" content="EBI Gene Expression Team – https://www.ebi.ac.uk/about/people/irene-papatheodorou">
#     <meta name="HandheldFriendly" content="true" />
#     <meta name="MobileOptimized" content="width" />
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <meta name="theme-color" content="#70BDBD"> <!-- Android Chrome mobile browser tab color -->
#
#     <!-- Add information on the life cycle of this page -->
#     <meta name="ebi:owner" content="Irene Papatheodorou <irenep@ebi.ac.uk>">
#     <meta name="ebi:review-cycle" content="60">
#     <meta name="ebi:last-review" content="2018-05-01">
#     <meta name="ebi:expiry" content="2018-07-01">
#
#     <!-- If you link to any other sites frequently, consider optimising performance with a DNS prefetch -->
#     <link rel="dns-prefetch" href="https://www.ebi.ac.uk/gxa/">
#     <link rel="dns-prefetch" href="https://www.ebi.ac.uk/arrayexpress/">
#     <link rel="dns-prefetch" href="https://www.ebi.ac.uk/">
#     <link rel="dns-prefetch" href="https://embl.de/">
#
#     <!-- If you have custom icon, replace these as appropriate. You can generate them at realfavicongenerator.net -->
#     <link rel="icon" type="image/x-icon" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/favicon.ico" />
#     <link rel="icon" type="image/png" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/favicon-32x32.png" />
#     <link rel="icon" type="image/png" sizes="192×192" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/android-chrome-192x192.png" /> <!-- Android (192px) -->
#     <link rel="apple-touch-icon-precomposed" sizes="114x114" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/apple-icon-114x114.png" /> <!-- For iPhone 4 Retina display (114px) -->
#     <link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/apple-icon-72x72.png" /> <!-- For iPad (72px) -->
#     <link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/apple-icon-144x144.png" /> <!-- For iPad retina (144px) -->
#     <link rel="apple-touch-icon-precomposed" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/apple-icon-57x57.png" /> <!-- For iPhone (57px) -->
#     <link rel="mask-icon" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/safari-pinned-tab.svg" color="#ffffff" /> <!-- Safari icon for pinned tab -->
#     <meta name="msapplication-TileColor" content="#2b5797" /> <!-- MS Icons -->
#     <meta name="msapplication-TileImage" content="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/mstile-144x144.png" />
#
#     <!-- CSS: implied media=all -->
#     <!-- CSS concatenated and minified via ant build script-->
#     <link rel="stylesheet" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/css/ebi-global.css" type="text/css" media="all" />
#     <link rel="stylesheet" href="https://ebi.emblstatic.net/web_guidelines/EBI-Icon-fonts/v1.3/fonts.css" type="text/css" media="all" />
#
#     <!-- If you have a custom header image or colour -->
#     <meta name="ebi:masthead-color" content="rgb(0,124,130)" />
#     <meta name="ebi:masthead-image" content="/gxa/sc/resources/images/cells_background.png" />
#
#     <!-- you can replace this with theme-[projectname].css. See http://www.ebi.ac.uk/web/style/colour for details of how to do this -->
#     <!-- also inform ES so we can host your colour palette file -->
#     <!-- <link rel="stylesheet" href="https://dev.ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/css/theme-embl-petrol.css" type="text/css" media="all" /> -->
#     <link rel="stylesheet" href="/gxa/sc/resources/css/theme-atlas.css" type="text/css" media="all">
#
#     <!-- Use this CSS file for any custom styling -->
#     <link rel="stylesheet" href="/gxa/sc/resources/css/atlas.css" type="text/css" media="all">
#     <!-- end CSS-->
# </head>
#
# <body>
# <div id="skip-to">
#     <ul>
#         <li><a href="#content">Skip to main content</a></li>
#         <li><a href="#local-nav">Skip to local navigation</a></li>
#         <li><a href="#global-nav">Skip to EBI global navigation menu</a></li>
#         <li><a href="#global-nav-expanded">Skip to expanded EBI global navigation menu (includes all sub-sections)</a></li>
#     </ul>
# </div>
#
#
#
# <header id="masthead-black-bar" class="clearfix masthead-black-bar">
# </header>
#
# <script>
#   // Hack that solves https://github.com/ebiwd/EBI-Framework/pull/139 (I got tired of waiting)
#   window.addEventListener('load', function(event) {
#     $('#masthead-black-bar nav')[2].className='row expanded';
#   });
# </script>
#
#
#
# <div data-sticky-container>
#     <header id="masthead" class="masthead" data-sticky data-sticky-on="large" data-top-anchor="content:top" data-btm-anchor="content:bottom">
#         <div class="masthead-inner row expanded">
#             <div class="small-12 large-8 columns">
#                 <!-- local-title -->
#                 <a href="/gxa/sc/home" title="Back to Single Cell Expression Atlas homepage">
#                     <div class="media-object" id="local-title">
#                         <div class="media-object-section hide-for-small-only">
#                             <img src="/gxa/sc/resources/images/logos/sc_atlas_logo.png" alt="Single Cell Expression Atlas logo" style="height:7em">
#                         </div>
#                         <div class="media-object-section">
#                             <h1>Single&nbsp;Cell Expression&nbsp;Atlas</h1>
#                             <h4 class="show-for-large">Single cell gene expression across species</h4>
#                         </div>
#                     </div>
#                 </a>
#             </div>
#             <div class="small-12 large-4 columns">
#                 <div class="media-object" style="display: flex; justify-content: flex-end; align-items: center;">
#                     <div class="media-object-section">
#                         <h4 class="show-for-large">Query bulk expression</h4>
#                         <a href="/gxa" title="To Expression Atlas" class="button" style="box-shadow: 2px 2px 2px 2px rgba(0,0,0,0.5)"><i class="icon icon-functional" data-icon="<"></i> Back to Expression Atlas</a>
#                     </div>
#                     <div class="media-object-section show-for-large">
#                         <a href="https://wellcome.ac.uk/">
#                             <img src="/gxa/sc/resources/images/logos/wellcome_trust_logo_black.png" alt="Wellcome Trust logo" style="max-height: 5.5em; background: white">
#                         </a>
#                     </div>
#                 </div>
#             </div>
#
#             <nav>
#                 <ul id="local-nav" class="dropdown menu float-left" data-description="navigational">
#                     <li id="local-nav-home"><a href="/gxa/sc/home"><i class="icon icon-generic padding-right-medium" data-icon="H"></i>Home</a></li>
#                     <li id="local-nav-search"><a href="/gxa/sc/search"><i class="icon icon-functional padding-right-medium" data-icon="1"></i>Gene search</a></li>
#                     <li id="local-nav-experiments"><a href="/gxa/sc/experiments"><i class="icon icon-functional padding-right-medium" data-icon="C"></i>Browse experiments</a></li>
#
#                     <li id="local-nav-release-notes"><a href="/gxa/sc/release-notes.html"><i class="icon icon-generic padding-right-medium" data-icon=";"></i>Release notes</a></li>
#                     <li id="local-nav-help"><a href="/gxa/sc/help.html"><i class="icon icon-generic padding-right-medium" data-icon="?"></i>Help</a></li>
#
#                     <li id="local-nav-feedback"><a href="https://www.ebi.ac.uk/support/gxasc" target="_blank" data-icon="X"><i class="icon icon-generic padding-right-medium" data-icon="s"></i>Support</a></li>
#                 </ul>
#             </nav>
#             <!-- /local-nav -->
#         </div>
#     </header>
# </div>
#
#
# <div id="content">
#     <div id="main-content-area" class="margin-top-large margin-bottom-large" role="main">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="experimentDescription" class="row column expanded">
#     <div class="media-object stack-for-small">
#
#
#         <div class="media-object-section middle">
#             <h3 id="goto-experiment">
#                 Single cell RNA-sequencing of PBMC derived B cells from human healthy donor
#             </h3>
#
#             <h5>Single-cell RNA-Seq mRNA baseline</h5>
#             <div>Number of cells: 116</div>
#
#             <div id="experimentOrganisms">Organism:
#                 <span style="font-style:italic">Homo sapiens</span>
#             </div>
#
#
#
#
#
#
#         </div>
#     </div>
# </div>
#
#
# <div class="row column margin-top-large expanded">
#     <div id="experiment-page"></div>
# </div>
#
# <div id="feedback-button"></div>
#
# <link rel="stylesheet" href="/gxa/sc/resources/css/react-popup.css" type="text/css" media="all">
# <script defer src="/gxa/sc/resources/js-bundles/feedbackForm.bundle.js"></script>
#
# <script defer src="/gxa/sc/resources/js-bundles/experimentPage.bundle.js"></script>
#
# <script>
#   document.addEventListener("DOMContentLoaded", function(event) {
#     experimentPage.render({
#       atlasUrl: '/gxa/sc/',
#       resourcesUrl: '/gxa/sc/resources/js-bundles/',
#       content: {"experimentAccession":"E-MTAB-6386","accessKey":"","species":"homo sapiens","disclaimer":"","tabs":[{"type":"results","name":"Results","props":{"ks":[1,2,3,18,33,45,59],"ksWithMarkerGenes":[2,3,18],"selectedK":3,"perplexities":[10,35,1,25,45,5,30,15,50,40,20],"metadata":[{"value":"cell_type","label":"Cell type"}],"units":["CPM"],"suggesterEndpoint":"json/suggestions"}},{"type":"experiment-design","name":"Experiment Design","props":{"table":{"headers":[{"name":"","values":["Assay"]},{"name":"Sample Characteristics","values":["organism","developmental stage","individual","age","sex","disease","organism part","cell type","phenotype","single cell quality"]},{"name":"Experimental Variables","values":["cell type","single cell identifier"]}],"data":[{"properties":{"analysed":true},"values":[["ERR2632411"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 13"]]},{"properties":{"analysed":true},"values":[["ERR2632412"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 14"]]},{"properties":{"analysed":true},"values":[["ERR2632413"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 15"]]},{"properties":{"analysed":true},"values":[["ERR2632414"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 16"]]},{"properties":{"analysed":true},"values":[["ERR2632415"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 17"]]},{"properties":{"analysed":true},"values":[["ERR2632416"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 18"]]},{"properties":{"analysed":true},"values":[["ERR2632417"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 19"]]},{"properties":{"analysed":true},"values":[["ERR2632418"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 20"]]},{"properties":{"analysed":true},"values":[["ERR2632419"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 21"]]},{"properties":{"analysed":true},"values":[["ERR2632420"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 22"]]},{"properties":{"analysed":true},"values":[["ERR2632421"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 23"]]},{"properties":{"analysed":true},"values":[["ERR2632422"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 24"]]},{"properties":{"analysed":true},"values":[["ERR2632423"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 55"]]},{"properties":{"analysed":true},"values":[["ERR2632424"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 56"]]},{"properties":{"analysed":true},"values":[["ERR2632425"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 57"]]},{"properties":{"analysed":true},"values":[["ERR2632426"],["Homo sapiens","adult","A","33 year","female","normal","blood","memory B cell","CD19+ IgD- CD27+ IgG+","OK"],["memory B cell","cell 58"]]},{"properties":{"analysed":true},"values":[["ERR2632427"],["Homo sapiens","adult ...
#     }, 'experiment-page');
#     feedbackForm.render({
#       feedbackFormLink: 'https://www.ebi.ac.uk/support/gxasc',
#       gaId: 'UA-37676851-3'
#     }, 'feedback-button');
#   });
# </script>
#
#     </div>
# </div>
#
#
#
# <footer id="local-footer" class="local-footer" role="local-footer">
#     <div id="relationships" class="row">
#         <!-- https://www.ebi.ac.uk/style-lab/websites/patterns/banner-elixir.html -->
#         <div class="small-10 columns">
#             <div id="elixir-banner"
#                  data-color="none"
#                  data-use-cdr-logo="false"
#                  data-name="This service"
#                  data-description="Expression Atlas is an ELIXIR database service"
#                  data-more-information-link="https://www.elixir-europe.org/about-us/who-we-are/nodes/embl-ebi"
#                  data-use-basic-styles="false">
#             </div>
#         </div>
#         <div class="small-2 columns text-right padding-top-medium">
#             <a href="https://wellcome.ac.uk/" class="clear">
#                 <img src="/gxa/sc/resources/images/logos/wellcome_trust_logo_black.png"
#                      alt="Wellcome Trust logo" style="height: 4em">
#             </a>
#         </div>
#     </div>
# </footer>
#
# <script defer="defer" src="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/js/elixirBanner.js"></script>
#
#
#
# <footer>
#     <div id="global-footer" class="global-footer">
#         <nav id="global-nav-expanded" class="global-nav row">
#         </nav>
#         <section id="ebi-footer-meta" class="ebi-footer-meta row">
#         </section>
#     </div>
# </footer>
#
#
# <!-- Custom JavaScript -->
# <!-- Don’t defer or async, these two need to be loaded before other bundles, which are effectively deferred -->
# <script src="/gxa/sc/resources/js/lib/babel-polyfill.min.js"></script>
# <script src="/gxa/sc/resources/js/lib/fetch-polyfill.min.js"></script>
# <script src="/gxa/sc/resources/js/lib/url-search-params-polyfill.min.js"></script>
# <script src="/gxa/sc/resources/js/lib/append-polyfill.min.js"></script>
# <script src="/gxa/sc/resources/js-bundles/vendorCommons.bundle.js"></script>
#
# <!-- JavaScript -->
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js"></script>
# <script defer="defer" src="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/js/script.js"></script>
#
# <!-- The Foundation theme JavaScript -->
# <script src="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/libraries/foundation-6/js/foundation.js"></script>
# <script src="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/js/foundationExtendEBI.js"></script>
# <script type="text/JavaScript">$(document).foundation();</script>
# <script type="text/JavaScript">$(document).foundationExtendEBI();</script>
#
# <!-- Google Analytics -->
# <script>
#   window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#   ga('create', 'UA-37676851-3', 'auto');
#   ga('send', 'pageview');
# </script>
# <script async src="https://www.google-analytics.com/analytics.js"></script>
# <!-- End Google Analytics -->
#
# </body>
# </html>

# %%
match = re.search(r'content: (?P<value>{.*})', script_text[0])

pprint(match.group('value'))
# Out:
# ('{"experimentAccession":"E-ENAD-21","accessKey":"","species":"homo '
#  'sapiens","disclaimer":"","tabs":[{"type":"results","name":"Results","props":{"ks":[3,4,7,9,10,14,17,24,28],"ksWithMarkerGenes":[3,4,7,9,10,14,17,24],"selectedK":3,"perplexities":[10,35,1,25,45,5,30,15,50,40,20],"metadata":[{"value":"cell_type","label":"Cell '
#  'type"},{"value":"individual","label":"Individual"},{"value":"age","label":"Age"}],"units":["CPM"],"suggesterEndpoint":"json/suggestions"}},{"type":"experiment-design","name":"Experiment '
#  'Design","props":{"table":{"headers":[{"name":"","values":["Assay"]},{"name":"Sample '
#  'Characteristics","values":["organism","individual","sex","age","ethnic '
#  'group","clinical information","organism part","facs marker","cell '
#  'type","fluidigm c1 run"]},{"name":"Experimental Variables","values":["single '
#  'cell identifier","cell '
#  'type"]}],"data":[{"properties":{"analysed":true},"values":[["SRR7008457"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A1","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008458"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A2","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008459"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A3","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008460"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A4","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008461"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A5","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008462"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A6","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008463"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A7","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008464"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A8","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008465"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A9","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008466"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A10","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008467"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A11","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008468"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_A12","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008469"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B1","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008470"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B2","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008471"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B3","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008472"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B4","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008473"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B5","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008474"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B6","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008475"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B7","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008476"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B8","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008477"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B9","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008478"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B10","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008479"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B11","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008480"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_B12","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008481"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C1","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008482"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C2","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008483"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C3","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008484"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C4","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008485"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C5","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008486"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C6","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008487"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C7","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008488"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C8","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008489"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C9","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008490"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C10","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008491"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C11","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008492"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_C12","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008493"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D1","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008494"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D2","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008495"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D3","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008496"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D4","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008497"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D5","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008498"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D6","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008499"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D7","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008500"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D8","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008501"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D9","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008502"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D10","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008503"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D11","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008504"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_D12","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008505"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_E1","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008506"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_E2","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008507"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_E3","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008508"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_E4","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008509"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_E5","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008510"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_E6","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008511"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_E7","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008512"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_E8","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008513"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_E9","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008514"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L1_I1"],["L1_I1_BAS_E10","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008515"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_E11","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008516"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_E12","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008517"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F1","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008518"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F2","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008519"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F3","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008520"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F4","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008521"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F5","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008522"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F6","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008523"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F7","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008524"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F8","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008525"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F9","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008526"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F10","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008527"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F11","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008528"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_F12","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008529"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G1","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008530"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G2","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008531"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G3","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008532"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G4","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008533"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G5","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008534"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G6","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008535"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G7","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008536"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G8","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008537"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G9","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008538"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G10","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008539"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G11","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008540"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_G12","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008541"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H1","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008542"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H2","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008543"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H3","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008544"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H4","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008545"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H5","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008546"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H6","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008547"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H7","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008548"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H8","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008549"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H9","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008550"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H10","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008551"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H11","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008552"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L1_I1"],["L1_I1_LUM_H12","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008553"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_A1","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008554"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_A2","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008555"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_A3","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008556"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_A4","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008557"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_A5","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008558"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_A6","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008559"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_A7","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008560"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_A8","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008561"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_A9","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008562"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_A10","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008563"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B1","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008564"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B2","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008565"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B3","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008566"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B4","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008567"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B5","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008568"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B6","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008569"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B7","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008570"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B8","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008571"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B9","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008572"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B10","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008573"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B11","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008574"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_B12","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008575"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C1","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008576"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C2","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008577"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C3","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008578"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C4","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008579"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C5","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008580"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C6","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008581"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C7","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008582"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C8","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008583"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C9","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008584"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C10","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008585"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C11","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008586"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_C12","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008587"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D1","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008588"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D2","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008589"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D3","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008590"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D4","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008591"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D5","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008592"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D6","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008593"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D7","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008594"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D8","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008595"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D9","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008596"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D10","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008597"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D11","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008598"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_D12","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008599"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_E1","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008600"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_E2","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008601"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_E3","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008602"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_E4","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008603"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","luminal '
#  'epithelial cell of mammary gland","L2_I1"],["L2_I1_LUM_E5","luminal '
#  'epithelial cell of mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7008604"],["Homo '
#  'sapiens","individual1","female","37 year","Caucasian","reduction '
# ...
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_E3","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010834"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_E4","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010835"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_E6","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010836"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_E7","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010837"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_E8","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010838"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_E10","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010839"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_E11","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010840"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_E12","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010841"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F1","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010842"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F2","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010843"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F3","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010844"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F4","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010845"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F5","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010846"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F6","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010847"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F7","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010848"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F8","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010849"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F9","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010850"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F10","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010851"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F11","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010852"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_F12","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010853"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_G1","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010854"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_G2","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010855"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_G3","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010856"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_G5","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010857"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_G6","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010858"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_G7","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010859"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_G8","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010860"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_G9","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010861"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_G10","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010862"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_G11","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010863"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_G12","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010864"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_H1","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010865"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_H2","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010866"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_H5","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010867"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_H8","myoepithelial cell of '
#  'mammary '
#  'gland"]]},{"properties":{"analysed":true},"values":[["SRR7010868"],["Homo '
#  'sapiens","individual3","female","20 year","Caucasian","reduction '
#  'mammoplasty","breast epithelium","CD31, CD45, EpCAM, CD49f","myoepithelial '
#  'cell of mammary gland","L5_I3"],["L5_I3_BAS_H12","myoepithelial cell of '
#  'mammary '
#  'gland"]]}]},"downloadUrl":"experiment/E-ENAD-21/download?fileType\\u003dexperiment-design\\u0026accessKey\\u003d"}},{"type":"supplementary-information","name":"Supplementary '
#  'Information","props":{"sections":[{"type":"static-table","name":"Analysis '
#  'Methods","props":{"data":[["Analysis","Software","Version","Citation"],["filter_cells","Scanpy '
#  'FilterCells","1.4.3+galaxy1","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_filter_cells/8e48fa9618c1"],["filter_genes","Scanpy '
#  'FilterGenes","1.4.3+galaxy3","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_filter_genes/fa6c08064fc1"],["Filtering '
#  'and '
#  'trimming","fastq_utils","0.18.2","https://github.com/nunofonseca/fastq_utils"],["Filtering '
#  'and '
#  'trimming","FASTX-Toolkit","0.0.14","http://hannonlab.cshl.edu/fastx_toolkit/"],["find_clusters","Scanpy '
#  'FindCluster","1.4.3+galaxy1","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_cluster/455846afcc73"],["find_markers","Scanpy '
#  'FindMarkers","1.4.3+galaxy1","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_markers/c18f446dcfbf"],["find_variable_genes","Scanpy '
#  'FindVariableGenes","1.4.3+galaxy9","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_variable_genes/7a68f44c866b"],["Gene/transcript '
#  'quantification","kallisto","0.45.0","Nicolas L Bray, Harold Pimentel, Páll '
#  'Melsted, Lior Pachter. Near-optimal probabilistic RNA-seq quantification. '
#  'Nature Biotechnology '
#  '(2016)."],["GTF2GeneList","GTF2GeneList","1.42.1+galaxy4","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/gtf2gene_list/b6354c917ef9"],["neighbours '
#  'for umap","Scanpy '
#  'ComputeGraph","1.4.3+galaxy11","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_compute_graph/232937b5bb8f"],["neighbours","Scanpy '
#  'ComputeGraph","1.4.3+galaxy0","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_compute_graph/6b2673e1f4c6"],["n_neighbors","Scanpy '
#  'ParameterIterator","0.0.1+galaxy2","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_parameter_iterator/7c4d44c14ceb"],["normalise_data","Scanpy '
#  'NormaliseData","1.4.3+galaxy3","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_normalise_data/f7322b68cc90"],["Pipeline","Gene '
#  'expression group single-cell analysis pipeline '
#  '(Nextflow)","20.04.1","https://github.com/ebi-gene-expression-group/scxa-control-workflow"],["plot_pca","Scanpy '
#  'PlotEmbed","1.4.3+galaxy0","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_plot_embed/882f4671d686"],["QC","FastQC","0.11.8","http://www.bioinformatics.babraham.ac.uk/projects/fastqc/"],["Reference","Ensembl","99","Homo_sapiens.GRCh38.cdna.all.99.fa.gz, '
#  'Homo_sapiens.GRCh38.99.gtf.gz"],["resolution","Scanpy '
#  'ParameterIterator","0.0.1+galaxy1","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_parameter_iterator/f0dd61087af3"],["run_pca","Scanpy '
#  'RunPCA","1.4.3+galaxy10","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_pca/2dd53b944e78"],["run_tsne","Scanpy '
#  'RunTSNE","1.4.3+galaxy1","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_tsne/3589dfaef3f6"],["run_umap","Scanpy '
#  'RunUMAP","1.4.3+galaxy1","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_umap/c111d7d04f0b"],["Scanpy '
#  'Read10x","Scanpy '
#  'Read10x","1.4.3+galaxy0","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_read_10x/cf55e0e462da"],["Configuration","scxa-workflows","db1eeaf","https://github.com/ebi-gene-expression-group/scxa-workflows"]]}},{"type":"resources","name":"Resources","props":{"url":"json/experiments/E-ENAD-21/resources/SUPPLEMENTARY_INFORMATION"}}]}},{"type":"downloads","name":"Downloads","props":{"data":[{"title":"Metadata '
#  'files","files":[{"url":"experiment/E-ENAD-21/download/zip?fileType\\u003dexperiment-metadata\\u0026accessKey\\u003d","type":"icon-tsv","description":"Experiment '
#  'metadata (SDRF and IDF files '
#  'archive)","isDownload":true},{"url":"experiment/E-ENAD-21/download?fileType\\u003dexperiment-design\\u0026accessKey\\u003d","type":"icon-experiment-design","description":"Experiment '
#  'design file (TSV format)","isDownload":true}]},{"title":"Result '
#  'files","files":[{"url":"experiment/E-ENAD-21/download?fileType\\u003dcluster\\u0026accessKey\\u003d","type":"icon-tsv","description":"Clustering '
#  'file (TSV '
#  'format)","isDownload":true},{"url":"experiment/E-ENAD-21/download/zip?fileType\\u003dmarker-genes\\u0026accessKey\\u003d","type":"icon-tsv","description":"Marker '
#  'gene files (TSV files '
#  'archive)","isDownload":true},{"url":"experiment/E-ENAD-21/download/zip?fileType\\u003dnormalised\\u0026accessKey\\u003d","type":"icon-tsv","description":"Normalised '
#  'counts files (MatrixMarket '
#  'archive)","isDownload":true},{"url":"experiment/E-ENAD-21/download/zip?fileType\\u003dquantification-raw\\u0026accessKey\\u003d","type":"icon-tsv","description":"Raw '
#  'counts files (MatrixMarket archive)","isDownload":true}]}]}}]}')

# %%
specimens = []
accessing_error = []

for n, experiment in enumerate(projects):
    # Get the ID of the proyect and make the url
    experiment_ID = experiment['experimentAccession']
    seed_url = "https://www.ebi.ac.uk/gxa/sc/experiments/" + experiment_ID + "/experiment-design"
  
    # Print loop information
    print("Getting specimens from experiment \"" + experiment_ID + "\"")
    print("Number of errors: " + str(len(accessing_error)))
    print(f"{n+1}/{len(projects)}")
    # Wait between request so we dont overcharge server
    time.sleep(2.0)

    # Get the project samples information
    answer = requests.get(seed_url, headers=headers)
    
    # If couldn't get the information save the error
    if answer.status_code != requests.codes.ok:
        accessing_error.append(answer)
        clear_output(wait=True)
        continue
    
    # Parse response so we get the sample information
    parser = html.fromstring(answer.text)
    script_text = parser.xpath(".//div[@id='content']//script[3]/text()") 
    match = re.search(r'content: (?P<value>{.*})', script_text[0])
    value = match.group('value')
    
    # Add the samples to the list
    specimens.append(json.loads(value))
    
    clear_output(wait=True)
# Out:
# Getting specimens from experiment "E-ENAD-27"
# Number of errors: 0
# 24/153
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-42a6cb927afc> in <module>
#      12     print(f"{n+1}/{len(projects)}")
#      13     # Wait between request so we dont overcharge server
# ---> 14     time.sleep(2.0)
#      15
#      16     # Get the project samples information
#
# KeyboardInterrupt:

# %%
accessing_error[0].url

# %%
specimens_json = {'specimens': specimens}

# %%
with open('../SingleCell-Files/raw_data/SCAE_samples.json', 'w') as outfile:
    json.dump(specimens_json, outfile)
