# %%
import requests
import pandas as pd
import urllib.parse
import json
import time
import re

from IPython.display import clear_output
from GetTermsOntobee import get_URI_from_name, get_name_from_URI

# %%
seed_url = "https://www.ebi.ac.uk/gxa/sc/json/experiments"

# %%
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)

# %%
ontologies = ['CL', 'EFO', 'UBERON', 'NCIT', 'PO']

# %%
def get_terms_from_project(experiment_id, name_column, ontology_column):
    terms = []
    terms_names = []
    
    experiment_metadata = f"https://www.ebi.ac.uk/gxa/sc/experiment/{experiment_id}/download?fileType=experiment-design&accessKey="
    
    df = pd.read_csv(experiment_metadata, sep='\t', low_memory=False)
            
    if name_column in df.columns:
        project_term_names = df[name_column].unique()
        project_term_URIs = df[ontology_column].unique()
    
        # Balance names and URIs
        project_term_URIs = list(project_term_URIs)
        project_term_URIs += [None] * (len(project_term_names) - len(project_term_URIs))
        
        for name, URI in zip(project_term_names, project_term_URIs):
            # If we have already code the cell_type we skip it
            if name in terms_names:
                continue
            
            print(name)
            
            # If we have no info of URI we search for it
            if URI is None or str(URI) == 'nan':
                for ontology in ontologies:
                    
                    URI = get_URI_from_name(name, ontology)
                    time.sleep(1)
                    
                    if URI is not None:
                        terms.append({
                            'name': name,
                            'URI': URI
                        })
                
                if URI is None:
                    URI = get_URI_from_name(name)
                    time.sleep(1)
                    
                    terms.append({
                        'name': name,
                        'URI': URI
                    })
                    
            # Otherwise   
            else:                    
                terms_names.append(name)

                terms.append({
                    'name': name,
                    'URI': URI
                })
                
            # If there are two or more cell types in the name
            if URI is None:
                new_l = re.split(' and |, ', name)
                for new_name in new_l:
                    
                    for ontology in ontologies:
                        
                        URI = get_URI_from_name(new_name, ontology)
                        time.sleep(1)
                        
                        if URI is not None:

                            terms.append({
                                'name': new_name,
                                'URI': URI
                            })
                    
                    if URI is None:
                        URI = get_URI_from_name(name)
                        time.sleep(1)

                        terms.append({
                            'name': name,
                            'URI': URI
                        })
                        
                    terms_names.append(new_name)
            

    return terms, terms_names

# %%
avoid_collections = ["Human Cell Atlas"]

cell_types = []
cell_types_names = []

n_experiments = len(answer.json()['experiments'])

for n, experiment in enumerate(answer.json()['experiments']):
    print(f"{n+1}/{n_experiments}")

    # We skip projects from the avoid collections
    if [i for i in experiment["experimentProjects"] if i in avoid_collections]:
        clear_output(wait=True)
        continue
    
    experiment_id = experiment['experimentAccession']
    cell_types_pro, cell_types_names_pro = get_terms_from_project(experiment_id=experiment_id, 
                                                                  name_column='Sample Characteristic[cell type]', 
                                                                  ontology_column='Sample Characteristic Ontology Term[cell type]')
    
    cell_types += cell_types_pro
    cell_types_names += cell_types_names_pro
    
    clear_output(wait=True)

df_SCEA = pd.DataFrame(cell_types)
# Out:
# 181/181

# %%
df_SCEA = df_SCEA.drop_duplicates()

# %%
df_SCEA[df_SCEA.isnull().any(axis=1)].name.tolist()
# Out:
# ['olfactory projection neuron innvervating DC2 glomerulus',
#  'olfactory projection neuron innervating VM2 glomerulus',
#  'multi-lymphoid progenitor',
#  'hematopoietic stem cell and thrombocyte',
#  'neutrophil and myeloid cell',
#  'marrow-derived B cell',
#  'neuronal, glial and vascular cells',
#  'Un-cryopreserved peripheral blood mononuclear cells (PBMCs)',
#  'hematopoietic stem cell and hematopoietic multipotent progenitor cell',
#  'megakaryocyte-erythroid progenitor cell, common myeloid progenitor and granulocyte monocyte progenitor cell',
#  'dormant hematopoietic stem cell',
#  'mixed cell types',
#  'cardiac non-myocyte',
#  'induced neural border stem cell',
#  'embryonic neural border stem cell',
#  'extra thymic aire-expressing cells',
#  'mix of stromal fibroblasts and epithelial tumour cells',
#  'cardiac non-myocyte and cardiomyocyte']

# %%
df_SCEA[df_SCEA['name'] == 'common lymphoid progenitor']
# Out:
# Empty DataFrame
# Columns: [name, URI]
# Index: []

# %%
df_SCEA['name'].tolist()
# Out:
# ['epithelial cell',
#  'not applicable',
#  'protoplast',
#  'hemocyte',
#  'bone marrow cell',
#  'stem cell',
#  'myoepithelial cell of mammary gland',
#  'luminal epithelial cell of mammary gland',
#  'plant protoplast',
#  'neuron',
#  'olfactory projection neuron',
#  'olfactory projection neuron innervating DA1, VA1d or DC3 glomerulus',
#  'astrocyte',
#  'astrocyte',
#  'olfactory projection neuron innvervating DC2 glomerulus',
#  'olfactory projection neuron innervating VM2 glomerulus',
#  'long term hematopoietic stem cell',
#  'hematopoietic multipotent progenitor cell',
#  'short term hematopoietic stem cell',
#  'granulocyte macrophage progenitor',
#  'lymphoid-primed multipotent progenitor',
#  'multi-lymphoid progenitor',
#  'hematopoietic stem cell and thrombocyte',
#  'hematopoietic stem cell',
#  'hematopoietic stem cell',
#  'thrombocyte',
#  'thrombocyte',
#  'thrombocyte',
#  'thymic T cell',
#  'mature T cell',
#  'neutrophil and myeloid cell',
#  'neutrophil',
#  'neutrophil',
#  'myeloid cell',
#  'myeloid cell',
#  'marrow-derived B cell',
#  'spheroplast',
#  'microglial cell',
#  'basophil mast progenitor cell',
#  'granulocyte monocyte progenitor cell',
#  'neural crest cell',
#  'embryonic stem cell',
#  'plasma cell',
#  'CD4-positive helper T cell',
#  'mesenchymal stem cell of the bone marrow',
#  'intestinal epithelial cell',
#  'hepatocyte',
#  'neuronal, glial and vascular cells',
#  'neuronal',
#  'neuronal',
#  'neuronal',
#  'neuronal',
#  'glial',
#  'glial',
#  'glial',
#  'glial',
#  'leukocyte',
#  'keratinocyte',
#  'peripheral blood mononuclear cell',
#  'Un-cryopreserved peripheral blood mononuclear cells (PBMCs)',
#  'oocyte',
#  'zygote',
#  'totipotent stem cell',
#  'morula cell',
#  'blastoderm cell',
#  'group 1 innate lymphoid cell',
#  'natural killer cell',
#  'group 2 innate lymphoid cell',
#  'group 3 innate lymphoid cell',
#  'induced pluripotent stem cell',
#  'circulating tumor cell',
#  'mononuclear cell of bone marrow',
#  'hematopoietic stem cell and hematopoietic multipotent progenitor cell',
#  'megakaryocyte-erythroid progenitor cell, common myeloid progenitor and granulocyte monocyte progenitor cell',
#  'megakaryocyte-erythroid progenitor cell',
#  'common myeloid progenitor',
#  'common myeloid progenitor',
#  'islet of Langerhans',
#  'pre-conventional dendritic cell',
#  'conventional dendritic cell',
#  'embryonic cell',
#  'epiblast cell',
#  'retinal cell',
#  'dormant hematopoietic stem cell',
#  'CD8-Positive T-Lymphocytes',
#  'CD8-Positive T-Lymphocytes',
#  'CD8-Positive T-Lymphocytes',
#  'naive thymus-derived CD4-positive, alpha-beta T cell',
#  'effector memory CD4-positive, alpha-beta T cell',
#  'mixed cell types',
#  'blood cell',
#  'neural crest-derived cell',
#  'medullary thymic epithelial cells',
#  'mesenchymal stem cell of adipose',
#  'CD8-positive, alpha-beta T cell',
#  'retinal cone cell',
#  'retinal ganglion cell',
#  'cardiac non-myocyte',
#  'endothelial cell',
#  'fibroblast',
#  'memory B cell',
#  'naive B cell',
#  'plasmablast',
#  'transitional stage B cell',
#  'adipose tissue derived mesenchymal stem cell',
#  'adipocyte',
#  'preadipocyte',
#  'not applicable',
#  'peptic cell',
#  'stem cell of gastric gland',
#  'induced neural border stem cell',
#  'embryonic neural border stem cell',
#  'macrophage',
#  'fibroblast of dermis',
#  'reticular cell',
#  'reticular cell',
#  'reticular cell',
#  'mouse embryonic stem cell',
#  'aortic endothelial cell',
#  'stromal cell',
#  'neoplastic cell',
#  'neoplastic cell',
#  'dopaminergic neuron',
#  'dopaminergic neuron',
#  'CD4-positive, CD25-positive, alpha-beta regulatory T cell',
#  'CD4-positive, alpha-beta memory T cell',
#  'extra thymic aire-expressing cells',
#  'lung macrophage',
#  'classical monocyte',
#  'mix of stromal fibroblasts and epithelial tumour cells',
#  'cardiac non-myocyte and cardiomyocyte',
#  'cardiomyocyte',
#  'cardiomyocyte']

# %%
from OntologyConversorSCAE import OntologyConversorSCAE

conversor = OntologyConversorSCAE()

# %%
df = df_SCEA

df['name'] = df['name'].apply(conversor.parse_word)
df
# Out:
#                                    name  \
# 0                        EpithelialCell
# 1                         NotApplicable
# 2                            Protoplast
# 4                              Hemocyte
# 6                        BoneMarrowCell
# ..                                  ...
# 243                            Monocyte
# 254   [Fibroblast, EpithelialTumorCell]
# 258  [CardiacNonMyocyte, Cardiomyocyte]
# 260                       Cardiomyocyte
# 262                       Cardiomyocyte
#
#                                             URI
# 0     http://purl.obolibrary.org/obo/CL_0000066
# 1    http://purl.obolibrary.org/obo/NCIT_C48660
# 2     http://purl.obolibrary.org/obo/CL_0000371
# 4     http://purl.obolibrary.org/obo/CL_0000387
# 6     http://purl.obolibrary.org/obo/CL_0002092
# ..                                          ...
# 243   http://purl.obolibrary.org/obo/CL_0000860
# 254                                        None
# 258                                        None
# 260   http://purl.obolibrary.org/obo/CL_0000746
# 262  http://purl.obolibrary.org/obo/NCIT_C13002
#
# [133 rows x 2 columns]

# %% [markdown]
# # HCA cell types

# %%
seed_url = "https://service.azul.data.humancellatlas.org/index/projects?size=999&catalog=dcp1"

# %%
# User-Agent obtenido del recurso del curso.
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)
project_hits = answer.json()["hits"]

# %%
n_projects = len(project_hits)

cell_types = []

for n, hit in enumerate(project_hits):
    entry_id = hit["entryId"]
    seed_url = "https://service.explore.data.humancellatlas.org/repository/projects/" + entry_id
    
    print(n)
    
    for item in hit['cellSuspensions']:
        cell_types += item['selectedCellType']
        
    clear_output(wait=True)
    
cell_types = list(set(cell_types))
# Out:
# 27

# %%
cell_types = [x for x in cell_types if x is not None]
cell_types
# Out:
# ['CD31+ endothelial',
#  'dendritic cell',
#  'T cell',
#  'Epcam+',
#  'CD11b+ Macrophages/monocytes',
#  'inhibitory interneuron',
#  'myofibroblast cell',
#  'stromal cell',
#  'B cell',
#  'effector memory CD8-positive, alpha-beta T cell, terminally differentiated',
#  'monocyte',
#  'endodermal cell',
#  'Plasma cell',
#  'neuron',
#  'CD4+ T cell',
#  'myeloid cell',
#  'peripheral blood mononuclear cell',
#  'CD11c+ DC',
#  'leukocyte',
#  'fibroblast',
#  'epithelial cell of esophagus',
#  'neural cell',
#  'CD8-positive, alpha-beta T cell',
#  'embryonic fibroblast',
#  'endothelial cell',
#  'splenocyte',
#  'pancreatic PP cell',
#  'CD11b+CD11c+DC',
#  'CD45-',
#  'CAFs',
#  'cord blood hematopoietic stem cell',
#  'HLAG+',
#  'epithelial cell',
#  'bone marrow hematopoietic cell',
#  'natural killer cell',
#  'kidney cell',
#  'CD34-positive, CD38-negative hematopoietic stem cell',
#  'innate lymphoid cell',
#  'live',
#  'mononuclear cell']

# %%
cell_types_URIs = list(map(get_URI_from_name, cell_types))
cell_types_URIs
# Out:
# [None,
#  'http://purl.obolibrary.org/obo/CL_0000451',
#  'http://purl.obolibrary.org/obo/CL_0000084',
#  'http://purl.obolibrary.org/obo/OMIT_0033324',
#  None,
#  'http://purl.obolibrary.org/obo/CL_0000498',
#  'http://purl.obolibrary.org/obo/CL_0000186',
#  'http://purl.obolibrary.org/obo/TAO_0009226',
#  'http://purl.obolibrary.org/obo/CL_0000236',
#  'http://purl.obolibrary.org/obo/CL_0001062',
#  'http://purl.obolibrary.org/obo/CL_0000576',
#  'http://purl.obolibrary.org/obo/CL_0000223',
#  'http://purl.obolibrary.org/obo/CL_0000786',
#  'http://purl.obolibrary.org/obo/CL_0000540',
#  None,
#  'http://purl.obolibrary.org/obo/CL_0000763',
#  'http://purl.obolibrary.org/obo/CL_2000001',
#  None,
#  'http://purl.obolibrary.org/obo/CL_0000738',
#  'http://purl.obolibrary.org/obo/CL_0000057',
#  'http://purl.obolibrary.org/obo/CL_0002252',
#  'http://purl.obolibrary.org/obo/CL_0002319',
#  'http://purl.obolibrary.org/obo/CL_0000625',
#  'http://purl.obolibrary.org/obo/BTO_0004725',
#  'http://purl.obolibrary.org/obo/CL_0000115',
#  'http://purl.obolibrary.org/obo/BTO_0001598',
#  'http://purl.obolibrary.org/obo/CL_0002275',
#  None,
#  None,
#  'http://purl.obolibrary.org/obo/NCIT_C75412',
#  'http://purl.obolibrary.org/obo/CL_2000095',
#  'http://purl.obolibrary.org/obo/NCIT_C104317',
#  'http://purl.obolibrary.org/obo/TADS_0000628',
#  'http://purl.obolibrary.org/obo/CL_1001610',
#  'http://purl.obolibrary.org/obo/CL_0000623',
#  'http://purl.obolibrary.org/obo/CL_1000497',
#  'http://purl.obolibrary.org/obo/CL_0001024',
#  'http://purl.obolibrary.org/obo/CL_0001065',
#  'http://www.ebi.ac.uk/swo/maturity/SWO_9000065',
#  'http://purl.obolibrary.org/obo/CL_0000842']

# %%
df_HCA = pd.DataFrame({'name': cell_types, 'URI': cell_types_URIs})
df_HCA[df_HCA.isnull().any(axis=1)].name.tolist()
# Out:
# ['CD31+ endothelial',
#  'CD11b+ Macrophages/monocytes',
#  'CD4+ T cell',
#  'CD11c+ DC',
#  'CD11b+CD11c+DC',
#  'CD45-']

# %%
len(cell_types)
# Out:
# 40

# %%
from OntologyConversorHCA import OntologyConversorHCA

conversor = OntologyConversorHCA()

# %%
cell_types = list(map(conversor.parse_word, cell_types))
cell_types
# Out:
# ['CD31+Endothelial',
#  'DendriticCell',
#  'Tcell',
#  'Epcam+',
#  'CD11b+Macrophages/Monocytes',
#  'InhibitoryInterneuron',
#  'MyofibroblastCell',
#  'StromalCell',
#  'Bcell',
#  'EffectorMemoryCD8+AlphaBetaTCellTerminallyDifferentiated',
#  'Monocyte',
#  'EndodermalCell',
#  'PlasmaCell',
#  'Neuron',
#  'Tcell',
#  'MyeloidCell',
#  'PeripheralBloodMononuclearCell',
#  'CD11c+DC',
#  'Leukocyte',
#  'Fibroblast',
#  'EpithelialCellOfEsophagus',
#  'NeuralCell',
#  'CD8+AlphaBetaTcell',
#  'EmbryonicFibroblast',
#  'EndothelialCell',
#  'Splenocyte',
#  'PancreaticPPCell',
#  'CD11b+CD11c+DC',
#  'CD45-',
#  'Cancer-associatedFibroblasts(CAFs)',
#  'CordBloodHematopoieticStemCell',
#  'HLAG+',
#  'EpithelialCell',
#  'BoneMarrowHematopoieticCell',
#  'NaturalKillerCell',
#  'KidneyCell',
#  'CD34+CD38-HematopoieticStemCell',
#  'InnateLymphoidCell',
#  'Live',
#  'MononuclearCell']

# %%
rows = pd.DataFrame({'name': cell_types, 'URI': cell_types_URIs})
rows
# Out:
#                                                  name  \
# 0                                    CD31+Endothelial
# 1                                       DendriticCell
# 2                                               Tcell
# 3                                              Epcam+
# 4                         CD11b+Macrophages/Monocytes
# 5                               InhibitoryInterneuron
# 6                                   MyofibroblastCell
# 7                                         StromalCell
# 8                                               Bcell
# 9   EffectorMemoryCD8+AlphaBetaTCellTerminallyDiff...
# 10                                           Monocyte
# 11                                     EndodermalCell
# 12                                         PlasmaCell
# 13                                             Neuron
# 14                                              Tcell
# 15                                        MyeloidCell
# 16                     PeripheralBloodMononuclearCell
# 17                                           CD11c+DC
# 18                                          Leukocyte
# 19                                         Fibroblast
# 20                          EpithelialCellOfEsophagus
# 21                                         NeuralCell
# 22                                 CD8+AlphaBetaTcell
# 23                                EmbryonicFibroblast
# 24                                    EndothelialCell
# 25                                         Splenocyte
# 26                                   PancreaticPPCell
# 27                                     CD11b+CD11c+DC
# 28                                              CD45-
# 29                 Cancer-associatedFibroblasts(CAFs)
# 30                     CordBloodHematopoieticStemCell
# 31                                              HLAG+
# 32                                     EpithelialCell
# 33                        BoneMarrowHematopoieticCell
# 34                                  NaturalKillerCell
# 35                                         KidneyCell
# 36                    CD34+CD38-HematopoieticStemCell
# 37                                 InnateLymphoidCell
# 38                                               Live
# 39                                    MononuclearCell
#
#                                               URI
# 0                                            None
# 1       http://purl.obolibrary.org/obo/CL_0000451
# 2       http://purl.obolibrary.org/obo/CL_0000084
# 3     http://purl.obolibrary.org/obo/OMIT_0033324
# 4                                            None
# 5       http://purl.obolibrary.org/obo/CL_0000498
# 6       http://purl.obolibrary.org/obo/CL_0000186
# 7      http://purl.obolibrary.org/obo/TAO_0009226
# 8       http://purl.obolibrary.org/obo/CL_0000236
# 9       http://purl.obolibrary.org/obo/CL_0001062
# 10      http://purl.obolibrary.org/obo/CL_0000576
# 11      http://purl.obolibrary.org/obo/CL_0000223
# 12      http://purl.obolibrary.org/obo/CL_0000786
# 13      http://purl.obolibrary.org/obo/CL_0000540
# 14                                           None
# 15      http://purl.obolibrary.org/obo/CL_0000763
# 16      http://purl.obolibrary.org/obo/CL_2000001
# 17                                           None
# 18      http://purl.obolibrary.org/obo/CL_0000738
# 19      http://purl.obolibrary.org/obo/CL_0000057
# 20      http://purl.obolibrary.org/obo/CL_0002252
# 21      http://purl.obolibrary.org/obo/CL_0002319
# 22      http://purl.obolibrary.org/obo/CL_0000625
# 23     http://purl.obolibrary.org/obo/BTO_0004725
# 24      http://purl.obolibrary.org/obo/CL_0000115
# 25     http://purl.obolibrary.org/obo/BTO_0001598
# 26      http://purl.obolibrary.org/obo/CL_0002275
# 27                                           None
# 28                                           None
# 29     http://purl.obolibrary.org/obo/NCIT_C75412
# 30      http://purl.obolibrary.org/obo/CL_2000095
# 31    http://purl.obolibrary.org/obo/NCIT_C104317
# 32    http://purl.obolibrary.org/obo/TADS_0000628
# 33      http://purl.obolibrary.org/obo/CL_1001610
# 34      http://purl.obolibrary.org/obo/CL_0000623
# 35      http://purl.obolibrary.org/obo/CL_1000497
# 36      http://purl.obolibrary.org/obo/CL_0001024
# 37      http://purl.obolibrary.org/obo/CL_0001065
# 38  http://www.ebi.ac.uk/swo/maturity/SWO_9000065
# 39      http://purl.obolibrary.org/obo/CL_0000842

# %%
df = df.append(rows, ignore_index=True).dropna().drop_duplicates()
df
# Out:
#                                 name  \
# 0                     EpithelialCell
# 1                      NotApplicable
# 2                         Protoplast
# 3                           Hemocyte
# 4                     BoneMarrowCell
# ..                               ...
# 144                       KidneyCell
# 145  CD34+CD38-HematopoieticStemCell
# 146               InnateLymphoidCell
# 147                             Live
# 148                  MononuclearCell
#
#                                                URI
# 0        http://purl.obolibrary.org/obo/CL_0000066
# 1       http://purl.obolibrary.org/obo/NCIT_C48660
# 2        http://purl.obolibrary.org/obo/CL_0000371
# 3        http://purl.obolibrary.org/obo/CL_0000387
# 4        http://purl.obolibrary.org/obo/CL_0002092
# ..                                             ...
# 144      http://purl.obolibrary.org/obo/CL_1000497
# 145      http://purl.obolibrary.org/obo/CL_0001024
# 146      http://purl.obolibrary.org/obo/CL_0001065
# 147  http://www.ebi.ac.uk/swo/maturity/SWO_9000065
# 148      http://purl.obolibrary.org/obo/CL_0000842
#
# [139 rows x 2 columns]

# %%
df.to_csv('../SingleCell-Files/cell_types_ontology.csv', index=False, header=False, sep='\t')

# %% [markdown]
# # Test

# %%
experiment_id = "E-MTAB-8810"
experiment_metadata = f"https://www.ebi.ac.uk/gxa/sc/experiment/{experiment_id}/download?fileType=experiment-design&accessKey="

df = pd.read_csv(experiment_metadata, sep='\t', low_memory=False)
df
# Out:
#                              Assay Sample Characteristic[organism]  \
# 0      ERR3971663-AAACCTGAGAAAGTGG                    Mus musculus
# 1      ERR3971663-AAACCTGAGCCGGTAA                    Mus musculus
# 2      ERR3971663-AAACCTGAGGCAGGTT                    Mus musculus
# 3      ERR3971663-AAACCTGCAATAAGCA                    Mus musculus
# 4      ERR3971663-AAACCTGCAATAGAGT                    Mus musculus
# ...                            ...                             ...
# 39681  ERR3971670-TTTGTCAGTTGTCGCG                    Mus musculus
# 39682  ERR3971670-TTTGTCATCGAGGTAG                    Mus musculus
# 39683  ERR3971670-TTTGTCATCGGTCTAA                    Mus musculus
# 39684  ERR3971670-TTTGTCATCTTCCTTC                    Mus musculus
# 39685  ERR3971670-TTTTTTTTTTTTTTTT                    Mus musculus
#
#         Sample Characteristic Ontology Term[organism]  \
# 0      http://purl.obolibrary.org/obo/NCBITaxon_10090
# 1      http://purl.obolibrary.org/obo/NCBITaxon_10090
# 2      http://purl.obolibrary.org/obo/NCBITaxon_10090
# 3      http://purl.obolibrary.org/obo/NCBITaxon_10090
# 4      http://purl.obolibrary.org/obo/NCBITaxon_10090
# ...                                               ...
# 39681  http://purl.obolibrary.org/obo/NCBITaxon_10090
# 39682  http://purl.obolibrary.org/obo/NCBITaxon_10090
# 39683  http://purl.obolibrary.org/obo/NCBITaxon_10090
# 39684  http://purl.obolibrary.org/obo/NCBITaxon_10090
# 39685  http://purl.obolibrary.org/obo/NCBITaxon_10090
#
#       Sample Characteristic[strain]  \
# 0                          C57BL/6J
# 1                          C57BL/6J
# 2                          C57BL/6J
# 3                          C57BL/6J
# 4                          C57BL/6J
# ...                             ...
# 39681                      C57BL/6J
# 39682                      C57BL/6J
# 39683                      C57BL/6J
# 39684                      C57BL/6J
# 39685                      C57BL/6J
#
#       Sample Characteristic Ontology Term[strain] Sample Characteristic[age]  \
# 0            http://www.ebi.ac.uk/efo/EFO_0000606                    10 week
# 1            http://www.ebi.ac.uk/efo/EFO_0000606                    10 week
# 2            http://www.ebi.ac.uk/efo/EFO_0000606                    10 week
# 3            http://www.ebi.ac.uk/efo/EFO_0000606                    10 week
# 4            http://www.ebi.ac.uk/efo/EFO_0000606                    10 week
# ...                                           ...                        ...
# 39681        http://www.ebi.ac.uk/efo/EFO_0000606                    10 week
# 39682        http://www.ebi.ac.uk/efo/EFO_0000606                    10 week
# 39683        http://www.ebi.ac.uk/efo/EFO_0000606                    10 week
# 39684        http://www.ebi.ac.uk/efo/EFO_0000606                    10 week
# 39685        http://www.ebi.ac.uk/efo/EFO_0000606                    10 week
#
#        Sample Characteristic Ontology Term[age]  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 39681                                       NaN
# 39682                                       NaN
# 39683                                       NaN
# 39684                                       NaN
# 39685                                       NaN
#
#       Sample Characteristic[developmental stage]  \
# 0                                          adult
# 1                                          adult
# 2                                          adult
# 3                                          adult
# 4                                          adult
# ...                                          ...
# 39681                                      adult
# 39682                                      adult
# 39683                                      adult
# 39684                                      adult
# 39685                                      adult
#
#       Sample Characteristic Ontology Term[developmental stage]  \
# 0                   http://www.ebi.ac.uk/efo/EFO_0001272
# 1                   http://www.ebi.ac.uk/efo/EFO_0001272
# 2                   http://www.ebi.ac.uk/efo/EFO_0001272
# 3                   http://www.ebi.ac.uk/efo/EFO_0001272
# 4                   http://www.ebi.ac.uk/efo/EFO_0001272
# ...                                                  ...
# 39681               http://www.ebi.ac.uk/efo/EFO_0001272
# 39682               http://www.ebi.ac.uk/efo/EFO_0001272
# 39683               http://www.ebi.ac.uk/efo/EFO_0001272
# 39684               http://www.ebi.ac.uk/efo/EFO_0001272
# 39685               http://www.ebi.ac.uk/efo/EFO_0001272
#
#       Sample Characteristic[sex]  ... Sample Characteristic[genotype]  \
# 0                          mixed  ...              wild type genotype
# 1                          mixed  ...              wild type genotype
# 2                          mixed  ...              wild type genotype
# 3                          mixed  ...              wild type genotype
# 4                          mixed  ...              wild type genotype
# ...                          ...  ...                             ...
# 39681                      mixed  ...              wild type genotype
# 39682                      mixed  ...              wild type genotype
# 39683                      mixed  ...              wild type genotype
# 39684                      mixed  ...              wild type genotype
# 39685                      mixed  ...              wild type genotype
#
#       Sample Characteristic Ontology Term[genotype]  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 39681                                           NaN
# 39682                                           NaN
# 39683                                           NaN
# 39684                                           NaN
# 39685                                           NaN
#
#        Sample Characteristic[organism part]  \
# 0                                     heart
# 1                                     heart
# 2                                     heart
# 3                                     heart
# 4                                     heart
# ...                                     ...
# 39681                                 heart
# 39682                                 heart
# 39683                                 heart
# 39684                                 heart
# 39685                                 heart
#
#       Sample Characteristic Ontology Term[organism part]  \
# 0          http://purl.obolibrary.org/obo/UBERON_0000948
# 1          http://purl.obolibrary.org/obo/UBERON_0000948
# 2          http://purl.obolibrary.org/obo/UBERON_0000948
# 3          http://purl.obolibrary.org/obo/UBERON_0000948
# 4          http://purl.obolibrary.org/obo/UBERON_0000948
# ...                                                  ...
# 39681      http://purl.obolibrary.org/obo/UBERON_0000948
# 39682      http://purl.obolibrary.org/obo/UBERON_0000948
# 39683      http://purl.obolibrary.org/obo/UBERON_0000948
# 39684      http://purl.obolibrary.org/obo/UBERON_0000948
# 39685      http://purl.obolibrary.org/obo/UBERON_0000948
#
#             Sample Characteristic[cell type]  \
# 0      cardiac non-myocyte and cardiomyocyte
# 1      cardiac non-myocyte and cardiomyocyte
# 2      cardiac non-myocyte and cardiomyocyte
# 3      cardiac non-myocyte and cardiomyocyte
# 4      cardiac non-myocyte and cardiomyocyte
# ...                                      ...
# 39681  cardiac non-myocyte and cardiomyocyte
# 39682  cardiac non-myocyte and cardiomyocyte
# 39683  cardiac non-myocyte and cardiomyocyte
# 39684  cardiac non-myocyte and cardiomyocyte
# 39685  cardiac non-myocyte and cardiomyocyte
#
#       Sample Characteristic Ontology Term[cell type]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 39681                                            NaN
# 39682                                            NaN
# 39683                                            NaN
# 39684                                            NaN
# 39685                                            NaN
#
#                                   Factor Value[compound]  \
# 0      angiotensin II 1.5 milligram per kilogram per day
# 1      angiotensin II 1.5 milligram per kilogram per day
# 2      angiotensin II 1.5 milligram per kilogram per day
# 3      angiotensin II 1.5 milligram per kilogram per day
# 4      angiotensin II 1.5 milligram per kilogram per day
# ...                                                  ...
# 39681                                               none
# 39682                                               none
# 39683                                               none
# 39684                                               none
# 39685                                               none
#
#              Factor Value Ontology Term[compound] Factor Value[dose]  \
# 0      http://purl.obolibrary.org/obo/CHEBI_48432                NaN
# 1      http://purl.obolibrary.org/obo/CHEBI_48432                NaN
# 2      http://purl.obolibrary.org/obo/CHEBI_48432                NaN
# 3      http://purl.obolibrary.org/obo/CHEBI_48432                NaN
# 4      http://purl.obolibrary.org/obo/CHEBI_48432                NaN
# ...                                           ...                ...
# 39681        http://www.ebi.ac.uk/efo/EFO_0001461                NaN
# 39682        http://www.ebi.ac.uk/efo/EFO_0001461                NaN
# 39683        http://www.ebi.ac.uk/efo/EFO_0001461                NaN
# 39684        http://www.ebi.ac.uk/efo/EFO_0001461                NaN
# 39685        http://www.ebi.ac.uk/efo/EFO_0001461                NaN
#
#        Factor Value Ontology Term[dose]
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 39681                               NaN
# 39682                               NaN
# 39683                               NaN
# 39684                               NaN
# 39685                               NaN
#
# [39686 rows x 21 columns]

# %%
if 'Sample Characteristic[cell type]' in df.columns:
    cell_type_names = df['Sample Characteristic[cell type]'].unique()
    cell_type_URIs = df['Sample Characteristic Ontology Term[cell type]'].unique()

    new_l = []
    
    for x in cell_type_names:
        if " and " in x:
            print(x.split(" and "))
            new_l += x.split(" and ")
        else:
            new_l += [x]

    cell_type_names = new_l
    
    cell_type_URIs = list(cell_type_URIs)
    cell_type_URIs += [None] * (len(cell_type_names) - len(cell_type_URIs))
    
    for name, URI in zip(cell_type_names, cell_type_URIs):
        
        if URI is None or str(URI) == 'nan':
            URI = get_URI_from_name(name)
        print(name, URI)
# Out:
# ['cardiac non-myocyte', 'cardiomyocyte']
# cardiac non-myocyte None
# cardiomyocyte http://purl.obolibrary.org/obo/OARCS_0000013

# %%
get_URI_from_name('neoplastic cell')

# %%
l = ['cardiac non-myocyte and cardiomyocyte']
new_l = []
for x in l:
    if " and " in x:
        new_l += x.split(" and ")

new_l

# %%
import re

string = 'megakaryocyte-erythroid progenitor cell'
re.split(' and |, ', string)
# Out:
# ['megakaryocyte-erythroid progenitor cell']

# %%
get_terms_from_project('E-GEOD-100618', name_column='Sample Characteristic[cell type]', 
                                                                  ontology_column='Sample Characteristic Ontology Term[cell type]')
# Out:
# granulocyte macrophage progenitor
# lymphoid-primed multipotent progenitor
# multi-lymphoid progenitor
# ([{'name': 'granulocyte macrophage progenitor',
#    'URI': 'http://purl.obolibrary.org/obo/CL_0000557'},
#   {'name': 'lymphoid-primed multipotent progenitor',
#    'URI': 'http://purl.obolibrary.org/obo/CL_0000936'},
#   {'name': 'multi-lymphoid progenitor', 'URI': None},
#   {'name': 'multi-lymphoid progenitor', 'URI': None}],
#  ['granulocyte macrophage progenitor',
#   'lymphoid-primed multipotent progenitor',
#   'multi-lymphoid progenitor'])
