# %% [markdown]
# # Read data from HCA API

# %%
import requests
import json
import sys

# %% [markdown]
# ### API URL Request
#
# The data base has 800 samples, we indicate `size=801` to get them all.

# %%
seed_url = "https://service.explore.data.humancellatlas.org/repository/samples?filters=%7B%7D&size=801"

# %% [markdown]
# It is necessary to indicate the user agent in the request so the server do not detect we are web scraping.

# %%
# User-Agent obtenido del recurso del curso.
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %% [markdown]
# We do the request and get all the data in json format

# %%
answer = requests.get(seed_url, headers=headers)

# %% [markdown]
# If we take a look into the json, we can see that the data is in the object "hits".

# %%
# print(json.dumps(answer.json(), indent=2, sort_keys=True))

# %%
hits = answer.json()['hits']
print(len(hits))
# Out:
# 800

# %% [markdown]
# We save the hits in this raw json format.

# %%
with open('../SingleCell-Files/hits_raw.json', 'w') as outfile:
    json.dump(hits, outfile)

# %% [markdown]
# ### Format data
#
# For a more in-depth analysis of the data, as well as the formatting to the ontology format, see HCA_conversor notebook.

# %%
from OntologyConversor import format_HCD

# %%
print(json.dumps(hits[555], indent=2))
# Out:
# {
#   "protocols": [
#     {
#       "libraryConstructionApproach": [
#         "10X v2 sequencing",
#         null
#       ],
#       "instrumentManufacturerModel": [
#         "Illumina HiSeq 4000",
#         null
#       ],
#       "pairedEnd": [
#         false,
#         null
#       ],
#       "workflow": [
#         "optimus_v1.3.5",
#         null
#       ],
#       "assayType": [
#         null
#       ]
#     }
#   ],
#   "entryId": "a57ebdf9-1225-47a8-81cc-384ac452d83d",
#   "projects": [
#     {
#       "projectTitle": [
#         "Ischaemic sensitivity of human tissue by single cell RNA seq"
#       ],
#       "projectShortname": [
#         "TissueStability"
#       ],
#       "laboratory": [
#         "CGaP",
#         "Cambridge Biorepository for Translational Medicine",
#         "Human Cell Atlas (Mike Stubbington)",
#         "Human Cell Atlas (Sarah Teichmann)",
#         "Human Cell Atlas Data Coordination Platform",
#         "Human Cell Atlas UK",
#         "Molecular Immunity Unit, Department of Medicine",
#         "Oliver Stegle Group",
#         "Rebecca Fitzgerald",
#         "Sarah Teichmann Lab"
#       ]
#     }
#   ],
#   "samples": [
#     {
#       "sampleEntityType": "specimens",
#       "effectiveOrgan": "spleen",
#       "id": "A8-Spl-0-TL-12h-1",
#       "organ": "spleen",
#       "organPart": [
#         null
#       ],
#       "disease": [
#         null
#       ],
#       "preservationMethod": "hypothermic preservation media at 2-8C",
#       "source": "specimen_from_organism"
#     }
#   ],
#   "specimens": [
#     {
#       "id": [
#         "A8-Spl-0-TL-12h-1"
#       ],
#       "organ": [
#         "spleen"
#       ],
#       "organPart": [
#         null
#       ],
#       "disease": [
#         null
#       ],
#       "preservationMethod": [
#         "hypothermic preservation media at 2-8C"
#       ],
#       "source": [
#         "specimen_from_organism"
#       ]
#     }
#   ],
#   "cellLines": [],
#   "donorOrganisms": [
#     {
#       "id": [
#         "CBTM-302C"
#       ],
#       "donorCount": 1,
#       "genusSpecies": [
#         "Homo sapiens"
#       ],
#       "organismAge": [
#         "40-45"
#       ],
#       "organismAgeUnit": [
#         "year"
#       ],
#       "organismAgeRange": [
#         {
#           "gte": 1261440000.0,
#           "lte": 1419120000.0
#         }
#       ],
#       "biologicalSex": [
#         "male"
#       ],
#       "disease": [
#         "normal"
#       ]
#     }
#   ],
#   "organoids": [],
#   "cellSuspensions": [
#     {
#       "organ": [
#         "spleen"
#       ],
#       "organPart": [
#         null
#       ],
#       "selectedCellType": [
#         "splenocyte"
#       ],
#       "totalCells": 3136
#     }
#   ],
#   "fileTypeSummaries": [
#     {
#       "fileType": "fastq.gz",
#       "count": 3,
#       "totalSize": 20609182632
#     },
#     {
#       "fileType": "csv.gz",
#       "count": 2,
#       "totalSize": 32250419
#     },
#     {
#       "fileType": "npz",
#       "count": 1,
#       "totalSize": 13889179
#     },
#     {
#       "fileType": "npy",
#       "count": 2,
#       "totalSize": 22165632
#     },
#     {
#       "fileType": "bam",
#       "count": 1,
#       "totalSize": 19107936214
#     },
#     {
#       "fileType": "matrix",
#       "count": 1,
#       "totalSize": 148
#     },
#     {
#       "fileType": "csv",
#       "count": 1,
#       "totalSize": 17256070
#     }
#   ]
# }

# %%
print(json.dumps(format_HCD(hits[555]), indent=2))
# Out:
# {
#   "ID": "A8-Spl-0-TL-12h-1",
#   "ObjectProperties": {
#     "SR.hasAnalysisProtocol": [
#       "Optimus_v1.3.5",
#       null
#     ],
#     "SR.hasCellLineType": null,
#     "SR.hasDiseaseStatus": [
#       "Normal"
#     ],
#     "SR.hasGenusSpecie": [
#       "HomoSapiens"
#     ],
#     "SR.hasInstrument": [
#       "IlluminaHiSeq4000",
#       null
#     ],
#     "SR.hasLibrary": [
#       "10Xv2Sequencing",
#       null
#     ],
#     "SR.hasObjectOfStudy": [
#       "Spleen"
#     ],
#     "SR.hasPreservation": [
#       "HypothermicPreservationMediaAt2-8C"
#     ],
#     "SR.hasSampleType": "Specimens",
#     "SR.hasSelectedCellType": [
#       "Splenocyte"
#     ]
#   },
#   "DataProperties": {
#     "hasAgeUnit": [
#       "year"
#     ],
#     "hasBiologicalSex": [
#       "male"
#     ],
#     "hasFileFormat": [
#       "fastq.gz",
#       "csv.gz",
#       "npz",
#       "npy",
#       "bam",
#       "matrix",
#       "csv"
#     ],
#     "hasFileType": null,
#     "hasLaboratory": [
#       "CGaP",
#       "CambridgeBiorepositoryForTranslationalMedicine",
#       "HumanCellAtlas(MikeStubbington)",
#       "HumanCellAtlas(SarahTeichmann)",
#       "HumanCellAtlasDataCoordinationPlatform",
#       "HumanCellAtlasUK",
#       "MolecularImmunityUnit,DepartmentOfMedicine",
#       "OliverStegleGroup",
#       "RebeccaFitzgerald",
#       "SarahTeichmannLab"
#     ],
#     "hasMaxAge": "45",
#     "hasMinAge": "40",
#     "hasModelOrgan": false,
#     "hasProjectShortName": [
#       "TissueStability"
#     ],
#     "hasProjectTitle": [
#       "Ischaemic sensitivity of human tissue by single cell RNA seq"
#     ],
#     "hasTotalCellCounts": 3136,
#     "hasTotalDonorCounts": 1,
#     "hasTotalSize": 39802680294,
#     "isPairedEnd": [
#       false,
#       null
#     ],
#     "isPartOfCollection": "HumanCellAtlas",
#     "isPartOfRepository": "HumanCellAtlas"
#   }
# }

# %%
hits_processed = list(map(format_HCD, hits))
#print(list(hits_processed))
print(json.dumps(hits_processed, indent=2))
# Out:
# [
#   {
#     "ID": "1104_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD4+TCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 8206104986,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1104_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD4+TCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 5893786371,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1107_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD8-positive_Alpha-betaTCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 4712170205,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1107_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD8-positive_Alpha-betaTCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 5825947527,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1108_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "InnateLymphoidCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 6356622348,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1108_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "InnateLymphoidCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 7468460874,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1110_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "BCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 8753121196,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1110_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "BCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 1251172890,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1112_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11b+CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 10955528686,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1113_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11b+CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 7271723177,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1115_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 4299389989,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1115_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 5317596803,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1117_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11b+Macrophages/Monocytes"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 510451750,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1117_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11b+Macrophages/Monocytes"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 4602641978,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1118_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD4+TCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 4403772209,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1118_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD4+TCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 4943221163,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1120_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD8-positive_Alpha-betaTCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 5033279433,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1120_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD8-positive_Alpha-betaTCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 5395436896,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1121_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD8-positive_Alpha-betaTCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 7950754783,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1122_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "InnateLymphoidCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 4680332189,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1122_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "InnateLymphoidCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 6828373714,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1124_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "BCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 4207837299,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1125_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "BCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 6508691637,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1126_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11b+CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 4700223101,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1127_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11b+CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 182,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 10135696042,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1129_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 2686559240,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1129_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 3473758230,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1131_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11b+Macrophages/Monocytes"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 4907445918,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1131_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11b+Macrophages/Monocytes"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 91,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 4554885756,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1134_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD4+TCell",
#         "CD8-positive_Alpha-betaTCell",
#         "InnateLymphoidCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 273,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 11897459672,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1134_T",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Tumor"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD4+TCell",
#         "CD8-positive_Alpha-betaTCell",
#         "InnateLymphoidCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "hasTotalCellCounts": 273,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 23178909687,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "1135_LN",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SR.hasGenusSpecie": [
#         "MusMusculus"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "LymphNode"
#       ],
#       "SR.hasPreservation": [
#         null
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "CD11b+CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         "week"
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "hasMaxAge": "12",
#       "hasMinAge": "6",
#       "hasModelOrgan": false,
# ...
#       ],
#       "hasMaxAge": null,
#       "hasMinAge": null,
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Fetal/Maternal Interface"
#       ],
#       "hasProjectTitle": [
#         "Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics"
#       ],
#       "hasTotalCellCounts": 0,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 228470145402,
#       "isPairedEnd": [
#         false,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "placenta_sample_81",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         "Optimus_v1.3.1",
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "OrofaciodigitalSyndromeVIII"
#       ],
#       "SR.hasGenusSpecie": [
#         "HomoSapiens"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq4000",
#         null
#       ],
#       "SR.hasLibrary": [
#         "10Xv2Sequencing",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Placenta"
#       ],
#       "SR.hasPreservation": [
#         "Fresh"
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "Live"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         null
#       ],
#       "hasBiologicalSex": [
#         "male"
#       ],
#       "hasFileFormat": [
#         "fastq.gz",
#         "unknown",
#         "bam",
#         "matrix",
#         "csv"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "ArrayExpress",
#         "CentreForTrophoblastResearch",
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine"
#       ],
#       "hasMaxAge": null,
#       "hasMinAge": null,
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Fetal/Maternal Interface"
#       ],
#       "hasProjectTitle": [
#         "Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics"
#       ],
#       "hasTotalCellCounts": 0,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 66054615066,
#       "isPairedEnd": [
#         false,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "placenta_sample_91",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         "Optimus_v1.3.1",
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "Normal"
#       ],
#       "SR.hasGenusSpecie": [
#         "HomoSapiens"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq4000",
#         null
#       ],
#       "SR.hasLibrary": [
#         "10Xv2Sequencing",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Placenta"
#       ],
#       "SR.hasPreservation": [
#         "Fresh"
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "Live"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         null
#       ],
#       "hasBiologicalSex": [
#         "male"
#       ],
#       "hasFileFormat": [
#         "fastq.gz",
#         "unknown",
#         "bam",
#         "matrix",
#         "csv"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "ArrayExpress",
#         "CentreForTrophoblastResearch",
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine"
#       ],
#       "hasMaxAge": null,
#       "hasMinAge": null,
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Fetal/Maternal Interface"
#       ],
#       "hasProjectTitle": [
#         "Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics"
#       ],
#       "hasTotalCellCounts": 0,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 67608231405,
#       "isPairedEnd": [
#         false,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "specimen_control_1",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "AcousticNeuroma",
#         "KidneyCancer",
#         "ObstructiveSleepApneaSyndrome"
#       ],
#       "SR.hasGenusSpecie": [
#         "HomoSapiens"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Cortex"
#       ],
#       "SR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         null
#       ],
#       "hasBiologicalSex": [
#         "male"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "hasMaxAge": "54",
#       "hasMinAge": "54",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "hasTotalCellCounts": 5000,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 34031145047,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "specimen_control_2",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "AcuteKidneyTubularNecrosis",
#         "BenignProstaticHyperplasia",
#         "EssentialHypertension",
#         "KidneyCancer",
#         "PericardialEffusion"
#       ],
#       "SR.hasGenusSpecie": [
#         "HomoSapiens"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Cortex"
#       ],
#       "SR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         null
#       ],
#       "hasBiologicalSex": [
#         "male"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "hasMaxAge": "62",
#       "hasMinAge": "62",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "hasTotalCellCounts": 5000,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 23557286884,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "specimen_control_3",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "LymeDisease",
#         "AnxietyDisorder",
#         "Arthritis",
#         "DepressiveDisorder",
#         "Diverticulitis",
#         "GastroesophagealRefluxDisease",
#         "KidneyCancer"
#       ],
#       "SR.hasGenusSpecie": [
#         "HomoSapiens"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Cortex"
#       ],
#       "SR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         null
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "hasMaxAge": "61",
#       "hasMinAge": "61",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "hasTotalCellCounts": 5000,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 28937523068,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "specimen_diabetes_1",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "AdrenalCortexAdenoma",
#         "Arthritis",
#         "GastroesophagealRefluxDisease",
#         "HereditaryHemochromatosis",
#         "HiatusHernia",
#         "IrritableBowelSyndrome",
#         "KidneyCancer",
#         "NonAlcoholicFattyLiverDisease",
#         "ObstructiveSleepApneaSyndrome",
#         "Type2DiabetesMellitus",
#         "VentricularTachycardia"
#       ],
#       "SR.hasGenusSpecie": [
#         "HomoSapiens"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Cortex"
#       ],
#       "SR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         null
#       ],
#       "hasBiologicalSex": [
#         "male"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "hasMaxAge": "74",
#       "hasMinAge": "74",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "hasTotalCellCounts": 5000,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 31593866919,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "specimen_diabetes_2",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "EnterococcusFaecalisInfection",
#         "EssentialHypertension",
#         "KidneyCancer",
#         "ProstateCancer",
#         "PureAutonomicFailure",
#         "SyndromicDyslipidemia",
#         "Type2DiabetesMellitus"
#       ],
#       "SR.hasGenusSpecie": [
#         "HomoSapiens"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Cortex"
#       ],
#       "SR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         null
#       ],
#       "hasBiologicalSex": [
#         "male"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "hasMaxAge": "52",
#       "hasMinAge": "52",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "hasTotalCellCounts": 5000,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 24771459847,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   },
#   {
#     "ID": "specimen_diabetes_3",
#     "ObjectProperties": {
#       "SR.hasAnalysisProtocol": [
#         null
#       ],
#       "SR.hasCellLineType": null,
#       "SR.hasDiseaseStatus": [
#         "GastroesophagealRefluxDisease",
#         "Hyperlipidemia",
#         "KidneyCancer",
#         "Type2DiabetesMellitus"
#       ],
#       "SR.hasGenusSpecie": [
#         "HomoSapiens"
#       ],
#       "SR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SR.hasObjectOfStudy": [
#         "Cortex"
#       ],
#       "SR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SR.hasSampleType": "Specimens",
#       "SR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "hasAgeUnit": [
#         null
#       ],
#       "hasBiologicalSex": [
#         "female"
#       ],
#       "hasFileFormat": [
#         "fastq.gz"
#       ],
#       "hasFileType": null,
#       "hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "hasMaxAge": "57",
#       "hasMinAge": "57",
#       "hasModelOrgan": false,
#       "hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "hasTotalCellCounts": 5000,
#       "hasTotalDonorCounts": 1,
#       "hasTotalSize": 31037810836,
#       "isPairedEnd": [
#         true,
#         null
#       ],
#       "isPartOfCollection": "HumanCellAtlas",
#       "isPartOfRepository": "HumanCellAtlas"
#     }
#   }
# ]

# %%
json_processed = {}
json_processed['hits'] = hits_processed

# print(json.dumps(json_processed, indent=2, sort_keys=True))

# %%
with open('../SingleCell-Files/hits_processed.json', 'w') as outfile:
    json.dump(json_processed, outfile)
