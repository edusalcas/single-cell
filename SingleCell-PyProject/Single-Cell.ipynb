# %% [markdown]
# # Read samples from HCA API

# %%
import requests
import json
import sys

# %% [markdown]
# ### API URL Request
#
# The data base has 800 samples, we indicate `size=801` to get them all.

# %%
seed_url = "https://service.explore.data.humancellatlas.org/repository/samples?filters=%7B%7D&size=801"

# %% [markdown]
# It is necessary to indicate the user agent in the request so the server do not detect we are web scraping.

# %%
# User-Agent obtenido del recurso del curso.
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %% [markdown]
# We do the request and get all the data in json format

# %%
answer = requests.get(seed_url, headers=headers)

# %% [markdown]
# If we take a look into the json, we can see that the data is in the object "hits".

# %%
# print(json.dumps(answer.json(), indent=2, sort_keys=True))

# %%
hits = answer.json()['hits']
print(len(hits))
# Out:
# 800

# %% [markdown]
# We save the hits in this raw json format.

# %%
with open('../SingleCell-Files/hits_raw.json', 'w') as outfile:
    json.dump(hits, outfile)

# %% [markdown]
# ### Format data
#
# For a more in-depth analysis of the data, as well as the formatting to the ontology format, see HCA_conversor notebook.

# %%
from OntologyCreator import OntologyCreator

ont_creator = OntologyCreator()

# %%
# print(json.dumps(hits[555], indent=2))

# %%
# print(json.dumps(ont_creator.create_hca_individual(hits[555]), indent=2))

# %%
hits_processed = list(map(ont_creator.create_hca_specimen, hits))

print(json.dumps(hits_processed, indent=2))
# Out:
# [
#   {
#     "ID": "SPECIMEN_ID_0",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD4+TCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 7825.95156288147,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1104_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_1",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD4+TCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 5620.752688407898,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1104_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_2",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD8-positive_Alpha-betaTCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 4493.875699043274,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1107_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_3",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD8-positive_Alpha-betaTCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 5556.056525230408,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1107_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_4",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "InnateLymphoidCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 6062.147472381592,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1108_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_5",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "InnateLymphoidCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 7122.479318618774,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1108_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_6",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "BCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 8347.626873016357,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1110_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_7",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "BCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 1193.2114505767822,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1110_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_8",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11b+CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 10448.006330490112,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1112_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_9",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11b+CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 6934.8556299209595,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1113_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_10",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 4100.21780872345,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1115_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_11",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 5071.255496025085,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1115_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_12",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11b+Macrophages/Monocytes"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 486.804723739624,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1117_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_13",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11b+Macrophages/Monocytes"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 4389.42144203186,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1117_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_14",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD4+TCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 4199.7644510269165,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1118_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_15",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD4+TCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 4714.223063468933,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1118_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_16",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD8-positive_Alpha-betaTCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 4800.109322547913,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1120_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_17",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD8-positive_Alpha-betaTCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 5145.489593505859,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1120_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_18",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD8-positive_Alpha-betaTCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 7582.430632591248,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1121_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_19",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "InnateLymphoidCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 4463.512600898743,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1122_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_20",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "InnateLymphoidCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 6512.044633865356,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1122_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_21",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "BCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 4012.9063596725464,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1124_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_22",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "BCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 6207.172047615051,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1125_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_23",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11b+CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 4482.48205280304,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1126_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_24",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11b+CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 182,
#       "SPR.hasTotalSizeOfFilesInMB": 9666.152994155884,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1127_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_25",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 2562.1025466918945,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1129_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_26",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11c+DC"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 3312.834005355835,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1129_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_27",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11b+Macrophages/Monocytes"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 4680.105131149292,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1131_LN"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_28",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Tumor"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD11b+Macrophages/Monocytes"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 91,
#       "SPR.hasTotalSizeOfFilesInMB": 4343.877559661865,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine",
#         "MRCCancerUnit",
#         "SarahTeichmann"
#       ],
#       "SPR.hasProjectShortName": [
#         "Mouse Melanoma"
#       ],
#       "SPR.hasProjectTitle": [
#         "Melanoma infiltration of stromal and immune cells"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "1131_T"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_29",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "MusMusculus"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Melanoma"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "Smart-seq2",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "LymphNode"
#       ],
#       "SPR.hasPreservation": [
#         null
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "CD4+TCell",
#         "CD8-positive_Alpha-betaTCell",
#         "InnateLymphoidCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         "week"
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 12,
#       "SPR.hasMinAge": 6,
#       "SPR.hasTotalCellCount": 273,
#       "SPR.hasTotalSizeOfFilesInMB": 11346.301719665527,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "HumanCellAtlasDataCoordinationPlatform",
# ...
#         "OrofaciodigitalSyndromeVIII"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq4000",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "10Xv2Sequencing",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Placenta"
#       ],
#       "SPR.hasPreservation": [
#         "Fresh"
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "Live"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         null
#       ],
#       "SPR.hasBiologicalSex": [
#         "male"
#       ],
#       "SPR.hasMaxAge": -1,
#       "SPR.hasMinAge": -1,
#       "SPR.hasTotalCellCount": -1,
#       "SPR.hasTotalSizeOfFilesInMB": 62994.58986854553,
#       "SPR.isPairedEnd": [
#         false,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz",
#         "unknown",
#         "bam",
#         "csv"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "ArrayExpress",
#         "CentreForTrophoblastResearch",
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine"
#       ],
#       "SPR.hasProjectShortName": [
#         "Fetal/Maternal Interface"
#       ],
#       "SPR.hasProjectTitle": [
#         "Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "placenta_sample_81"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_793",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "HomoSapiens"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         "Optimus_v1.3.1",
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "Normal"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq4000",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "10Xv2Sequencing",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         null,
#         "Placenta"
#       ],
#       "SPR.hasPreservation": [
#         "Fresh"
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "Live"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         null
#       ],
#       "SPR.hasBiologicalSex": [
#         "male"
#       ],
#       "SPR.hasMaxAge": -1,
#       "SPR.hasMinAge": -1,
#       "SPR.hasTotalCellCount": -1,
#       "SPR.hasTotalSizeOfFilesInMB": 64476.23386859894,
#       "SPR.isPairedEnd": [
#         false,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz",
#         "unknown",
#         "bam",
#         "csv"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "ArrayExpress",
#         "CentreForTrophoblastResearch",
#         "HumanCellAtlasDataCoordinationPlatform",
#         "InstituteOfCellularMedicine"
#       ],
#       "SPR.hasProjectShortName": [
#         "Fetal/Maternal Interface"
#       ],
#       "SPR.hasProjectTitle": [
#         "Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "placenta_sample_91"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_794",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "HomoSapiens"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "AcousticNeuroma",
#         "KidneyCancer",
#         "ObstructiveSleepApneaSyndrome"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         "Cortex",
#         "Kidney"
#       ],
#       "SPR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         null
#       ],
#       "SPR.hasBiologicalSex": [
#         "male"
#       ],
#       "SPR.hasMaxAge": 54,
#       "SPR.hasMinAge": 54,
#       "SPR.hasTotalCellCount": 5000,
#       "SPR.hasTotalSizeOfFilesInMB": 32454.628989219666,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "SPR.hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "SPR.hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "specimen_control_1"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_795",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "HomoSapiens"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "AcuteKidneyTubularNecrosis",
#         "BenignProstaticHyperplasia",
#         "EssentialHypertension",
#         "KidneyCancer",
#         "PericardialEffusion"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         "Cortex",
#         "Kidney"
#       ],
#       "SPR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         null
#       ],
#       "SPR.hasBiologicalSex": [
#         "male"
#       ],
#       "SPR.hasMaxAge": 62,
#       "SPR.hasMinAge": 62,
#       "SPR.hasTotalCellCount": 5000,
#       "SPR.hasTotalSizeOfFilesInMB": 22465.97946548462,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "SPR.hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "SPR.hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "specimen_control_2"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_796",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "HomoSapiens"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "LymeDisease",
#         "AnxietyDisorder",
#         "Arthritis",
#         "DepressiveDisorder",
#         "Diverticulitis",
#         "GastroesophagealRefluxDisease",
#         "KidneyCancer"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         "Cortex",
#         "Kidney"
#       ],
#       "SPR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         null
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 61,
#       "SPR.hasMinAge": 61,
#       "SPR.hasTotalCellCount": 5000,
#       "SPR.hasTotalSizeOfFilesInMB": 27596.97253036499,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "SPR.hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "SPR.hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "specimen_control_3"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_797",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "HomoSapiens"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "AdrenalCortexAdenoma",
#         "Arthritis",
#         "GastroesophagealRefluxDisease",
#         "HereditaryHemochromatosis",
#         "HiatusHernia",
#         "IrritableBowelSyndrome",
#         "KidneyCancer",
#         "NonAlcoholicFattyLiverDisease",
#         "ObstructiveSleepApneaSyndrome",
#         "Type2DiabetesMellitus",
#         "VentricularTachycardia"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         "Cortex",
#         "Kidney"
#       ],
#       "SPR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         null
#       ],
#       "SPR.hasBiologicalSex": [
#         "male"
#       ],
#       "SPR.hasMaxAge": 74,
#       "SPR.hasMinAge": 74,
#       "SPR.hasTotalCellCount": 5000,
#       "SPR.hasTotalSizeOfFilesInMB": 30130.25943660736,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "SPR.hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "SPR.hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "specimen_diabetes_1"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_798",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "HomoSapiens"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "EnterococcusFaecalisInfection",
#         "EssentialHypertension",
#         "KidneyCancer",
#         "ProstateCancer",
#         "PureAutonomicFailure",
#         "SyndromicDyslipidemia",
#         "Type2DiabetesMellitus"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         "Cortex",
#         "Kidney"
#       ],
#       "SPR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         null
#       ],
#       "SPR.hasBiologicalSex": [
#         "male"
#       ],
#       "SPR.hasMaxAge": 52,
#       "SPR.hasMinAge": 52,
#       "SPR.hasTotalCellCount": 5000,
#       "SPR.hasTotalSizeOfFilesInMB": 23623.905035972595,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "SPR.hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "SPR.hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "specimen_diabetes_2"
#     }
#   },
#   {
#     "ID": "SPECIMEN_ID_799",
#     "ObjectProperties": {
#       "SPR.hasSpecie": [
#         "HomoSapiens"
#       ],
#       "SPR.hasAnalysisProtocol": [
#         null
#       ],
#       "SPR.hasCellLineType": null,
#       "SPR.hasDiseaseStatus": [
#         "GastroesophagealRefluxDisease",
#         "Hyperlipidemia",
#         "KidneyCancer",
#         "Type2DiabetesMellitus"
#       ],
#       "SPR.hasInstrument": [
#         "IlluminaHiSeq2500",
#         null
#       ],
#       "SPR.hasLibrary": [
#         "10X5'v2Sequencing",
#         null
#       ],
#       "SPR.hasModel": null,
#       "SPR.hasObjectOfStudy": [
#         "Cortex",
#         "Kidney"
#       ],
#       "SPR.hasPreservation": [
#         "CryopreservationInLiquidNitrogenDeadTissue"
#       ],
#       "SPR.hasSampleType": "Specimens",
#       "SPR.hasSelectedCellType": [
#         "EndothelialCell",
#         "EpithelialCell",
#         "Fibroblast",
#         "Monocyte",
#         "MyofibroblastCell"
#       ]
#     },
#     "DataProperties": {
#       "SPR.hasAgeUnit": [
#         null
#       ],
#       "SPR.hasBiologicalSex": [
#         "female"
#       ],
#       "SPR.hasMaxAge": 57,
#       "SPR.hasMinAge": 57,
#       "SPR.hasTotalCellCount": 5000,
#       "SPR.hasTotalSizeOfFilesInMB": 29599.9630317688,
#       "SPR.isPairedEnd": [
#         true,
#         null
#       ],
#       "SR.hasFileFormat": [
#         "fastq.gz"
#       ]
#     },
#     "AnnotationProperties": {
#       "SPR.hasLaboratory": [
#         "DepartmentOfMedicine,DivisionOfNephrology",
#         "DepartmentOfMedicine,DivisionOfRenalMedicine",
#         "DepartmentOfPathologyAndImmunology",
#         "DepartmentOfPathology,BrighamAndWomen\u2019SHospital",
#         "HumanCellAtlasDataCoordinationPlatform"
#       ],
#       "SPR.hasProjectShortName": [
#         "Diabetic Nephropathy snRNA-seq"
#       ],
#       "SPR.hasProjectTitle": [
#         "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#       ],
#       "SPR.isPartOfCollection": "HumanCellAtlas",
#       "SPR.isPartOfRepository": "HumanCellAtlas",
#       "SR.hasSpecimenID": "specimen_diabetes_3"
#     }
#   }
# ]

# %%
json_processed = {}
json_processed['specimens'] = hits_processed

# print(json.dumps(json_processed, indent=2, sort_keys=True))

# %% [markdown]
# # Read projects from HCA

# %%
seed_url = "https://service.explore.data.humancellatlas.org/repository/projects?filters=%7B%7D&size=30&sort=projectTitle&order=asc"

# %%
# User-Agent obtenido del recurso del curso.
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)

# %%
print(json.dumps(answer.json(), indent=2, sort_keys=True))
# Out:
# {
#   "hits": [
#     {
#       "cellLines": [],
#       "cellSuspensions": [
#         {
#           "organ": [
#             "brain"
#           ],
#           "organPart": [
#             "cortex"
#           ],
#           "selectedCellType": [
#             "neuron"
#           ],
#           "totalCells": 1330000
#         }
#       ],
#       "donorOrganisms": [
#         {
#           "biologicalSex": [
#             "unknown"
#           ],
#           "disease": [
#             "normal"
#           ],
#           "donorCount": 2,
#           "genusSpecies": [
#             "Mus musculus"
#           ],
#           "id": [
#             "E18_20160930",
#             "E18_20161004"
#           ],
#           "organismAge": [
#             "18"
#           ],
#           "organismAgeRange": [
#             {
#               "gte": 1555200.0,
#               "lte": 1555200.0
#             }
#           ],
#           "organismAgeUnit": [
#             "day"
#           ]
#         }
#       ],
#       "entryId": "74b6d569-3b11-42ef-b6b1-a0454522b4a0",
#       "fileTypeSummaries": [
#         {
#           "count": 16377,
#           "fileType": "fastq",
#           "totalSize": 3206177550920
#         }
#       ],
#       "organoids": [],
#       "projects": [
#         {
#           "arrayExpressAccessions": [
#             null
#           ],
#           "geoSeriesAccessions": [
#             "GSE93421"
#           ],
#           "insdcProjectAccessions": [
#             "SRP096558"
#           ],
#           "insdcStudyAccessions": [
#             "PRJNA360949"
#           ],
#           "laboratory": [
#             "Human Cell Atlas Data Coordination Platform"
#           ],
#           "projectShortname": "1M Neurons",
#           "projectTitle": "1.3 Million Brain Cells from E18 Mice",
#           "supplementaryLinks": [
#             "https://support.10xgenomics.com/single-cell-gene-expression/datasets/1.3.0/1M_neurons"
#           ]
#         }
#       ],
#       "protocols": [
#         {
#           "assayType": [
#             null
#           ],
#           "instrumentManufacturerModel": [
#             "Illumina HiSeq 4000",
#             null
#           ],
#           "libraryConstructionApproach": [
#             "10X v2 sequencing",
#             null
#           ],
#           "pairedEnd": [
#             false,
#             null
#           ],
#           "workflow": [
#             null
#           ]
#         }
#       ],
#       "samples": [
#         {
#           "disease": [
#             "normal"
#           ],
#           "effectiveOrgan": [
#             "brain"
#           ],
#           "id": [
#             "E18_20160930_Brain",
#             "E18_20161004_Brain"
#           ],
#           "organ": [
#             "brain"
#           ],
#           "organPart": [
#             "cortex"
#           ],
#           "preservationMethod": [
#             "fresh"
#           ],
#           "sampleEntityType": [
#             "specimens"
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ],
#       "specimens": [
#         {
#           "disease": [
#             "normal"
#           ],
#           "id": [
#             "E18_20160930_Brain",
#             "E18_20161004_Brain"
#           ],
#           "organ": [
#             "brain"
#           ],
#           "organPart": [
#             "cortex"
#           ],
#           "preservationMethod": [
#             "fresh"
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ]
#     },
#     {
#       "cellLines": [],
#       "cellSuspensions": [
#         {
#           "organ": [
#             "pancreas"
#           ],
#           "organPart": [
#             null
#           ],
#           "selectedCellType": [
#             "pancreatic PP cell"
#           ],
#           "totalCells": 12404
#         }
#       ],
#       "donorOrganisms": [
#         {
#           "biologicalSex": [
#             "female",
#             "male",
#             "unknown"
#           ],
#           "disease": [
#             "normal",
#             "type 2 diabetes mellitus"
#           ],
#           "donorCount": 14,
#           "genusSpecies": [
#             "Homo sapiens",
#             "Mus musculus"
#           ],
#           "id": [
#             "H1",
#             "H2",
#             "H3",
#             "H4",
#             "M_C57BL/6_1",
#             "M_C57BL/6_2",
#             "M_C57BL/6_3",
#             "M_C57BL/6_4",
#             "M_C57BL/6_5",
#             "M_ICR_1",
#             "M_ICR_2",
#             "M_ICR_3",
#             "M_ICR_4",
#             "M_ICR_5"
#           ],
#           "organismAge": [
#             "17",
#             "38",
#             "51",
#             "59",
#             null
#           ],
#           "organismAgeRange": [
#             {
#               "gte": 536112000.0,
#               "lte": 536112000.0
#             },
#             {
#               "gte": 1198368000.0,
#               "lte": 1198368000.0
#             },
#             {
#               "gte": 1608336000.0,
#               "lte": 1608336000.0
#             },
#             {
#               "gte": 1860624000.0,
#               "lte": 1860624000.0
#             }
#           ],
#           "organismAgeUnit": [
#             "year",
#             null
#           ]
#         }
#       ],
#       "entryId": "f86f1ab4-1fbb-4510-ae35-3ffd752d4dfc",
#       "fileTypeSummaries": [
#         {
#           "count": 38,
#           "fileType": "fastq.gz",
#           "totalSize": 418064570672
#         }
#       ],
#       "organoids": [],
#       "projects": [
#         {
#           "arrayExpressAccessions": [
#             "E-GEOD-84133"
#           ],
#           "geoSeriesAccessions": [
#             "GSE84133"
#           ],
#           "insdcProjectAccessions": [
#             "SRP078321"
#           ],
#           "insdcStudyAccessions": [
#             "PRJNA328774"
#           ],
#           "laboratory": [
#             "Center for the Science of Therapeutics",
#             "Department of Immunology, Faculty of Medicine",
#             "Department of Stem Cell and Regenerative Biology",
#             "Department of Systems Biology",
#             "Faculty of Biology",
#             "Human Cell Atlas Data Coordination Platform"
#           ],
#           "projectShortname": "HumanMousePancreas",
#           "projectTitle": "A Single-Cell Transcriptomic Map of the Human and Mouse Pancreas Reveals Inter- and Intra-cell Population Structure",
#           "supplementaryLinks": [
#             null
#           ]
#         }
#       ],
#       "protocols": [
#         {
#           "assayType": [
#             null
#           ],
#           "instrumentManufacturerModel": [
#             "Illumina HiSeq 2500",
#             null
#           ],
#           "libraryConstructionApproach": [
#             "inDrop",
#             null
#           ],
#           "pairedEnd": [
#             true,
#             null
#           ],
#           "workflow": [
#             null
#           ]
#         }
#       ],
#       "samples": [
#         {
#           "disease": [
#             null
#           ],
#           "effectiveOrgan": [
#             "pancreas"
#           ],
#           "id": [
#             "H1_pancreas",
#             "H2_pancreas",
#             "H3_pancreas",
#             "H4_pancreas",
#             "M_C57BL/6_pancreas",
#             "M_ICR_pancreas"
#           ],
#           "organ": [
#             "pancreas"
#           ],
#           "organPart": [
#             null
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "sampleEntityType": [
#             "specimens"
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ],
#       "specimens": [
#         {
#           "disease": [
#             null
#           ],
#           "id": [
#             "H1_pancreas",
#             "H2_pancreas",
#             "H3_pancreas",
#             "H4_pancreas",
#             "M_C57BL/6_pancreas",
#             "M_ICR_pancreas"
#           ],
#           "organ": [
#             "pancreas"
#           ],
#           "organPart": [
#             null
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ]
#     },
#     {
#       "cellLines": [],
#       "cellSuspensions": [
#         {
#           "organ": [
#             "embryo"
#           ],
#           "organPart": [
#             null
#           ],
#           "selectedCellType": [
#             null
#           ],
#           "totalCells": 339089
#         }
#       ],
#       "donorOrganisms": [
#         {
#           "biologicalSex": [
#             "female"
#           ],
#           "disease": [
#             null
#           ],
#           "donorCount": 63,
#           "genusSpecies": [
#             "Mus musculus"
#           ],
#           "id": [
#             "Female_mouse_1",
#             "Female_mouse_10",
#             "Female_mouse_11",
#             "Female_mouse_12",
#             "Female_mouse_13",
#             "Female_mouse_14",
#             "Female_mouse_15",
#             "Female_mouse_16",
#             "Female_mouse_17",
#             "Female_mouse_18",
#             "Female_mouse_19",
#             "Female_mouse_2",
#             "Female_mouse_20",
#             "Female_mouse_21",
#             "Female_mouse_22",
#             "Female_mouse_23",
#             "Female_mouse_24",
#             "Female_mouse_25",
#             "Female_mouse_26",
#             "Female_mouse_27",
#             "Female_mouse_28",
#             "Female_mouse_29",
#             "Female_mouse_3",
#             "Female_mouse_30",
#             "Female_mouse_31",
#             "Female_mouse_32",
#             "Female_mouse_33",
#             "Female_mouse_34",
#             "Female_mouse_35",
#             "Female_mouse_36",
#             "Female_mouse_37",
#             "Female_mouse_38",
#             "Female_mouse_39",
#             "Female_mouse_4",
#             "Female_mouse_40",
#             "Female_mouse_41",
#             "Female_mouse_42",
#             "Female_mouse_43",
#             "Female_mouse_44",
#             "Female_mouse_45",
#             "Female_mouse_46",
#             "Female_mouse_47",
#             "Female_mouse_48",
#             "Female_mouse_49",
#             "Female_mouse_5",
#             "Female_mouse_50",
#             "Female_mouse_51",
#             "Female_mouse_52",
#             "Female_mouse_53",
#             "Female_mouse_54",
#             "Female_mouse_55",
#             "Female_mouse_56",
#             "Female_mouse_57",
#             "Female_mouse_58",
#             "Female_mouse_59",
#             "Female_mouse_6",
#             "Female_mouse_60",
#             "Female_mouse_61",
#             "Female_mouse_62",
#             "Female_mouse_63",
#             "Female_mouse_7",
#             "Female_mouse_8",
#             "Female_mouse_9"
#           ],
#           "organismAge": [
#             "7",
#             "7-8",
#             "8",
#             "9"
#           ],
#           "organismAgeRange": [
#             {
#               "gte": 4233600.0,
#               "lte": 4233600.0
#             },
#             {
#               "gte": 4233600.0,
#               "lte": 4838400.0
#             },
#             {
#               "gte": 4838400.0,
#               "lte": 4838400.0
#             },
#             {
#               "gte": 5443200.0,
#               "lte": 5443200.0
#             }
#           ],
#           "organismAgeUnit": [
#             "week"
#           ]
#         }
#       ],
#       "entryId": "1defdada-a365-44ad-9b29-443b06bd11d6",
#       "fileTypeSummaries": [
#         {
#           "count": 10240,
#           "fileType": "fastq.gz",
#           "totalSize": 994936026664
#         }
#       ],
#       "organoids": [],
#       "projects": [
#         {
#           "arrayExpressAccessions": [
#             "E-MTAB-6967"
#           ],
#           "geoSeriesAccessions": [
#             "GSE87038"
#           ],
#           "insdcProjectAccessions": [
#             "ERP110801"
#           ],
#           "insdcStudyAccessions": [
#             "PRJEB28586"
#           ],
#           "laboratory": [
#             null
#           ],
#           "projectShortname": "MouseGastrulationAtlas",
#           "projectTitle": "A single-cell molecular map of mouse gastrulation and early organogenesis",
#           "supplementaryLinks": [
#             "https://github.com/MarioniLab/EmbryoTimecourse2018",
#             "https://marionilab.cruk.cam.ac.uk/MouseGastrulation2018/"
#           ]
#         }
#       ],
#       "protocols": [
#         {
#           "assayType": [
#             null
#           ],
#           "instrumentManufacturerModel": [
#             "Illumina HiSeq 2500",
#             null
#           ],
#           "libraryConstructionApproach": [
#             "10X 3' v1 sequencing",
#             null
#           ],
#           "pairedEnd": [
#             false,
#             null
#           ],
#           "workflow": [
#             null
#           ]
#         }
#       ],
#       "samples": [
#         {
#           "disease": [
#             null
#           ],
#           "effectiveOrgan": [
#             "embryo"
#           ],
#           "id": [
#             "embryo_pool_1",
#             "embryo_pool_10",
#             "embryo_pool_11",
#             "embryo_pool_12",
#             "embryo_pool_13",
#             "embryo_pool_14",
#             "embryo_pool_15",
#             "embryo_pool_16",
#             "embryo_pool_17",
#             "embryo_pool_18",
#             "embryo_pool_19",
#             "embryo_pool_2",
#             "embryo_pool_20",
#             "embryo_pool_21",
#             "embryo_pool_22",
#             "embryo_pool_23",
#             "embryo_pool_24",
#             "embryo_pool_25",
#             "embryo_pool_26",
#             "embryo_pool_3",
#             "embryo_pool_4",
#             "embryo_pool_5",
#             "embryo_pool_6",
#             "embryo_pool_7",
#             "embryo_pool_8",
#             "embryo_pool_9"
#           ],
#           "organ": [
#             "embryo"
#           ],
#           "organPart": [
#             null
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "sampleEntityType": [
#             "specimens"
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ],
#       "specimens": [
#         {
#           "disease": [
#             null
#           ],
#           "id": [
#             "embryo_pool_1",
#             "embryo_pool_10",
#             "embryo_pool_11",
#             "embryo_pool_12",
#             "embryo_pool_13",
#             "embryo_pool_14",
#             "embryo_pool_15",
#             "embryo_pool_16",
#             "embryo_pool_17",
#             "embryo_pool_18",
#             "embryo_pool_19",
#             "embryo_pool_2",
#             "embryo_pool_20",
#             "embryo_pool_21",
#             "embryo_pool_22",
#             "embryo_pool_23",
#             "embryo_pool_24",
#             "embryo_pool_25",
#             "embryo_pool_26",
#             "embryo_pool_3",
#             "embryo_pool_4",
#             "embryo_pool_5",
#             "embryo_pool_6",
#             "embryo_pool_7",
#             "embryo_pool_8",
#             "embryo_pool_9"
#           ],
#           "organ": [
#             "embryo"
#           ],
#           "organPart": [
#             null
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ]
#     },
#     {
#       "cellLines": [],
#       "cellSuspensions": [
#         {
#           "organ": [
#             "lung"
#           ],
#           "organPart": [
#             "Left lateral basal bronchopulmonary segment"
#           ],
#           "selectedCellType": [
#             "T cell"
#           ],
#           "totalCells": 0
#         },
#         {
#           "organ": [
#             "blood"
#           ],
#           "organPart": [
#             "venous blood"
#           ],
#           "selectedCellType": [
#             "T cell"
#           ],
#           "totalCells": 0
#         },
#         {
#           "organ": [
#             "mediastinal lymph node"
#           ],
#           "organPart": [
#             "mediastinal lymph node"
#           ],
#           "selectedCellType": [
#             "T cell"
#           ],
#           "totalCells": 0
#         },
#         {
#           "organ": [
#             "hematopoietic system"
#           ],
#           "organPart": [
#             "bone marrow"
#           ],
#           "selectedCellType": [
#             "T cell"
#           ],
#           "totalCells": 0
#         }
#       ],
#       "donorOrganisms": [
#         {
#           "biologicalSex": [
#             "male"
#           ],
#           "disease": [
#             "hypertension",
#             "normal"
#           ],
#           "donorCount": 4,
#           "genusSpecies": [
#             "Homo sapiens"
#           ],
#           "id": [
#             "Blood_donor_A",
#             "Blood_donor_B",
#             "Tissue_donor_1",
#             "Tissue_donor_2"
#           ],
#           "organismAge": [
#             "50-55",
#             "52",
#             "65"
#           ],
#           "organismAgeRange": [
#             {
#               "gte": 1639872000.0,
#               "lte": 1639872000.0
#             },
#             {
#               "gte": 1576800000.0,
#               "lte": 1734480000.0
#             },
#             {
#               "gte": 2049840000.0,
#               "lte": 2049840000.0
#             }
#           ],
#           "organismAgeUnit": [
#             "year"
#           ]
#         }
#       ],
#       "entryId": "4a95101c-9ffc-4f30-a809-f04518a23803",
#       "fileTypeSummaries": [
#         {
#           "count": 32,
#           "fileType": "fastq.gz",
#           "totalSize": 496164231119
#         },
#         {
#           "count": 80,
#           "fileType": "unknown",
#           "totalSize": 1497756132
#         },
#         {
#           "count": 16,
#           "fileType": "bam",
#           "totalSize": 461515369236
#         },
#         {
#           "count": 16,
#           "fileType": "matrix",
#           "totalSize": 2368
#         },
#         {
#           "count": 16,
#           "fileType": "csv",
#           "totalSize": 414889663
#         }
#       ],
#       "organoids": [],
#       "projects": [
#         {
#           "arrayExpressAccessions": [
#             null
#           ],
#           "geoSeriesAccessions": [
#             null
#           ],
#           "insdcProjectAccessions": [
#             null
#           ],
#           "insdcStudyAccessions": [
#             null
#           ],
#           "laboratory": [
#             "Farber Lab; Columbia Center for Translational Immunology",
#             "Human Cell Atlas Data Coordination Platform",
#             "Sims Lab; Department of Systems Biology"
#           ],
#           "projectShortname": "HumanTissueTcellActivation",
#           "projectTitle": "A single-cell reference map of transcriptional states for human blood and tissue T cell activation",
#           "supplementaryLinks": [
#             null
#           ]
#         }
#       ],
#       "protocols": [
#         {
#           "assayType": [
#             null
#           ],
#           "instrumentManufacturerModel": [
#             "Illumina HiSeq 4000",
#             null
#           ],
#           "libraryConstructionApproach": [
#             "10X v2 sequencing",
#             null
#           ],
#           "pairedEnd": [
#             false,
#             null
#           ],
#           "workflow": [
#             "optimus_v1.3.5",
#             null
#           ]
#         }
#       ],
#       "samples": [
#         {
#           "disease": [
#             null
#           ],
#           "effectiveOrgan": [
#             "blood",
#             "hematopoietic system",
#             "lung",
#             "mediastinal lymph node"
#           ],
#           "id": [
#             "PP001",
#             "PP002",
#             "PP003",
#             "PP004",
#             "PP005",
#             "PP006",
#             "PP009",
#             "PP010",
#             "PP011",
#             "PP012",
#             "PP013",
#             "PP014",
#             "PP017",
#             "PP018",
#             "PP019",
#             "PP020"
#           ],
#           "organ": [
#             "blood",
#             "hematopoietic system",
#             "lung",
#             "mediastinal lymph node"
#           ],
#           "organPart": [
#             "Left lateral basal bronchopulmonary segment",
#             "bone marrow",
#             "mediastinal lymph node",
#             "venous blood"
#           ],
#           "preservationMethod": [
#             "fresh"
#           ],
#           "sampleEntityType": [
#             "specimens"
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ],
#       "specimens": [
#         {
#           "disease": [
#             null
#           ],
#           "id": [
#             "PP001",
#             "PP002",
#             "PP003",
#             "PP004",
#             "PP005",
#             "PP006",
#             "PP009",
#             "PP010",
#             "PP011",
#             "PP012",
#             "PP013",
#             "PP014",
#             "PP017",
#             "PP018",
#             "PP019",
#             "PP020"
#           ],
#           "organ": [
#             "blood",
#             "hematopoietic system",
#             "lung",
#             "mediastinal lymph node"
#           ],
#           "organPart": [
#             "Left lateral basal bronchopulmonary segment",
#             "bone marrow",
#             "mediastinal lymph node",
#             "venous blood"
#           ],
#           "preservationMethod": [
#             "fresh"
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ]
#     },
#     {
#       "cellLines": [],
#       "cellSuspensions": [
#         {
#           "organ": [
#             "eye"
#           ],
#           "organPart": [
#             "retinal neural layer"
#           ],
#           "selectedCellType": [
#             null
#           ],
#           "totalCells": 44000
#         }
#       ],
#       "donorOrganisms": [
#         {
#           "biologicalSex": [
#             "female",
#             "male"
#           ],
#           "disease": [
#             "cataract (disease)",
#             "normal"
#           ],
#           "donorCount": 3,
#           "genusSpecies": [
#             "Homo sapiens"
#           ],
#           "id": [
#             "17-010",
#             "17-011",
#             "SC"
#           ],
#           "organismAge": [
#             "42",
#             "53",
#             "80"
#           ],
#           "organismAgeRange": [
#             {
#               "gte": 1324512000.0,
#               "lte": 1324512000.0
#             },
#             {
#               "gte": 1671408000.0,
#               "lte": 1671408000.0
#             },
#             {
#               "gte": 2522880000.0,
#               "lte": 2522880000.0
#             }
#           ],
#           "organismAgeUnit": [
#             "year"
#           ]
#         }
#       ],
#       "entryId": "8185730f-4113-40d3-9cc3-929271784c2b",
#       "fileTypeSummaries": [
#         {
#           "count": 15,
#           "fileType": "fastq.gz",
#           "totalSize": 101869450565
#         },
#         {
#           "count": 25,
#           "fileType": "unknown",
#           "totalSize": 344662182
#         },
#         {
#           "count": 5,
#           "fileType": "bam",
#           "totalSize": 94362546462
#         },
#         {
#           "count": 5,
#           "fileType": "matrix",
#           "totalSize": 740
#         },
#         {
#           "count": 5,
#           "fileType": "csv",
#           "totalSize": 81162079
#         }
#       ],
#       "organoids": [],
#       "projects": [
#         {
#           "arrayExpressAccessions": [
#             "E-MTAB-7316"
#           ],
#           "geoSeriesAccessions": [
#             null
#           ],
#           "insdcProjectAccessions": [
#             null
#           ],
#           "insdcStudyAccessions": [
#             null
#           ],
#           "laboratory": [
#             "Cellular Reprogramming Unit",
#             "Clinical Genetics Unit",
#             "Department of Chemistry and Biotechnology",
#             "Garvan\u2010Weizmann Centre for Cellular Genomics",
#             "Human Cell Atlas Data Coordination Platform",
#             "Institute for Molecular Bioscience",
#             "John Curtin School of Medical Research",
#             "Lions Eye Donation Services",
#             "National Institute for Aging",
#             "Save Sight Institute",
#             "Stem Cells and Regenerative Medicine Section, NIHR Great Ormond Street Hospital Biomedical Research Centre"
#           ],
#           "projectShortname": "WongAdultRetina",
#           "projectTitle": "A single-cell transcriptome atlas of the adult human retina",
#           "supplementaryLinks": [
#             "https://github.com/IMB-Computational-Genomics-Lab/scGPS",
#             "https://github.com/powellgenomicslab/ascend",
#             "https://github.com/satijalab/seurat"
#           ]
#         }
#       ],
#       "protocols": [
#         {
#           "assayType": [
#             null
#           ],
#           "instrumentManufacturerModel": [
#             "Illumina HiSeq 2500",
#             null
#           ],
#           "libraryConstructionApproach": [
#             "10X v2 sequencing",
#             null
#           ],
#           "pairedEnd": [
#             false,
#             null
#           ],
#           "workflow": [
#             "optimus_v1.3.5",
#             null
#           ]
#         }
#       ],
#       "samples": [
#         {
#           "disease": [
#             "normal"
#           ],
#           "effectiveOrgan": [
#             "eye"
#           ],
#           "id": [
#             "17-010-R",
#             "17-011-R",
#             "SC-L"
#           ],
#           "organ": [
#             "eye"
#           ],
#           "organPart": [
#             "retinal neural layer"
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "sampleEntityType": [
#             "specimens"
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ],
#       "specimens": [
#         {
#           "disease": [
#             "normal"
#           ],
#           "id": [
#             "17-010-R",
#             "17-011-R",
#             "SC-L"
#           ],
#           "organ": [
#             "eye"
#           ],
#           "organPart": [
#             "retinal neural layer"
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ]
#     },
#     {
#       "cellLines": [
#         {
#           "cellLineType": [
#             "induced pluripotent"
#           ],
#           "id": [
#             "HPSI0214i-kucg_2",
#             "HPSI0214i-wibj_2",
#             "HPSI0314i-hoik_1",
#             "HPSI0314i-sojd_3"
#           ],
#           "modelOrgan": [
#             "stem cell"
#           ]
#         }
#       ],
#       "cellSuspensions": [
#         {
#           "organ": [
#             "brain"
#           ],
#           "organPart": [
#             null
#           ],
#           "selectedCellType": [
#             "neural cell"
#           ],
#           "totalCells": 19916
#         }
#       ],
#       "donorOrganisms": [
#         {
#           "biologicalSex": [
#             "female",
#             "male"
#           ],
#           "disease": [
#             "normal"
#           ],
#           "donorCount": 4,
#           "genusSpecies": [
#             "Homo sapiens"
#           ],
#           "id": [
#             "HPSI0214i-kucg",
#             "HPSI0214i-wibj",
#             "HPSI0314i-hoik",
#             "HPSI0314i-sojd"
#           ],
#           "organismAge": [
#             "40-44",
#             "45-49",
#             "55-59",
#             "65-69"
#           ],
#           "organismAgeRange": [
#             {
#               "gte": 1261440000.0,
#               "lte": 1387584000.0
#             },
#             {
#               "gte": 1419120000.0,
#               "lte": 1545264000.0
#             },
#             {
#               "gte": 1734480000.0,
#               "lte": 1860624000.0
#             },
#             {
#               "gte": 2049840000.0,
#               "lte": 2175984000.0
#             }
#           ],
#           "organismAgeUnit": [
#             "year"
#           ]
#         }
#       ],
#       "entryId": "005d611a-14d5-4fbf-846e-571a1f874f70",
#       "fileTypeSummaries": [
#         {
#           "count": 18,
#           "fileType": "fastq.gz",
#           "totalSize": 53857782294
#         },
#         {
#           "count": 3,
#           "fileType": "pdf",
#           "totalSize": 15762678
#         },
#         {
#           "count": 30,
#           "fileType": "unknown",
#           "totalSize": 641963142
#         },
#         {
#           "count": 6,
#           "fileType": "bam",
#           "totalSize": 56932529172
#         },
#         {
#           "count": 6,
#           "fileType": "matrix",
#           "totalSize": 888
#         },
#         {
#           "count": 6,
#           "fileType": "csv",
#           "totalSize": 154340957
#         }
#       ],
#       "organoids": [
#         {
#           "id": [
#             "Org_HPSI0214i-kucg_2_1",
#             "Org_HPSI0214i-kucg_2_2",
#             "Org_HPSI0214i-kucg_2_3",
#             "Org_HPSI0214i-wibj_2_1",
#             "Org_HPSI0214i-wibj_2_2",
#             "Org_HPSI0214i-wibj_2_3",
#             "Org_HPSI0314i-hoik_1_1",
#             "Org_HPSI0314i-hoik_1_2",
#             "Org_HPSI0314i-hoik_1_3",
#             "Org_HPSI0314i-sojd_3_1",
#             "Org_HPSI0314i-sojd_3_2",
#             "Org_HPSI0314i-sojd_3_3"
#           ],
#           "modelOrgan": [
#             "brain"
#           ],
#           "modelOrganPart": [
#             null
#           ]
#         }
#       ],
#       "projects": [
#         {
#           "arrayExpressAccessions": [
#             null
#           ],
#           "geoSeriesAccessions": [
#             null
#           ],
#           "insdcProjectAccessions": [
#             "ERP114427"
#           ],
#           "insdcStudyAccessions": [
#             "PRJEB31821"
#           ],
#           "laboratory": [
#             "Human Cell Atlas Data Coordination Platform"
#           ],
#           "projectShortname": "HPSI human cerebral organoids",
#           "projectTitle": "Assessing the relevance of organoids to model inter-individual variation",
#           "supplementaryLinks": [
#             null
#           ]
#         }
#       ],
#       "protocols": [
#         {
#           "assayType": [
#             null
#           ],
#           "instrumentManufacturerModel": [
#             "Illumina HiSeq 2500",
#             null
#           ],
#           "libraryConstructionApproach": [
#             "10X v2 sequencing",
#             null
#           ],
#           "pairedEnd": [
#             true,
#             null
#           ],
#           "workflow": [
#             "optimus_v1.3.1",
#             "optimus_v1.3.2",
#             null
#           ]
#         }
#       ],
#       "samples": [
#         {
#           "effectiveOrgan": [
#             "brain"
#           ],
#           "id": [
#             "Org_HPSI0214i-kucg_2_1",
#             "Org_HPSI0214i-kucg_2_2",
#             "Org_HPSI0214i-kucg_2_3",
#             "Org_HPSI0214i-wibj_2_1",
#             "Org_HPSI0214i-wibj_2_2",
#             "Org_HPSI0214i-wibj_2_3",
#             "Org_HPSI0314i-hoik_1_1",
#             "Org_HPSI0314i-hoik_1_2",
#             "Org_HPSI0314i-hoik_1_3",
#             "Org_HPSI0314i-sojd_3_1",
#             "Org_HPSI0314i-sojd_3_2",
#             "Org_HPSI0314i-sojd_3_3"
#           ],
#           "modelOrgan": [
#             "brain"
#           ],
#           "modelOrganPart": [
#             null
#           ],
#           "sampleEntityType": [
#             "organoids"
#           ]
#         }
#       ],
#       "specimens": [
#         {
#           "disease": [
#             "normal"
#           ],
#           "id": [
#             "HPSI0214i-kucg_skin",
#             "HPSI0214i-wibj_skin",
#             "HPSI0314i-hoik_skin",
#             "HPSI0314i-sojd_skin"
#           ],
#           "organ": [
#             "skin of body"
#           ],
#           "organPart": [
#             "skin epidermis"
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ]
#     },
#     {
#       "cellLines": [],
#       "cellSuspensions": [
#         {
#           "organ": [
#             "hematopoietic system"
#           ],
#           "organPart": [
#             "bone marrow"
#           ],
#           "selectedCellType": [
#             "Plasma cell"
#           ],
#           "totalCells": 9500
#         }
#       ],
#       "donorOrganisms": [
#         {
#           "biologicalSex": [
#             "female",
#             "male"
#           ],
#           "disease": [
#             "osteoarthritis, hip"
#           ],
#           "donorCount": 12,
#           "genusSpecies": [
#             "Homo sapiens"
#           ],
#           "id": [
#             "Hip10",
#             "Hip11",
#             "Hip12",
#             "Hip13",
#             "Hip15",
#             "Hip16",
#             "Hip17",
#             "Hip5",
#             "Hip6",
#             "Hip7",
#             "Hip8",
#             "Hip9"
#           ],
#           "organismAge": [
#             "49",
#             "50",
#             "53",
#             "63",
#             "68",
#             "69",
#             "73",
#             "76",
#             "78",
#             "80",
#             "85"
#           ],
#           "organismAgeRange": [
#             {
#               "gte": 1545264000.0,
#               "lte": 1545264000.0
#             },
#             {
#               "gte": 1576800000.0,
#               "lte": 1576800000.0
#             },
#             {
#               "gte": 1671408000.0,
#               "lte": 1671408000.0
#             },
#             {
#               "gte": 1986768000.0,
#               "lte": 1986768000.0
#             },
#             {
#               "gte": 2144448000.0,
#               "lte": 2144448000.0
#             },
#             {
#               "gte": 2175984000.0,
#               "lte": 2175984000.0
#             },
#             {
#               "gte": 2302128000.0,
#               "lte": 2302128000.0
#             },
#             {
#               "gte": 2396736000.0,
#               "lte": 2396736000.0
#             },
#             {
#               "gte": 2459808000.0,
#               "lte": 2459808000.0
#             },
#             {
#               "gte": 2522880000.0,
#               "lte": 2522880000.0
#             },
#             {
#               "gte": 2680560000.0,
#               "lte": 2680560000.0
#             }
#           ],
#           "organismAgeUnit": [
#             "year"
#           ]
#         }
#       ],
#       "entryId": "a29952d9-925e-40f4-8a1c-274f118f1f51",
#       "fileTypeSummaries": [
#         {
#           "count": 50,
#           "fileType": "fastq.gz",
#           "totalSize": 32304816501
#         },
#         {
#           "count": 2,
#           "fileType": "pdf",
#           "totalSize": 204869
#         }
#       ],
#       "organoids": [],
#       "projects": [
#         {
#           "arrayExpressAccessions": [
#             null
#           ],
#           "geoSeriesAccessions": [
#             null
#           ],
#           "insdcProjectAccessions": [
#             null
#           ],
#           "insdcStudyAccessions": [
#             null
#           ],
#           "laboratory": [
#             "Human Cell Atlas Data Coordination Platform",
#             "Prof. Ido Amit"
#           ],
#           "projectShortname": "BM_PC",
#           "projectTitle": "Bone marrow plasma cells from hip replacement surgeries",
#           "supplementaryLinks": [
#             null
#           ]
#         }
#       ],
#       "protocols": [
#         {
#           "assayType": [
#             null
#           ],
#           "instrumentManufacturerModel": [
#             "Illumina NextSeq 500",
#             null
#           ],
#           "libraryConstructionApproach": [
#             "MARS-seq",
#             null
#           ],
#           "pairedEnd": [
#             true,
#             null
#           ],
#           "workflow": [
#             null
#           ]
#         }
#       ],
#       "samples": [
#         {
#           "disease": [
#             null
#           ],
#           "effectiveOrgan": [
#             "hematopoietic system"
#           ],
#           "id": [
#             "Hip10_specimen",
#             "Hip11_specimen",
#             "Hip12_specimen",
#             "Hip13_specimen",
#             "Hip15_specimen",
#             "Hip16_specimen",
#             "Hip17_specimen",
#             "Hip5_specimen",
#             "Hip6_specimen",
#             "Hip7_specimen",
#             "Hip8_specimen",
#             "Hip9_specimen"
#           ],
#           "organ": [
#             "hematopoietic system"
#           ],
#           "organPart": [
#             "bone marrow"
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "sampleEntityType": [
#             "specimens"
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ],
#       "specimens": [
#         {
#           "disease": [
#             null
#           ],
#           "id": [
#             "Hip10_specimen",
#             "Hip11_specimen",
#             "Hip12_specimen",
#             "Hip13_specimen",
#             "Hip15_specimen",
#             "Hip16_specimen",
#             "Hip17_specimen",
#             "Hip5_specimen",
#             "Hip6_specimen",
#             "Hip7_specimen",
#             "Hip8_specimen",
#             "Hip9_specimen"
#           ],
#           "organ": [
#             "hematopoietic system"
#           ],
#           "organPart": [
#             "bone marrow"
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ]
#     },
#     {
#       "cellLines": [],
#       "cellSuspensions": [
#         {
#           "organ": [
#             "blood"
#           ],
#           "organPart": [
#             null
#           ],
#           "selectedCellType": [
#             "peripheral blood mononuclear cell"
#           ],
#           "totalCells": 20000
#         }
#       ],
#       "donorOrganisms": [
#         {
#           "biologicalSex": [
#             "unknown"
#           ],
#           "disease": [
#             "normal"
#           ],
#           "donorCount": 8,
#           "genusSpecies": [
#             "Homo sapiens"
#           ],
#           "id": [
#             "Donor_PBMC1",
#             "Donor_PBMC2",
#             "Donor_PBMC3",
#             "Donor_PBMC4",
#             "Donor_PBMC5",
#             "Donor_PBMC6",
#             "Donor_PBMC7",
#             "Donor_PBMC8"
#           ],
#           "organismAge": [
#             null
#           ],
#           "organismAgeRange": null,
#           "organismAgeUnit": [
#             null
#           ]
#         }
#       ],
#       "entryId": "f81efc03-9f56-4354-aabb-6ce819c3d414",
#       "fileTypeSummaries": [
#         {
#           "count": 6,
#           "fileType": "fastq.gz",
#           "totalSize": 83729759795
#         }
#       ],
#       "organoids": [],
#       "projects": [
#         {
#           "arrayExpressAccessions": [
#             null
#           ],
#           "geoSeriesAccessions": [
#             null
#           ],
#           "insdcProjectAccessions": [
#             null
#           ],
#           "insdcStudyAccessions": [
#             null
#           ],
#           "laboratory": [
#             "Human Cell Atlas Data Coordination Platform",
#             "Satija Lab",
#             "Technology Development and Innovation"
#           ],
#           "projectShortname": "Multiplexed scRNA-seq with barcoded antibodies",
#           "projectTitle": "Cell hashing with barcoded antibodies enables multiplexing and doublet detection for single cell genomics",
#           "supplementaryLinks": [
#             null
#           ]
#         }
#       ],
#       "protocols": [
#         {
#           "assayType": [
#             null
#           ],
#           "instrumentManufacturerModel": [
#             "Illumina Hiseq 2500",
#             null
#           ],
#           "libraryConstructionApproach": [
#             "CITE-seq",
#             null
#           ],
#           "pairedEnd": [
#             false,
#             null
#           ],
#           "workflow": [
#             null
#           ]
#         }
#       ],
#       "samples": [
#         {
#           "disease": [
#             null
#           ],
#           "effectiveOrgan": [
#             "blood"
#           ],
#           "id": [
#             "Specimen_PBMC1",
#             "Specimen_PBMC2",
#             "Specimen_PBMC3",
#             "Specimen_PBMC4",
#             "Specimen_PBMC5",
#             "Specimen_PBMC6",
#             "Specimen_PBMC7",
#             "Specimen_PBMC8"
#           ],
#           "organ": [
#             "blood"
#           ],
#           "organPart": [
#             null
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "sampleEntityType": [
#             "specimens"
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ],
#       "specimens": [
#         {
#           "disease": [
#             null
#           ],
#           "id": [
#             "Specimen_PBMC1",
#             "Specimen_PBMC2",
#             "Specimen_PBMC3",
#             "Specimen_PBMC4",
#             "Specimen_PBMC5",
#             "Specimen_PBMC6",
#             "Specimen_PBMC7",
#             "Specimen_PBMC8"
#           ],
#           "organ": [
#             "blood"
#           ],
#           "organPart": [
#             null
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ]
#     },
#     {
#       "cellLines": [],
#       "cellSuspensions": [
#         {
#           "organ": [
#             "immune system"
#           ],
#           "organPart": [
#             "bone marrow"
#           ],
#           "selectedCellType": [
#             "bone marrow hematopoietic cell"
#           ],
#           "totalCells": 274182
#         },
#         {
#           "organ": [
#             "blood"
#           ],
#           "organPart": [
#             "umbilical cord blood"
#           ],
#           "selectedCellType": [
#             "cord blood hematopoietic stem cell"
#           ],
#           "totalCells": 253910
#         }
#       ],
#       "donorOrganisms": [
#         {
#           "biologicalSex": [
#             "female",
#             "male"
#           ],
#           "disease": [
#             null
#           ],
#           "donorCount": 16,
#           "genusSpecies": [
#             "Homo sapiens"
#           ],
#           "id": [
#             "BM1",
#             "BM2",
#             "BM3",
#             "BM4",
#             "BM5",
#             "BM6",
#             "BM7",
#             "BM8",
#             "CB1",
#             "CB2",
#             "CB3",
#             "CB4",
#             "CB5",
#             "CB6",
#             "CB7",
#             "CB8"
#           ],
#           "organismAge": [
#             "0",
#             "26",
#             "29",
#             "32",
#             "36",
#             "39",
#             "50",
#             "52"
#           ],
#           "organismAgeRange": [
#             {
#               "gte": 0.0,
#               "lte": 0.0
#             },
#             {
#               "gte": 819936000.0,
#               "lte": 819936000.0
#             },
#             {
#               "gte": 914544000.0,
#               "lte": 914544000.0
#             },
#             {
#               "gte": 1009152000.0,
#               "lte": 1009152000.0
#             },
#             {
#               "gte": 1135296000.0,
#               "lte": 1135296000.0
#             },
#             {
#               "gte": 1229904000.0,
#               "lte": 1229904000.0
#             },
#             {
#               "gte": 1576800000.0,
#               "lte": 1576800000.0
#             },
#             {
#               "gte": 1639872000.0,
#               "lte": 1639872000.0
#             }
#           ],
#           "organismAgeUnit": [
#             "year"
#           ]
#         }
#       ],
#       "entryId": "cc95ff89-2e68-4a08-a234-480eca21ce79",
#       "fileTypeSummaries": [
#         {
#           "count": 762,
#           "fileType": "fastq.gz",
#           "totalSize": 1306165450414
#         },
#         {
#           "count": 635,
#           "fileType": "unknown",
#           "totalSize": 7219422047
#         },
#         {
#           "count": 127,
#           "fileType": "bam",
#           "totalSize": 1237598776632
#         },
#         {
#           "count": 127,
#           "fileType": "matrix",
#           "totalSize": 18796
#         },
#         {
#           "count": 127,
#           "fileType": "csv",
#           "totalSize": 1949971768
#         }
#       ],
#       "organoids": [],
#       "projects": [
#         {
#           "arrayExpressAccessions": [
#             null
#           ],
#           "geoSeriesAccessions": [
#             null
#           ],
#           "insdcProjectAccessions": [
#             null
#           ],
#           "insdcStudyAccessions": [
#             null
#           ],
#           "laboratory": [
#             "Human Cell Atlas Data Coordination Platform",
#             "Regev Lab"
#           ],
#           "projectShortname": "1M Immune Cells",
#           "projectTitle": "Census of Immune Cells",
#           "supplementaryLinks": [
#             null
#           ]
#         }
#       ],
#       "protocols": [
#         {
#           "assayType": [
#             null
#           ],
#           "instrumentManufacturerModel": [
#             "Illumina HiSeq X",
#             null
#           ],
#           "libraryConstructionApproach": [
#             "10X v2 sequencing",
#             null
#           ],
#           "pairedEnd": [
#             false,
#             null
#           ],
#           "workflow": [
#             "optimus_v1.3.2",
#             null
#           ]
#         }
#       ],
#       "samples": [
#         {
#           "disease": [
#             null
#           ],
#           "effectiveOrgan": [
#             "blood",
#             "immune system"
#           ],
#           "id": [
#             "1_BM2",
#             "1_BM3",
#             "1_BM5",
#             "1_BM6",
#             "1_BM7",
#             "1_CB1",
#             "1_CB2",
#             "1_CB3",
#             "1_CB4",
#             "1_CB5",
#             "1_CB6",
#             "2_BM1",
#             "2_BM2",
#             "2_BM4",
#             "2_BM5",
#             "2_BM7",
#             "2_CB1",
#             "2_CB2",
#             "2_CB3",
#             "2_CB4",
#             "2_CB5",
#             "2_CB6",
#             "2_CB7",
#             "2_CB8",
#             "3_BM1",
#             "3_BM2",
#             "3_BM3",
#             "3_BM5",
#             "3_BM8",
#             "3_CB2",
#             "3_CB4",
#             "3_CB5",
#             "3_CB6",
#             "3_CB7",
#             "3_CB8",
#             "4_BM1",
#             "4_BM2",
#             "4_BM3",
#             "4_BM4",
#             "4_BM5",
#             "4_BM6",
#             "4_CB1",
#             "4_CB2",
#             "4_CB3",
#             "4_CB4",
#             "4_CB5",
#             "4_CB6",
#             "4_CB7",
#             "4_CB8",
#             "5_BM1",
#             "5_BM2",
#             "5_BM3",
#             "5_BM4",
#             "5_BM5",
#             "5_BM6",
#             "5_BM7",
#             "5_BM8",
#             "5_CB2",
#             "5_CB3",
#             "5_CB6",
#             "5_CB8",
#             "6_BM1",
#             "6_BM2",
#             "6_BM5",
#             "6_BM6",
#             "6_BM7",
#             "6_BM8",
#             "6_CB1",
#             "6_CB2",
#             "6_CB3",
#             "6_CB4",
#             "6_CB8",
#             "7_BM1",
#             "7_BM2",
#             "7_BM3",
#             "7_BM4",
#             "7_BM6",
#             "7_BM7",
#             "7_CB1",
#             "7_CB2",
#             "7_CB3",
#             "7_CB4",
#             "7_CB5",
#             "7_CB7",
#             "7_CB8",
#             "8_BM1",
#             "8_BM2",
#             "8_BM3",
#             "8_BM4",
#             "8_BM5",
#             "8_BM6",
#             "8_BM7",
#             "8_BM8",
#             "8_CB1",
#             "8_CB2",
#             "8_CB3",
#             "8_CB4",
#             "8_CB5",
#             "8_CB6",
#             "8_CB7"
#           ],
#           "organ": [
#             "blood",
#             "immune system"
#           ],
#           "organPart": [
#             "bone marrow",
#             "umbilical cord blood"
#           ],
#           "preservationMethod": [
#             null
#           ],
#           "sampleEntityType": [
#             "specimens"
#           ],
#           "source": [
#             "specimen_from_organism"
#           ]
#         }
#       ],
#       "specimens": [
#         {
#           "disease": [
#             null
#           ],
#           "id": [
#             "1_BM2",
#             "1_BM3",
#             "1_BM5",
#             "1_BM6",
#             "1_BM7",
#             "1_CB1",
#             "1_CB2",
#             "1_CB3",
#             "1_CB4",
#             "1_CB5",
#             "1_CB6",
#             "2_BM1",
#             "2_BM2",
#             "2_BM4",
#             "2_BM5",
#             "2_BM7",
#             "2_CB1",
#             "2_CB2",
#             "2_CB3",
#             "2_CB4",
#             "2_CB5",
#             "2_CB6",
#             "2_CB7",
#             "2_CB8",
#             "3_BM1",
#             "3_BM2",
#             "3_BM3",
#             "3_BM5",
#             "3_BM8",
#             "3_CB2",
#             "3_CB4",
#             "3_CB5",
#             "3_CB6",
#             "3_CB7",
#             "3_CB8",
#             "4_BM1",
# ...
#         },
#         {
#           "count": 1,
#           "term": "Precursors of human CD4+ cytotoxic T lymphocytes identified by single-cell transcriptome analysis"
#         },
#         {
#           "count": 1,
#           "term": "Profiling of CD34+ cells from human bone marrow to understand hematopoiesis"
#         },
#         {
#           "count": 1,
#           "term": "Reconstructing the human first trimester fetal-maternal interface using single cell transcriptomics"
#         },
#         {
#           "count": 1,
#           "term": "Single Cell Transcriptomics of a Human Kidney Allograft Biopsy Defines a Diverse Inflammatory Response"
#         },
#         {
#           "count": 1,
#           "term": "Single cell profiling of human induced dendritic cells generated by direct reprogramming of embryonic fibroblasts"
#         },
#         {
#           "count": 1,
#           "term": "Single cell transcriptome analysis of human pancreas reveals transcriptional signatures of aging and somatic mutation patterns."
#         },
#         {
#           "count": 1,
#           "term": "Single-cell RNA-seq analysis  throughout a 125-day differentiation protocol that converted H1 human embryonic stem cells to a variety of ventrally-derived cell types."
#         },
#         {
#           "count": 1,
#           "term": "Single-cell RNA-seq analysis of human pancreas from healthy individuals and type 2 diabetes patients"
#         },
#         {
#           "count": 1,
#           "term": "Spatio-temporal immune zonation of the human kidney"
#         },
#         {
#           "count": 1,
#           "term": "Structural Remodeling of the Human Colonic Mesenchyme in Inflammatory Bowel Disease"
#         },
#         {
#           "count": 1,
#           "term": "Systematic comparative analysis of single cell RNA-sequencing methods"
#         },
#         {
#           "count": 1,
#           "term": "Tabula Muris: Transcriptomic characterization of 20 organs and tissues from Mus musculus at single cell resolution"
#         },
#         {
#           "count": 1,
#           "term": "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#         },
#         {
#           "count": 1,
#           "term": "The emergent landscape of the mouse gut endoderm at single-cell resolution"
#         },
#         {
#           "count": 1,
#           "term": "Transcriptomic classification of human retinal cell types with single-nuclei RNA-seq."
#         }
#       ],
#       "total": 28,
#       "type": "terms"
#     },
#     "publicationTitle": {
#       "terms": [
#         {
#           "count": 7,
#           "term": null
#         },
#         {
#           "count": 1,
#           "term": "A single-cell molecular map of mouse gastrulation and early organogenesis"
#         },
#         {
#           "count": 1,
#           "term": "A single\u2010cell transcriptome atlas of the adult human retina"
#         },
#         {
#           "count": 1,
#           "term": "Cell Hashing with barcoded antibodies enables multiplexing and doublet detection for single cell genomics"
#         },
#         {
#           "count": 1,
#           "term": "Lung, spleen and oesophagus tissue remains stable for scRNAseq in cold preservation"
#         },
#         {
#           "count": 1,
#           "term": "Palantir characterizes cell fate continuities in human hematopoiesis"
#         },
#         {
#           "count": 1,
#           "term": "Precursors of human CD4+ cytotoxic T lymphocytes identified by single-cell transcriptome analysis."
#         },
#         {
#           "count": 1,
#           "term": "Single cell RNA sequencing of human liver reveals distinct intrahepatic macrophage populations"
#         },
#         {
#           "count": 1,
#           "term": "Single cell dissection of plasma cell heterogeneity in symptomatic and asymptomatic myeloma"
#         },
#         {
#           "count": 1,
#           "term": "Single-Cell Analysis of Human Pancreas Reveals Transcriptional Signatures of Aging and Somatic Mutation Patterns."
#         },
#         {
#           "count": 1,
#           "term": "Single-Cell Profiling of an In\u00a0Vitro Model of Human Interneuron Development Reveals Temporal Dynamics of Cell Type Production and Maturation."
#         },
#         {
#           "count": 1,
#           "term": "Single-Cell Transcriptome Profiling of Human Pancreatic Islets in Health and Type 2 Diabetes"
#         },
#         {
#           "count": 1,
#           "term": "Single-Cell Transcriptomics of a Human Kidney Allograft Biopsy Specimen Defines a Diverse Inflammatory Response"
#         },
#         {
#           "count": 1,
#           "term": "Single-cell RNA sequencing reveals a dynamic stromal niche within the evolving tumour microenvironment"
#         },
#         {
#           "count": 1,
#           "term": "Single-cell transcriptomics of 20 mouse organs creates a Tabula Muris"
#         },
#         {
#           "count": 1,
#           "term": "Spatiotemporal immune zonation of the human kidney"
#         },
#         {
#           "count": 1,
#           "term": "Structural Remodeling of the Human Colonic Mesenchyme in Inflammatory Bowel Disease"
#         },
#         {
#           "count": 1,
#           "term": "Systematic Comparison of High-throughput Single-Cell and  Single-Nucleus Transcriptomes during Cardiomyocyte Differentiation"
#         },
#         {
#           "count": 1,
#           "term": "Systematic comparative analysis of single cell RNA-sequencing methods"
#         },
#         {
#           "count": 1,
#           "term": "The Single Cell Transcriptomic Landscape of Early Human Diabetic Nephropathy"
#         },
#         {
#           "count": 1,
#           "term": "The emergent landscape of the mouse gut endoderm at single-cell resolution"
#         },
#         {
#           "count": 1,
#           "term": "Transcriptional profiling of 1.3 Million Brain Cells with the Chromium Single Cell 3' Solution"
#         },
#         {
#           "count": 1,
#           "term": "Transcriptomic characterization of 20 organs and tissues from mouse at single cell resolution creates a Tabula Muris"
#         }
#       ],
#       "total": 28,
#       "type": "terms"
#     },
#     "sampleEntityType": {
#       "terms": [
#         {
#           "count": 24,
#           "term": "specimens"
#         },
#         {
#           "count": 4,
#           "term": "cell_lines"
#         },
#         {
#           "count": 1,
#           "term": "organoids"
#         }
#       ],
#       "total": 28,
#       "type": "terms"
#     },
#     "selectedCellType": {
#       "terms": [
#         {
#           "count": 11,
#           "term": null
#         },
#         {
#           "count": 2,
#           "term": "CD8-positive, alpha-beta T cell"
#         },
#         {
#           "count": 2,
#           "term": "T cell"
#         },
#         {
#           "count": 2,
#           "term": "endothelial cell"
#         },
#         {
#           "count": 2,
#           "term": "epithelial cell"
#         },
#         {
#           "count": 2,
#           "term": "fibroblast"
#         },
#         {
#           "count": 2,
#           "term": "monocyte"
#         },
#         {
#           "count": 2,
#           "term": "myofibroblast cell"
#         },
#         {
#           "count": 2,
#           "term": "neuron"
#         },
#         {
#           "count": 2,
#           "term": "peripheral blood mononuclear cell"
#         },
#         {
#           "count": 1,
#           "term": "B cell"
#         },
#         {
#           "count": 1,
#           "term": "CAFs"
#         },
#         {
#           "count": 1,
#           "term": "CD11b+ Macrophages/monocytes"
#         },
#         {
#           "count": 1,
#           "term": "CD11b+CD11c+DC"
#         },
#         {
#           "count": 1,
#           "term": "CD11c+ DC"
#         },
#         {
#           "count": 1,
#           "term": "CD31+ endothelial"
#         },
#         {
#           "count": 1,
#           "term": "CD34-positive, CD38-negative hematopoietic stem cell"
#         },
#         {
#           "count": 1,
#           "term": "CD4+ T cell"
#         },
#         {
#           "count": 1,
#           "term": "CD45-"
#         },
#         {
#           "count": 1,
#           "term": "Epcam+"
#         },
#         {
#           "count": 1,
#           "term": "HLAG+"
#         },
#         {
#           "count": 1,
#           "term": "Plasma cell"
#         },
#         {
#           "count": 1,
#           "term": "bone marrow hematopoietic cell"
#         },
#         {
#           "count": 1,
#           "term": "cord blood hematopoietic stem cell"
#         },
#         {
#           "count": 1,
#           "term": "dendritic cell"
#         },
#         {
#           "count": 1,
#           "term": "effector memory CD8-positive, alpha-beta T cell, terminally differentiated"
#         },
#         {
#           "count": 1,
#           "term": "embryonic fibroblast"
#         },
#         {
#           "count": 1,
#           "term": "endodermal cell"
#         },
#         {
#           "count": 1,
#           "term": "epithelial cell of esophagus"
#         },
#         {
#           "count": 1,
#           "term": "inhibitory interneuron"
#         },
#         {
#           "count": 1,
#           "term": "innate lymphoid cell"
#         },
#         {
#           "count": 1,
#           "term": "kidney cell"
#         },
#         {
#           "count": 1,
#           "term": "leukocyte"
#         },
#         {
#           "count": 1,
#           "term": "live"
#         },
#         {
#           "count": 1,
#           "term": "mononuclear cell"
#         },
#         {
#           "count": 1,
#           "term": "myeloid cell"
#         },
#         {
#           "count": 1,
#           "term": "natural killer cell"
#         },
#         {
#           "count": 1,
#           "term": "neural cell"
#         },
#         {
#           "count": 1,
#           "term": "pancreatic PP cell"
#         },
#         {
#           "count": 1,
#           "term": "splenocyte"
#         },
#         {
#           "count": 1,
#           "term": "stromal cell"
#         }
#       ],
#       "total": 28,
#       "type": "terms"
#     },
#     "specimenDisease": {
#       "terms": [
#         {
#           "count": 15,
#           "term": "normal"
#         },
#         {
#           "count": 12,
#           "term": null
#         },
#         {
#           "count": 1,
#           "term": "colitis (disease)"
#         },
#         {
#           "count": 1,
#           "term": "end stage renal failure"
#         },
#         {
#           "count": 1,
#           "term": "hemolytic-uremic syndrome"
#         },
#         {
#           "count": 1,
#           "term": "orofaciodigital syndrome VIII"
#         },
#         {
#           "count": 1,
#           "term": "type 2 diabetes mellitus"
#         },
#         {
#           "count": 1,
#           "term": "ulcerative colitis (disease)"
#         }
#       ],
#       "total": 28,
#       "type": "terms"
#     },
#     "specimenOrgan": {
#       "terms": [
#         {
#           "count": 7,
#           "term": "blood"
#         },
#         {
#           "count": 4,
#           "term": "embryo"
#         },
#         {
#           "count": 4,
#           "term": "kidney"
#         },
#         {
#           "count": 4,
#           "term": "pancreas"
#         },
#         {
#           "count": 3,
#           "term": "brain"
#         },
#         {
#           "count": 3,
#           "term": "hematopoietic system"
#         },
#         {
#           "count": 3,
#           "term": "lung"
#         },
#         {
#           "count": 3,
#           "term": "skin of body"
#         },
#         {
#           "count": 2,
#           "term": "eye"
#         },
#         {
#           "count": 2,
#           "term": "liver"
#         },
#         {
#           "count": 2,
#           "term": "spleen"
#         },
#         {
#           "count": 1,
#           "term": "adipose tissue"
#         },
#         {
#           "count": 1,
#           "term": "bladder organ"
#         },
#         {
#           "count": 1,
#           "term": "bone tissue"
#         },
#         {
#           "count": 1,
#           "term": "colon"
#         },
#         {
#           "count": 1,
#           "term": "decidua"
#         },
#         {
#           "count": 1,
#           "term": "diaphragm"
#         },
#         {
#           "count": 1,
#           "term": "endoderm"
#         },
#         {
#           "count": 1,
#           "term": "esophagus"
#         },
#         {
#           "count": 1,
#           "term": "heart"
#         },
#         {
#           "count": 1,
#           "term": "immune system"
#         },
#         {
#           "count": 1,
#           "term": "large intestine"
#         },
#         {
#           "count": 1,
#           "term": "lymph node"
#         },
#         {
#           "count": 1,
#           "term": "mammary gland"
#         },
#         {
#           "count": 1,
#           "term": "mediastinal lymph node"
#         },
#         {
#           "count": 1,
#           "term": "muscle organ"
#         },
#         {
#           "count": 1,
#           "term": "placenta"
#         },
#         {
#           "count": 1,
#           "term": "presumptive gut"
#         },
#         {
#           "count": 1,
#           "term": "thymus"
#         },
#         {
#           "count": 1,
#           "term": "tongue"
#         },
#         {
#           "count": 1,
#           "term": "trachea"
#         },
#         {
#           "count": 1,
#           "term": "tumor"
#         }
#       ],
#       "total": 28,
#       "type": "terms"
#     },
#     "specimenOrganPart": {
#       "terms": [
#         {
#           "count": 9,
#           "term": null
#         },
#         {
#           "count": 4,
#           "term": "bone marrow"
#         },
#         {
#           "count": 3,
#           "term": "cortex"
#         },
#         {
#           "count": 3,
#           "term": "venous blood"
#         },
#         {
#           "count": 2,
#           "term": "cortex of kidney"
#         },
#         {
#           "count": 2,
#           "term": "islet of Langerhans"
#         },
#         {
#           "count": 2,
#           "term": "skin epidermis"
#         },
#         {
#           "count": 1,
#           "term": "Left lateral basal bronchopulmonary segment"
#         },
#         {
#           "count": 1,
#           "term": "blastocyst"
#         },
#         {
#           "count": 1,
#           "term": "caudate lobe"
#         },
#         {
#           "count": 1,
#           "term": "definitive endoderm"
#         },
#         {
#           "count": 1,
#           "term": "esophagus mucosa"
#         },
#         {
#           "count": 1,
#           "term": "fovea centralis"
#         },
#         {
#           "count": 1,
#           "term": "lamina propria of mucosa of colon"
#         },
#         {
#           "count": 1,
#           "term": "lower lobe of left lung"
#         },
#         {
#           "count": 1,
#           "term": "lower lobe of right lung"
#         },
#         {
#           "count": 1,
#           "term": "lung parenchyma"
#         },
#         {
#           "count": 1,
#           "term": "mediastinal lymph node"
#         },
#         {
#           "count": 1,
#           "term": "parietal endoderm"
#         },
#         {
#           "count": 1,
#           "term": "peripheral blood mononuclear cell"
#         },
#         {
#           "count": 1,
#           "term": "renal medulla"
#         },
#         {
#           "count": 1,
#           "term": "renal pelvis"
#         },
#         {
#           "count": 1,
#           "term": "retina"
#         },
#         {
#           "count": 1,
#           "term": "retinal neural layer"
#         },
#         {
#           "count": 1,
#           "term": "umbilical cord blood"
#         },
#         {
#           "count": 1,
#           "term": "ureter"
#         },
#         {
#           "count": 1,
#           "term": "visceral endoderm"
#         },
#         {
#           "count": 1,
#           "term": "yolk sac endoderm"
#         }
#       ],
#       "total": 28,
#       "type": "terms"
#     },
#     "workflow": {
#       "terms": [
#         {
#           "count": 28,
#           "term": null
#         },
#         {
#           "count": 7,
#           "term": "optimus_v1.3.5"
#         },
#         {
#           "count": 4,
#           "term": "optimus_v1.3.2"
#         },
#         {
#           "count": 4,
#           "term": "smartseq2_v2.4.0"
#         },
#         {
#           "count": 3,
#           "term": "optimus_v1.3.1"
#         },
#         {
#           "count": 3,
#           "term": "smartseq2_v2.3.0"
#         },
#         {
#           "count": 1,
#           "term": "optimus_v1.3.3"
#         }
#       ],
#       "total": 28,
#       "type": "terms"
#     }
#   }
# }

# %%
import time

project_hits = []

for hit in answer.json()["hits"]:
    entry_id = hit["entryId"]
    print("Getting " + entry_id + "...")
    time.sleep(2)
    seed_url = "https://service.explore.data.humancellatlas.org/repository/projects/" + entry_id
    
    answer_project = requests.get(seed_url, headers=headers)
    project_hits.append(answer_project.json())
    
print(len(project_hits))
# Out:
# Getting 74b6d569-3b11-42ef-b6b1-a0454522b4a0...
# Getting f86f1ab4-1fbb-4510-ae35-3ffd752d4dfc...
# Getting 1defdada-a365-44ad-9b29-443b06bd11d6...
# Getting 4a95101c-9ffc-4f30-a809-f04518a23803...
# Getting 8185730f-4113-40d3-9cc3-929271784c2b...
# Getting 005d611a-14d5-4fbf-846e-571a1f874f70...
# Getting a29952d9-925e-40f4-8a1c-274f118f1f51...
# Getting f81efc03-9f56-4354-aabb-6ce819c3d414...
# Getting cc95ff89-2e68-4a08-a234-480eca21ce79...
# Getting a9c022b4-c771-4468-b769-cabcf9738de3...
# Getting 4d6f6c96-2a83-43d8-8fe1-0f53bffd4674...
# Getting c4077b3c-5c98-4d26-a614-246d12c2e5d7...
# Getting 8c3c290d-dfff-4553-8868-54ce45f4ba7f...
# Getting 90bd6933-40c0-48d4-8d76-778c103bf545...
# Getting 091cf39b-01bc-42e5-9437-f419a66c8a45...
# Getting f83165c5-e2ea-4d15-a5cf-33f3550bffde...
# Getting 027c51c6-0719-469f-a7f5-640fe57cbece...
# Getting 116965f3-f094-4769-9d28-ae675c1b569c...
# Getting cddab57b-6868-4be4-806f-395ed9dd635a...
# Getting 2043c65a-1cf8-4828-a656-9e247d4e64f1...
# Getting ae71be1d-ddd8-4feb-9bed-24c3ddb6e1ad...
# Getting abe1a013-af7a-45ed-8c26-f3793c24a1f4...
# Getting f8aa201c-4ff1-45a4-890e-840d63459ca2...
# Getting 88ec040b-8705-4f77-8f41-f81e57632f7d...
# Getting e0009214-c0a0-4a7b-96e2-d6a83e966ce0...
# Getting 577c946d-6de5-4b55-a854-cd3fde40bff2...
# Getting 4e6f083b-5b9a-4393-9890-2a83da8188f1...
# Getting 9c20a245-f2c0-43ae-82c9-2232ec6b594f...
# 28

# %%
with open('../SingleCell-Files/projects_raw.json', 'w') as outfile:
    json.dump({"hits": project_hits}, outfile)

# %%
# print(json.dumps(project_hits[0], indent=2))

# %%
hits_processed = list(map(ont_creator.create_hca_project, project_hits))

# print(json.dumps(hits_processed, indent=2))

# %%
json_processed['projects'] = hits_processed

# %%
with open('../SingleCell-Files/hits_processed.json', 'w') as outfile:
    json.dump(json_processed, outfile)
