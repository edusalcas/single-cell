# %%
import requests
import pandas as pd
import urllib.parse
import json
import time

from IPython.display import clear_output
from GetTermsOntobee import get_URI_from_name, get_name_from_URI

# %%
def get_first(l):
    if len(l) > 0:
        return l[0]
    
    return None

# %%
def get_cell_info(cell_URI):
    
    print(cell_URI)
    
    if cell_URI is None or cell_URI == 'http://purl.obolibrary.org/obo/NCIT_C48660':
        return None, None, None, None
    
    query = f'''
    DEFINE sql:describe-mode "CBD"
    DESCRIBE <{cell_URI}>
    FROM <http://purl.obolibrary.org/obo/merged/CL>
    '''
    query_parsed = urllib.parse.quote(query)
    
    headers = {
        "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
    }
    url = f"http://sparql.hegroup.org/sparql/?default-graph-uri=&query={query_parsed}&format=application%2Fsparql-results%2Bjson&timeout=0&debug=on"
    answer = requests.get(url, headers=headers)
    
    time.sleep(2)
    
    columns = answer.json()["head"]["vars"]
    results = answer.json()["results"]

    rows = []

    for result in answer.json()["results"]["bindings"]:
        result_dict = {}
        for header in columns:
            result_dict[header] = result[header]['value']

        rows.append(result_dict)

    df = pd.DataFrame(rows)
    if df.empty:
        return None, None, None, None
    
    df['p'] = df['p'].apply(lambda x: x.split('#')[1] if len(x.split('#')) > 1 else x)
    
    synonym = get_first(df[df['p'] == 'hasExactSynonym']['o'].tolist())
    comment = get_first(df[df['p'] == 'comment']['o'].tolist())
    super_classes = [x for x in df[df['p'] == 'subClassOf']['o'].tolist() if x.startswith('http')]
    asserts = df[df['p'] == 'someValuesFrom']['o'].tolist()
    
    return synonym, comment, super_classes, asserts

# %%
seed_url = "https://www.ebi.ac.uk/gxa/sc/json/experiments"

# %%
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)

# %%
avoid_collections = ["Human Cell Atlas"]

cell_types = []
cell_types_names = []
relations = []

n_experiments = len(answer.json()['experiments'])

for n, experiment in enumerate(answer.json()['experiments']):
    print(f"{n+1}/{n_experiments}")

    experiment_id = experiment['experimentAccession']
    experiment_metadata = f"https://www.ebi.ac.uk/gxa/sc/experiment/{experiment_id}/download?fileType=experiment-design&accessKey="
    
    df = pd.read_csv(experiment_metadata, sep='\t', low_memory=False)
    
    if 'Sample Characteristic[cell type]' in df.columns:
        cell_type_names = df['Sample Characteristic[cell type]'].unique()
        cell_type_URIs = df['Sample Characteristic Ontology Term[cell type]'].unique()
    
    
        for name, URI in zip(cell_type_names, cell_type_URIs):
            if name in cell_types_names:
                continue
            
            if URI is None:
                URI = get_URI_from_name(name, 'CL')
            
            if URI is None:
                continue
            
            synonym, comment, superclasses, asserts = get_cell_info(URI)
            cell_types_names.append(name)
            
            if superclasses:
            
                for superclass in superclasses:
                    cell_types.append({
                        'name': name,
                        'URI': URI,
                        'synonym': synonym,
                        'comment': comment,
                        'superclass': superclass,
                        'asserts': None
                    })

                    superclass_URI = get_URI_from_name(superclass, 'CL')
                    relations.append({
                        'subclass': name,
                        'subclass_URI': URI,
                        'superclass': superclass,
                        'superclass_URI': superclass_URI
                    })
            
            if asserts:

                for a in asserts:
                    cell_types.append({
                        'name': name,
                        'URI': URI,
                        'synonym': synonym,
                        'comment': comment,
                        'superclass': None,
                        'asserts': a
                    })

    time.sleep(2)
    
    clear_output(wait=True)

df_ct = pd.DataFrame(cell_types)
df_relations = pd.DataFrame(relations)
# Out:
# 181/181

# %%
df_ct
# Out:
#                 name                                        URI  \
# 0    epithelial cell  http://purl.obolibrary.org/obo/CL_0000066
# 1    epithelial cell  http://purl.obolibrary.org/obo/CL_0000066
# 2    epithelial cell  http://purl.obolibrary.org/obo/CL_0000066
# 3         protoplast  http://purl.obolibrary.org/obo/CL_0000371
# 4           hemocyte  http://purl.obolibrary.org/obo/CL_0000387
# ..               ...                                        ...
# 445       macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 446       macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 447       macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 448       macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 449       macrophage  http://purl.obolibrary.org/obo/CL_0000235
#
#            synonym                                            comment  \
# 0    epitheliocyte                                               None
# 1    epitheliocyte                                               None
# 2    epitheliocyte                                               None
# 3             None                                               None
# 4             None                                               None
# ..             ...                                                ...
# 445     histiocyte  Morphology: Diameter 30_M-80 _M, abundant cyto...
# 446     histiocyte  Morphology: Diameter 30_M-80 _M, abundant cyto...
# 447     histiocyte  Morphology: Diameter 30_M-80 _M, abundant cyto...
# 448     histiocyte  Morphology: Diameter 30_M-80 _M, abundant cyto...
# 449     histiocyte  Morphology: Diameter 30_M-80 _M, abundant cyto...
#
#                                     superclass  \
# 0    http://purl.obolibrary.org/obo/CL_0000548
# 1                                         None
# 2                                         None
# 3    http://purl.obolibrary.org/obo/CL_0000578
# 4    http://purl.obolibrary.org/obo/CL_0000519
# ..                                         ...
# 445                                       None
# 446                                       None
# 447                                       None
# 448                                       None
# 449                                       None
#
#                                            asserts
# 0                                             None
# 1    http://purl.obolibrary.org/obo/UBERON_0000483
# 2    http://purl.obolibrary.org/obo/UBERON_0000483
# 3                                             None
# 4                                             None
# ..                                             ...
# 445      http://purl.obolibrary.org/obo/GO_0031268
# 446      http://purl.obolibrary.org/obo/CL_0000576
# 447      http://purl.obolibrary.org/obo/GO_0006909
# 448      http://purl.obolibrary.org/obo/GO_0031268
# 449      http://purl.obolibrary.org/obo/GO_0002504
#
# [450 rows x 6 columns]

# %%
df_relations
# Out:
#              subclass                               subclass_URI  \
# 0     epithelial cell  http://purl.obolibrary.org/obo/CL_0000066
# 1          protoplast  http://purl.obolibrary.org/obo/CL_0000371
# 2            hemocyte  http://purl.obolibrary.org/obo/CL_0000387
# 3            hemocyte  http://purl.obolibrary.org/obo/CL_0000387
# 4    bone marrow cell  http://purl.obolibrary.org/obo/CL_0002092
# ..                ...                                        ...
# 97          adipocyte  http://purl.obolibrary.org/obo/CL_0000136
# 98       preadipocyte  http://purl.obolibrary.org/obo/CL_0002334
# 99         macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 100        macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 101        macrophage  http://purl.obolibrary.org/obo/CL_0000235
#
#                                     superclass  \
# 0    http://purl.obolibrary.org/obo/CL_0000548
# 1    http://purl.obolibrary.org/obo/CL_0000578
# 2    http://purl.obolibrary.org/obo/CL_0000519
# 3    http://purl.obolibrary.org/obo/CL_0000548
# 4    http://purl.obolibrary.org/obo/CL_0001035
# ..                                         ...
# 97   http://purl.obolibrary.org/obo/CL_0002320
# 98   http://purl.obolibrary.org/obo/CL_0000057
# 99   http://purl.obolibrary.org/obo/CL_0000145
# 100  http://purl.obolibrary.org/obo/CL_0000766
# 101  http://purl.obolibrary.org/obo/CL_0000234
#
#                                 superclass_URI
# 0    http://purl.obolibrary.org/obo/CL_0000548
# 1    http://purl.obolibrary.org/obo/CL_0000578
# 2    http://purl.obolibrary.org/obo/CL_0000519
# 3    http://purl.obolibrary.org/obo/CL_0000548
# 4    http://purl.obolibrary.org/obo/CL_0001035
# ..                                         ...
# 97   http://purl.obolibrary.org/obo/CL_0002320
# 98   http://purl.obolibrary.org/obo/CL_0000057
# 99   http://purl.obolibrary.org/obo/CL_0000145
# 100  http://purl.obolibrary.org/obo/CL_0000766
# 101  http://purl.obolibrary.org/obo/CL_0000234
#
# [102 rows x 4 columns]

# %%
df_ct.to_csv('../SingleCell-Files/cell_types.csv', index=False)
df_relations.to_csv('../SingleCell-Files/cell_types_relations.csv', index=False)

# %%
get_name_from_URI('http://purl.obolibrary.org/obo/CL_0000548', 'CL')
# Out:
# 'animal cell'

# %%
df_relations = pd.read_csv('../SingleCell-Files/cell_types_relations.csv')

# %%
df_relations['superclass'] = df_relations['superclass'].apply(get_name_from_URI)

# %%
df_relations
# Out:
#              subclass                               subclass_URI  \
# 0     epithelial cell  http://purl.obolibrary.org/obo/CL_0000066
# 1          protoplast  http://purl.obolibrary.org/obo/CL_0000371
# 2            hemocyte  http://purl.obolibrary.org/obo/CL_0000387
# 3            hemocyte  http://purl.obolibrary.org/obo/CL_0000387
# 4    bone marrow cell  http://purl.obolibrary.org/obo/CL_0002092
# ..                ...                                        ...
# 97          adipocyte  http://purl.obolibrary.org/obo/CL_0000136
# 98       preadipocyte  http://purl.obolibrary.org/obo/CL_0002334
# 99         macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 100        macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 101        macrophage  http://purl.obolibrary.org/obo/CL_0000235
#
#                                      superclass  \
# 0                                   animal cell
# 1         experimentally modified cell in vitro
# 2    phagocyte (sensu Nematoda and Protostomia)
# 3                                   animal cell
# 4                                     bone cell
# ..                                          ...
# 97                       connective tissue cell
# 98                                   fibroblast
# 99         professional antigen presenting cell
# 100                           myeloid leukocyte
# 101                                   phagocyte
#
#                                 superclass_URI
# 0    http://purl.obolibrary.org/obo/CL_0000548
# 1    http://purl.obolibrary.org/obo/CL_0000578
# 2    http://purl.obolibrary.org/obo/CL_0000519
# 3    http://purl.obolibrary.org/obo/CL_0000548
# 4    http://purl.obolibrary.org/obo/CL_0001035
# ..                                         ...
# 97   http://purl.obolibrary.org/obo/CL_0002320
# 98   http://purl.obolibrary.org/obo/CL_0000057
# 99   http://purl.obolibrary.org/obo/CL_0000145
# 100  http://purl.obolibrary.org/obo/CL_0000766
# 101  http://purl.obolibrary.org/obo/CL_0000234
#
# [102 rows x 4 columns]

# %%
df_relations.to_excel('../SingleCell-Files/cell_types_relations.xlsx', index=False)

# %%
df_ct = pd.read_csv('../SingleCell-Files/cell_types.csv')
df_ct['superclass'] = df_ct['superclass'].apply(get_name_from_URI)
df_ct
# Out:
#                 name                                        URI  \
# 0    epithelial cell  http://purl.obolibrary.org/obo/CL_0000066
# 1    epithelial cell  http://purl.obolibrary.org/obo/CL_0000066
# 2    epithelial cell  http://purl.obolibrary.org/obo/CL_0000066
# 3         protoplast  http://purl.obolibrary.org/obo/CL_0000371
# 4           hemocyte  http://purl.obolibrary.org/obo/CL_0000387
# ..               ...                                        ...
# 445       macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 446       macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 447       macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 448       macrophage  http://purl.obolibrary.org/obo/CL_0000235
# 449       macrophage  http://purl.obolibrary.org/obo/CL_0000235
#
#            synonym                                            comment  \
# 0    epitheliocyte                                                NaN
# 1    epitheliocyte                                                NaN
# 2    epitheliocyte                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# ..             ...                                                ...
# 445     histiocyte  Morphology: Diameter 30_M-80 _M, abundant cyto...
# 446     histiocyte  Morphology: Diameter 30_M-80 _M, abundant cyto...
# 447     histiocyte  Morphology: Diameter 30_M-80 _M, abundant cyto...
# 448     histiocyte  Morphology: Diameter 30_M-80 _M, abundant cyto...
# 449     histiocyte  Morphology: Diameter 30_M-80 _M, abundant cyto...
#
#                                      superclass  \
# 0                                   animal cell
# 1                            neoplastic, maligt
# 2                            neoplastic, maligt
# 3         experimentally modified cell in vitro
# 4    phagocyte (sensu Nematoda and Protostomia)
# ..                                          ...
# 445                          neoplastic, maligt
# 446                          neoplastic, maligt
# 447                          neoplastic, maligt
# 448                          neoplastic, maligt
# 449                          neoplastic, maligt
#
#                                            asserts
# 0                                              NaN
# 1    http://purl.obolibrary.org/obo/UBERON_0000483
# 2    http://purl.obolibrary.org/obo/UBERON_0000483
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 445      http://purl.obolibrary.org/obo/GO_0031268
# 446      http://purl.obolibrary.org/obo/CL_0000576
# 447      http://purl.obolibrary.org/obo/GO_0006909
# 448      http://purl.obolibrary.org/obo/GO_0031268
# 449      http://purl.obolibrary.org/obo/GO_0002504
#
# [450 rows x 6 columns]

# %%
df_ct.to_excel('../SingleCell-Files/cell_types.xlsx', index=False)
