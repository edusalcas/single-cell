# %%
import requests
import pandas as pd
import urllib.parse
import json
import time
import re

from IPython.display import clear_output
from GetTermsOntobee import get_URI_from_name, get_name_from_URI

# %% [markdown]
# # SCEA organism parts

# %%
seed_url = "https://www.ebi.ac.uk/gxa/sc/json/experiments"

# %%
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)

# %%
def get_terms_from_project(experiment_id, name_column, ontology_column):
    terms = []
    terms_names = []
    
    experiment_metadata = f"https://www.ebi.ac.uk/gxa/sc/experiment/{experiment_id}/download?fileType=experiment-design&accessKey="
    
    df = pd.read_csv(experiment_metadata, sep='\t', low_memory=False)
            
    if name_column in df.columns:
        project_term_names = df[name_column].unique()
        project_term_URIs = df[ontology_column].unique()
    
        # Balance names and URIs
        project_term_URIs = list(project_term_URIs)
        project_term_URIs += [None] * (len(project_term_names) - len(project_term_URIs))
        
        for name, URI in zip(project_term_names, project_term_URIs):
            # If we have already code the cell_type we skip it
            if name in terms_names:
                continue
            
            print(name)
            
            # If we have no info of URI we search for it
            if URI is None or str(URI) == 'nan':
                URI = get_URI_from_name(name)
                time.sleep(1)
            
            # If there are two cell types in the name
            if URI is None:
                new_l = re.split(' and |, |; ', name)
                for new_name in new_l:
                    URI = get_URI_from_name(new_name)
                    time.sleep(1)
                    
                    terms_names.append(new_name)

                    terms.append({
                        'name': new_name,
                        'URI': URI
                    })
            # Otherwise   
            else:                    
                terms_names.append(name)

                terms.append({
                    'name': name,
                    'URI': URI
                })
    return terms, terms_names

# %%
organism_parts = []
organism_part_names = []
avoid_collections = ["Human Cell Atlas"]

n_experiments = len(answer.json()['experiments'])

for n, experiment in enumerate(answer.json()['experiments']):
    print(f"{n+1}/{n_experiments}")

    if [i for i in experiment["experimentProjects"] if i in avoid_collections]:
        clear_output(wait=True)
        continue
    
    experiment_id = experiment['experimentAccession']
    organism_parts_pro, organism_part_names_pro = get_terms_from_project(experiment_id=experiment_id, 
                                                             name_column='Sample Characteristic[organism part]', 
                                                             ontology_column='Sample Characteristic Ontology Term[organism part]')
    
    organism_parts += organism_parts_pro
    organism_part_names += organism_part_names_pro
    
    clear_output(wait=True)

df_SCEA = pd.DataFrame(organism_parts)
# Out:
# 181/181
# blood

# %%
df_SCEA[df_SCEA.isnull().any(axis=1)].name.tolist()
# Out:
# ['peri-urethral mesenchyme',
#  'dorsal medial ganglionic eminence',
#  'brain without olfactory bulb',
#  'brain without olfactory bulb']

# %%
from OntologyConversorSCAE import OntologyConversorSCAE

conversor_SCAE = OntologyConversorSCAE()

# %%
df = df_SCEA
df['name'] = df['name'].apply(conversor_SCAE.parse_word)
df
# Out:
#                       name                                            URI
# 0                   Kidney  http://purl.obolibrary.org/obo/UBERON_0002113
# 1               Bronchiole  http://purl.obolibrary.org/obo/UBERON_0002186
# 2    MiddleLobeOfRightLung  http://purl.obolibrary.org/obo/UBERON_0002174
# 3                     Lung  http://purl.obolibrary.org/obo/UBERON_0002048
# 4               PedalDigit  http://purl.obolibrary.org/obo/UBERON_0006051
# ..                     ...                                            ...
# 232               Pancreas  http://purl.obolibrary.org/obo/UBERON_0001264
# 233        PeritonealFluid  http://purl.obolibrary.org/obo/UBERON_0001268
# 234              Hemolymph   http://purl.obolibrary.org/obo/FBbt_00001683
# 235                  Heart  http://purl.obolibrary.org/obo/UBERON_0000948
# 236                  Blood  http://purl.obolibrary.org/obo/UBERON_0000178
#
# [237 rows x 2 columns]

# %% [markdown]
# # HCA diseases

# %%
seed_url = "https://service.azul.data.humancellatlas.org/index/projects?size=999&catalog=dcp1"

# %%
# User-Agent obtenido del recurso del curso.
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)
project_hits = answer.json()["hits"]

# %%
n_projects = len(project_hits)

organism_parts = []

for n, hit in enumerate(project_hits):
    print(n)
    
    for item in hit['specimens']:
        organism_parts += item['organ']
        organism_parts += item['organPart']
        
    clear_output(wait=True)
    
organism_parts = list(set(organism_parts))
# Out:
# 27

# %%
organism_parts = [x for x in organism_parts if x is not None]
organism_parts
# Out:
# ['bone marrow',
#  'diaphragm',
#  'bladder organ',
#  'umbilical cord blood',
#  'thymus',
#  'ureter',
#  'Left lateral basal bronchopulmonary segment',
#  'renal pelvis',
#  'definitive endoderm',
#  'parietal endoderm',
#  'adipose tissue',
#  'mammary gland',
#  'fovea centralis',
#  'visceral endoderm',
#  'blood',
#  'islet of Langerhans',
#  'lamina propria of mucosa of colon',
#  'bone tissue',
#  'cortex of kidney',
#  'renal medulla',
#  'brain',
#  'pancreas',
#  'lower lobe of right lung',
#  'caudate lobe',
#  'liver',
#  'spleen',
#  'skin epidermis',
#  'cortex',
#  'decidua',
#  'placenta',
#  'lower lobe of left lung',
#  'presumptive gut',
#  'blastocyst',
#  'skin of body',
#  'lung',
#  'esophagus',
#  'tongue',
#  'heart',
#  'retinal neural layer',
#  'immune system',
#  'embryo',
#  'esophagus mucosa',
#  'lung parenchyma',
#  'large intestine',
#  'tumor',
#  'venous blood',
#  'colon',
#  'mediastinal lymph node',
#  'kidney',
#  'eye',
#  'endoderm',
#  'peripheral blood mononuclear cell',
#  'muscle organ',
#  'retina',
#  'trachea',
#  'lymph node',
#  'hematopoietic system',
#  'yolk sac endoderm']

# %%
organism_parts_URIs = list(map(get_URI_from_name, organism_parts))
organism_parts_URIs
# Out:
# ['http://purl.obolibrary.org/obo/UBERON_0002371',
#  'http://purl.obolibrary.org/obo/UBERON_0001103',
#  'http://purl.obolibrary.org/obo/UBERON_0018707',
#  'http://purl.obolibrary.org/obo/UBERON_0012168',
#  'http://purl.obolibrary.org/obo/UBERON_0002370',
#  'http://purl.obolibrary.org/obo/UBERON_0000056',
#  'http://purl.obolibrary.org/obo/FMA_7379',
#  'http://purl.obolibrary.org/obo/UBERON_0001224',
#  'http://purl.obolibrary.org/obo/UBERON_0005439',
#  'http://purl.obolibrary.org/obo/UBERON_0008800',
#  'http://purl.obolibrary.org/obo/UBERON_0001013',
#  'http://purl.obolibrary.org/obo/UBERON_0001911',
#  'http://purl.obolibrary.org/obo/UBERON_0001786',
#  'http://purl.obolibrary.org/obo/UBERON_0004877',
#  'http://purl.obolibrary.org/obo/NCRO_0000105',
#  'http://purl.obolibrary.org/obo/UBERON_0000006',
#  'http://purl.obolibrary.org/obo/UBERON_0007177',
#  'http://purl.obolibrary.org/obo/UBERON_0002481',
#  'http://purl.obolibrary.org/obo/UBERON_0001225',
#  'http://purl.obolibrary.org/obo/UBERON_0000362',
#  'http://purl.obolibrary.org/obo/UBERON_0000955',
#  'http://purl.obolibrary.org/obo/UBERON_0001264',
#  'http://purl.obolibrary.org/obo/UBERON_0002171',
#  'http://purl.obolibrary.org/obo/EHDA_10432',
#  'http://purl.obolibrary.org/obo/UBERON_0002107',
#  'http://purl.obolibrary.org/obo/UBERON_0002106',
#  'http://purl.obolibrary.org/obo/UBERON_0001003',
#  'http://purl.obolibrary.org/obo/PO_0005708',
#  'http://purl.obolibrary.org/obo/UBERON_0002450',
#  'http://purl.obolibrary.org/obo/BTO_0001078',
#  'http://purl.obolibrary.org/obo/UBERON_0008953',
#  'http://purl.obolibrary.org/obo/UBERON_0007026',
#  'http://purl.obolibrary.org/obo/UBERON_0000358',
#  'http://purl.obolibrary.org/obo/UBERON_0002097',
#  'http://purl.obolibrary.org/obo/UBERON_0002048',
#  'http://purl.obolibrary.org/obo/UBERON_0001043',
#  'http://purl.obolibrary.org/obo/UBERON_0001723',
#  'http://purl.obolibrary.org/obo/UBERON_0000948',
#  'http://purl.obolibrary.org/obo/UBERON_0003902',
#  'http://purl.obolibrary.org/obo/UBERON_0002405',
#  'http://purl.obolibrary.org/obo/IDOMAL_0000646',
#  'http://purl.obolibrary.org/obo/UBERON_0002469',
#  'http://purl.obolibrary.org/obo/UBERON_0008946',
#  'http://purl.obolibrary.org/obo/UBERON_0000059',
#  'http://purl.obolibrary.org/obo/ICDO_0000104',
#  'http://purl.obolibrary.org/obo/UBERON_0013756',
#  'http://purl.obolibrary.org/obo/UBERON_0001155',
#  'http://purl.obolibrary.org/obo/UBERON_0002524',
#  'http://purl.obolibrary.org/obo/UBERON_0002113',
#  'http://purl.obolibrary.org/obo/OMIT_0006347',
#  'http://purl.obolibrary.org/obo/NCRO_0000112',
#  'http://purl.obolibrary.org/obo/CL_2000001',
#  'http://purl.obolibrary.org/obo/UBERON_0001630',
#  'http://purl.obolibrary.org/obo/UBERON_0000966',
#  'http://purl.obolibrary.org/obo/UBERON_0003126',
#  'http://purl.obolibrary.org/obo/BTO_0000784',
#  'http://purl.obolibrary.org/obo/UBERON_0002390',
#  'http://purl.obolibrary.org/obo/UBERON_0003257']

# %%
from OntologyConversorHCA import OntologyConversorHCA

conversor_HCA = OntologyConversorHCA()

# %%
organism_parts = list(map(conversor_HCA.parse_word, organism_parts))
organism_parts
# Out:
# ['BoneMarrow',
#  'Diaphragm',
#  'Bladder',
#  'UmbilicalCordBlood',
#  'Thymus',
#  'Ureter',
#  'LeftLateralBasalBronchopulmonarySegment',
#  'RenalPelvis',
#  'DefinitiveEndoderm',
#  'ParietalEndoderm',
#  'AdiposeTissue',
#  'MammaryGland',
#  'FoveaCentralis',
#  'VisceralEndoderm',
#  'Blood',
#  'IsletOfLangerhans',
#  'LaminaPropriaOfMucosaOfColon',
#  'BoneTissue',
#  'CortexOfKidney',
#  'RenalMedulla',
#  'Brain',
#  'Pancreas',
#  'LowerLobeOfRightLung',
#  'CaudateLobe',
#  'Liver',
#  'Spleen',
#  'Epidermis',
#  'Cortex',
#  'Decidua',
#  'Placenta',
#  'LowerLobeOfLeftLung',
#  'presumptiveGut',
#  'Blastocyst',
#  'Skin',
#  'Lung',
#  'Esophagus',
#  'Tongue',
#  'Heart',
#  'RetinalNeuralLayer',
#  'ImmuneSystem',
#  'Embryo',
#  'EsophagusMucosa',
#  'LungParenchyma',
#  'LargeIntestine',
#  'Tumor',
#  'VenousBlood',
#  'Colon',
#  'MediastinalLymphNode',
#  'Kidney',
#  'Eye',
#  'Endoderm',
#  'PeripheralBloodMononuclearCell',
#  'Muscle',
#  'Retina',
#  'Trachea',
#  'LymphNode',
#  'HematopoieticSystem',
#  'YolkSacEndoderm']

# %%
rows = pd.DataFrame({'name': organism_parts, 'URI': organism_parts_URIs})
rows
# Out:
#                                        name  \
# 0                                BoneMarrow
# 1                                 Diaphragm
# 2                                   Bladder
# 3                        UmbilicalCordBlood
# 4                                    Thymus
# 5                                    Ureter
# 6   LeftLateralBasalBronchopulmonarySegment
# 7                               RenalPelvis
# 8                        DefinitiveEndoderm
# 9                          ParietalEndoderm
# 10                            AdiposeTissue
# 11                             MammaryGland
# 12                           FoveaCentralis
# 13                         VisceralEndoderm
# 14                                    Blood
# 15                        IsletOfLangerhans
# 16             LaminaPropriaOfMucosaOfColon
# 17                               BoneTissue
# 18                           CortexOfKidney
# 19                             RenalMedulla
# 20                                    Brain
# 21                                 Pancreas
# 22                     LowerLobeOfRightLung
# 23                              CaudateLobe
# 24                                    Liver
# 25                                   Spleen
# 26                                Epidermis
# 27                                   Cortex
# 28                                  Decidua
# 29                                 Placenta
# 30                      LowerLobeOfLeftLung
# 31                           presumptiveGut
# 32                               Blastocyst
# 33                                     Skin
# 34                                     Lung
# 35                                Esophagus
# 36                                   Tongue
# 37                                    Heart
# 38                       RetinalNeuralLayer
# 39                             ImmuneSystem
# 40                                   Embryo
# 41                          EsophagusMucosa
# 42                           LungParenchyma
# 43                           LargeIntestine
# 44                                    Tumor
# 45                              VenousBlood
# 46                                    Colon
# 47                     MediastinalLymphNode
# 48                                   Kidney
# 49                                      Eye
# 50                                 Endoderm
# 51           PeripheralBloodMononuclearCell
# 52                                   Muscle
# 53                                   Retina
# 54                                  Trachea
# 55                                LymphNode
# 56                      HematopoieticSystem
# 57                          YolkSacEndoderm
#
#                                               URI
# 0   http://purl.obolibrary.org/obo/UBERON_0002371
# 1   http://purl.obolibrary.org/obo/UBERON_0001103
# 2   http://purl.obolibrary.org/obo/UBERON_0018707
# 3   http://purl.obolibrary.org/obo/UBERON_0012168
# 4   http://purl.obolibrary.org/obo/UBERON_0002370
# 5   http://purl.obolibrary.org/obo/UBERON_0000056
# 6         http://purl.obolibrary.org/obo/FMA_7379
# 7   http://purl.obolibrary.org/obo/UBERON_0001224
# 8   http://purl.obolibrary.org/obo/UBERON_0005439
# 9   http://purl.obolibrary.org/obo/UBERON_0008800
# 10  http://purl.obolibrary.org/obo/UBERON_0001013
# 11  http://purl.obolibrary.org/obo/UBERON_0001911
# 12  http://purl.obolibrary.org/obo/UBERON_0001786
# 13  http://purl.obolibrary.org/obo/UBERON_0004877
# 14    http://purl.obolibrary.org/obo/NCRO_0000105
# 15  http://purl.obolibrary.org/obo/UBERON_0000006
# 16  http://purl.obolibrary.org/obo/UBERON_0007177
# 17  http://purl.obolibrary.org/obo/UBERON_0002481
# 18  http://purl.obolibrary.org/obo/UBERON_0001225
# 19  http://purl.obolibrary.org/obo/UBERON_0000362
# 20  http://purl.obolibrary.org/obo/UBERON_0000955
# 21  http://purl.obolibrary.org/obo/UBERON_0001264
# 22  http://purl.obolibrary.org/obo/UBERON_0002171
# 23      http://purl.obolibrary.org/obo/EHDA_10432
# 24  http://purl.obolibrary.org/obo/UBERON_0002107
# 25  http://purl.obolibrary.org/obo/UBERON_0002106
# 26  http://purl.obolibrary.org/obo/UBERON_0001003
# 27      http://purl.obolibrary.org/obo/PO_0005708
# 28  http://purl.obolibrary.org/obo/UBERON_0002450
# 29     http://purl.obolibrary.org/obo/BTO_0001078
# 30  http://purl.obolibrary.org/obo/UBERON_0008953
# 31  http://purl.obolibrary.org/obo/UBERON_0007026
# 32  http://purl.obolibrary.org/obo/UBERON_0000358
# 33  http://purl.obolibrary.org/obo/UBERON_0002097
# 34  http://purl.obolibrary.org/obo/UBERON_0002048
# 35  http://purl.obolibrary.org/obo/UBERON_0001043
# 36  http://purl.obolibrary.org/obo/UBERON_0001723
# 37  http://purl.obolibrary.org/obo/UBERON_0000948
# 38  http://purl.obolibrary.org/obo/UBERON_0003902
# 39  http://purl.obolibrary.org/obo/UBERON_0002405
# 40  http://purl.obolibrary.org/obo/IDOMAL_0000646
# 41  http://purl.obolibrary.org/obo/UBERON_0002469
# 42  http://purl.obolibrary.org/obo/UBERON_0008946
# 43  http://purl.obolibrary.org/obo/UBERON_0000059
# 44    http://purl.obolibrary.org/obo/ICDO_0000104
# 45  http://purl.obolibrary.org/obo/UBERON_0013756
# 46  http://purl.obolibrary.org/obo/UBERON_0001155
# 47  http://purl.obolibrary.org/obo/UBERON_0002524
# 48  http://purl.obolibrary.org/obo/UBERON_0002113
# 49    http://purl.obolibrary.org/obo/OMIT_0006347
# 50    http://purl.obolibrary.org/obo/NCRO_0000112
# 51      http://purl.obolibrary.org/obo/CL_2000001
# 52  http://purl.obolibrary.org/obo/UBERON_0001630
# 53  http://purl.obolibrary.org/obo/UBERON_0000966
# 54  http://purl.obolibrary.org/obo/UBERON_0003126
# 55     http://purl.obolibrary.org/obo/BTO_0000784
# 56  http://purl.obolibrary.org/obo/UBERON_0002390
# 57  http://purl.obolibrary.org/obo/UBERON_0003257

# %%
df = df.append(rows, ignore_index=True).drop_duplicates().dropna()
df
# Out:
#                       name                                            URI
# 0                   Kidney  http://purl.obolibrary.org/obo/UBERON_0002113
# 1               Bronchiole  http://purl.obolibrary.org/obo/UBERON_0002186
# 2    MiddleLobeOfRightLung  http://purl.obolibrary.org/obo/UBERON_0002174
# 3                     Lung  http://purl.obolibrary.org/obo/UBERON_0002048
# 4               PedalDigit  http://purl.obolibrary.org/obo/UBERON_0006051
# ..                     ...                                            ...
# 289                 Muscle  http://purl.obolibrary.org/obo/UBERON_0001630
# 291                Trachea  http://purl.obolibrary.org/obo/UBERON_0003126
# 292              LymphNode     http://purl.obolibrary.org/obo/BTO_0000784
# 293    HematopoieticSystem  http://purl.obolibrary.org/obo/UBERON_0002390
# 294        YolkSacEndoderm  http://purl.obolibrary.org/obo/UBERON_0003257
#
# [148 rows x 2 columns]

# %%
df.to_csv('../SingleCell-Files/organism_parts_ontology.csv', index=False, header=False, sep='\t')
